# %% [markdown]
# # KoNLPy 설치하기

# %%
# !set -x \
&& pip install konlpy \
&& curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh | bash -x
# Out:
# + pip install konlpy
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.3.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from konlpy) (0.4.4)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.12.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# + curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh
# + bash -x
# + mecab_dicdir=/usr/local/lib/mecab/dic/mecab-ko-dic
# + set -e
# ++ uname
# + os=Linux
# + [[ ! Linux == \L\i\n\u\x ]]
# + hash sudo
# + sudo=sudo
# + python=python3
# + hash pyenv
# + at_user_site=
# ++ check_python_site_location_is_writable
# ++ python3 -
# + [[ 1 == \0 ]]
# + hash automake
# + hash mecab
# + echo 'mecab-ko is already installed'
# mecab-ko is already installed
# + [[ -d /usr/local/lib/mecab/dic/mecab-ko-dic ]]
# + echo 'mecab-ko-dic is already installed'
# mecab-ko-dic is already installed
# ++ python3 -c 'import pkgutil; print(1 if pkgutil.find_loader("MeCab") else 0)'
# + [[ 1 == \1 ]]
# + echo 'mecab-python is already installed'
# mecab-python is already installed
# + echo Done.
# Done.

# %% [markdown]
# # 구글드라이브에 있는 CSV 파일 불러오기

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
couple_vlog = pd.read_csv('/content/drive/MyDrive/졸업프로젝트/강원도 명소 데이터/guesthouse1_blog.csv')
place = pd.read_csv('/content/drive/MyDrive/졸업프로젝트/강원도 명소 데이터/강릉_춘천_위도_경도_추가.csv', encoding='utf-8')

# %% [markdown]
# 블로그 내용이 nan인 행 삭제

# %%
couple_vlog = couple_vlog.dropna(subset=['블로그 내용'])

# %%
couple_vlog
# Out:
#             사용자 카테고리  ... Unnamed: 6
# 0          IF 게스트하우스  ...        5.0
# 1          IF 게스트하우스  ...        2.0
# 2          IF 게스트하우스  ...        NaN
# 3          IF 게스트하우스  ...        2.0
# 4          IF 게스트하우스  ...        1.0
# ...              ...  ...        ...
# 3994  강릉 게스트하우스 커피거리  ...        2.0
# 3995  강릉 게스트하우스 커피거리  ...        NaN
# 3996  강릉 게스트하우스 커피거리  ...        1.0
# 3997  강릉 게스트하우스 커피거리  ...        5.0
# 3998  강릉 게스트하우스 커피거리  ...        NaN
#
# [3999 rows x 7 columns]

# %% [markdown]
# 여행지아이디,여행지 이름,주소,카테고리,평점 리스트

# %%
p_li = place.values.tolist()

# %%
p_li
# Out:
# [[1,
#   '하슬라아트월드',
#   '테마파크',
#   3.7,
#   '282',
#   '강원 강릉시 강동면 정동진리 524-19',
#   37.7079586,
#   129.012171],
#  [2, '경포해변', '해수욕장,해변', 4.1, '194', '강원 강릉시 창해로 514', 37.8057795, 128.9074169],
#  [3,
#   '정동심곡 바다부채길',
#   '관광,명소',
#   4.3,
#   '182',
#   '강원 강릉시 강동면 심곡리 114-3',
#   37.6662501,
#   129.05454709999998],
#  [4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [5,
#   '정동진해변',
#   '해수욕장,해변',
#   4.1,
#   '123',
#   '강원 강릉시 강동면 정동진리 64-3',
#   37.68909379999999,
#   129.0348209],
#  [6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [9,
#   '강릉카페거리',
#   '카페거리',
#   4.0,
#   '199',
#   '강원 강릉시 창해로14번길 20',
#   37.772646200000004,
#   128.9472033],
#  [10,
#   '주문진방사제',
#   '관광,명소',
#   3.9,
#   '86',
#   '강원 강릉시 주문진읍 교항리',
#   37.8789811,
#   128.8177091],
#  [11,
#   '멍에전망대',
#   '전망대',
#   4.1,
#   '37',
#   '강원 강릉시 왕산면 대기리 2214-272',
#   37.6261275,
#   128.7414602],
#  [12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [13,
#   '영진해변',
#   '해수욕장,해변',
#   4.1,
#   '43',
#   '강원 강릉시 연곡면 영진리 72-2',
#   37.8680886,
#   128.8469178],
#  [14, '강릉선교장', '문화유적', 3.1, '124', '강원 강릉시 운정길 63', 37.7865935, 128.8851277],
#  [15,
#   '사천해변',
#   '해수욕장,해변',
#   3.8,
#   '27',
#   '강원 강릉시 사천면 방동리 282-1',
#   37.8202946,
#   128.86527809999998],
#  [16,
#   '초당순두부마을',
#   '테마거리',
#   3.1,
#   '33',
#   '강원 강릉시 초당순두부길 89-8',
#   37.791815299999996,
#   128.9151518],
#  [17,
#   '강릉솔향수목원',
#   '수목원,식물원',
#   4.5,
#   '65',
#   '강원 강릉시 구정면 수목원길 156',
#   37.6927213,
#   128.8609497],
#  [18,
#   '사근진해변',
#   '해수욕장,해변',
#   4.4,
#   '23',
#   '강원 강릉시 해안로604번길 14',
#   37.8126601,
#   128.8988879],
#  [19,
#   '주문진해변',
#   '해수욕장,해변',
#   4.4,
#   '39',
#   '강원 강릉시 주문진읍 향호리 8-35',
#   37.909236299999996,
#   128.8215305],
#  [20, '경포호', '호수', 4.3, '88', '강원 강릉시 초당동', 37.7919049, 128.9158303],
#  [21,
#   '순긋해변',
#   '해수욕장,해변',
#   4.0,
#   '25',
#   '강원 강릉시 안현동 235-5',
#   37.801911100000005,
#   128.8758249],
#  [22,
#   'BTS 버스정류장',
#   '촬영지',
#   5.0,
#   '12',
#   '강원 강릉시 주문진읍 향호리 8-39',
#   37.909236299999996,
#   128.8215305],
#  [23,
#   '향호해변',
#   '해수욕장,해변',
#   5.0,
#   '35',
#   '강원 강릉시 주문진읍 향호리',
#   37.8996511,
#   128.7843327],
#  [24,
#   '해안도로',
#   '드라이브코스',
#   3.7,
#   '3',
#   '강원 강릉시 강동면 헌화로 641',
#   37.6647915,
#   129.05304579999998],
#  [25,
#   '사천진해변',
#   '해수욕장,해변',
#   3.4,
#   '31',
#   '강원 강릉시 사천면 진리해변길 131',
#   37.839526299999996,
#   128.87401770000002],
#  [26,
#   '옥계해변',
#   '해수욕장,해변',
#   3.8,
#   '14',
#   '강원 강릉시 옥계면 금진솔밭길 148-3',
#   37.6304348,
#   129.04512659999997],
#  [27,
#   '소돌해변',
#   '해수욕장,해변',
#   4.4,
#   '41',
#   '강원 강릉시 주문진읍 주문리',
#   37.8990315,
#   128.8227808],
#  [28,
#   '국립대관령자연휴양림',
#   '자연휴양림',
#   3.7,
#   '16',
#   '강원 강릉시 성산면 삼포암길 133',
#   37.7144152,
#   128.7848205],
#  [29, '금진해변', '해수욕장,해변', 4.1, '10', '강원 강릉시 옥계면 금진리', 37.6432124, 129.0367071],
#  [30,
#   '대관령아기동물목장',
#   '동물원',
#   3.3,
#   '61',
#   '강원 강릉시 사천면 송암골길 197-23',
#   37.797637,
#   128.828676],
#  [31,
#   '국립대관령치유의숲',
#   '숲',
#   4.6,
#   '11',
#   '강원 강릉시 성산면 대관령옛길 127-42',
#   37.7107795,
#   128.7968291],
#  [32,
#   '남항진해변',
#   '해수욕장,해변',
#   3.7,
#   '9',
#   '강원 강릉시 공항길127번길 67',
#   37.7639352,
#   128.9543434],
#  [33,
#   '강릉임해자연휴양림',
#   '자연휴양림',
#   4.8,
#   '9',
#   '강원 강릉시 강동면 율곡로 1715-85',
#   37.718520399999996,
#   128.9985277],
#  [34,
#   '일출전망대',
#   '전망대',
#   5.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 2214-187',
#   37.6261275,
#   128.7414602],
#  [35,
#   '오대산국립공원',
#   '국립공원',
#   4.4,
#   '13',
#   '강원 강릉시 연곡면',
#   37.85975870000001,
#   128.8368017],
#  [36, '강릉월화거리', '테마거리', 4.0, '82', '강원 강릉시 경강로 2111', 37.7562073, 128.8969844],
#  [37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [38,
#   '안인해변',
#   '해수욕장,해변',
#   3.0,
#   '8',
#   '강원 강릉시 강동면 안인진리 316-2',
#   37.728188,
#   128.9866112],
#  [39,
#   '노추산모정탑',
#   '탑,비석',
#   5.0,
#   '5',
#   '강원 강릉시 왕산면 대기리 산 716',
#   37.570945200000004,
#   128.7406375],
#  [40, '경포도립공원', '도립공원', 4.0, '2', '강원 강릉시 창해로 473', 37.8029286, 128.9097587],
#  [41, '소금강계곡', '계곡', 4.6, '17', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [42, '소돌아들바위', '바위', 4.6, '5', '강원 강릉시 주문진읍 주문리', 37.8990315, 128.8227808],
#  [43,
#   '연곡해변',
#   '해수욕장,해변',
#   3.4,
#   '12',
#   '강원 강릉시 연곡면 해안로 1282',
#   37.858084399999996,
#   128.8530771],
#  [44,
#   '쌍둥이동물농장',
#   '동물원',
#   3.5,
#   '49',
#   '강원 강릉시 옥계면 천남리 384',
#   37.608512100000006,
#   129.0390821],
#  [45, '염전해변', '해수욕장,해변', 4.0, '4', '강원 강릉시 강동면 안인진리', 37.728188, 128.9866112],
#  [46,
#   '뒷뜨루',
#   '관광농원',
#   4.5,
#   '74',
#   '강원 강릉시 사천면 청솔공원길 108',
#   37.8352469,
#   128.8372205],
#  [47, '강릉대도호부 관아', '유적지', 4.3, '32', '강원 강릉시 명주동', 37.7507099, 128.8914359],
#  [48,
#   '강문솟대다리',
#   '관광,명소',
#   3.6,
#   '16',
#   '강원 강릉시 강문동 248-4',
#   37.7977587,
#   128.9167205],
#  [50,
#   '호텔탑스텐 금진온천',
#   '온천',
#   5.0,
#   '2',
#   '강원 강릉시 옥계면 헌화로 455-34 1층',
#   37.6532823,
#   129.0514825],
#  [51, '하평해변', '해수욕장,해변', 2.0, '6', '강원 강릉시 사천면 사천진리', 37.8435195, 128.8684982],
#  [52,
#   '런닝맨 강릉점',
#   '테마파크',
#   4.0,
#   '46',
#   '강원 강릉시 창해로 307 파인동 2층',
#   37.7911114,
#   128.92106869999998],
#  [53,
#   '노인봉',
#   '산봉우리',
#   4.2,
#   '46',
#   '강원 강릉시 연곡면 삼산리 산 1-2',
#   37.83994939999999,
#   128.6566871],
#  [54,
#   '강릉안반데기관광농원',
#   '관광농원',
#   0.0,
#   '8',
#   '강원 강릉시 왕산면 안반데기1길 203',
#   37.622628999999996,
#   128.73915549999998],
#  [55,
#   '호린파크',
#   '테마파크',
#   4.0,
#   '19',
#   '강원 강릉시 사천면 해안로 1119-51',
#   37.833163,
#   128.8770374],
#  [56,
#   '대관령전망대',
#   '전망대',
#   4.5,
#   '14',
#   '강원 강릉시 성산면 어흘리 803',
#   37.7107204,
#   128.7795353],
#  [57,
#   '경포해변인증센터',
#   '자전거여행',
#   0.0,
#   '4',
#   '강원 강릉시 안현동 산 1-10',
#   37.8054757,
#   128.90782990000002],
#  [58,
#   '강릉바우길',
#   '도보여행',
#   5.0,
#   '1',
#   '강원 강릉시 임영로180번길 25',
#   37.7571009,
#   128.89463130000001],
#  [59,
#   '순포해수욕장',
#   '해수욕장,해변',
#   4.6,
#   '1',
#   '강원 강릉시 사천면 산대월리 산 1',
#   37.8227298,
#   128.88591350000002],
#  [60,
#   '삽당령',
#   '바위',
#   0.0,
#   '8',
#   '강원 강릉시 왕산면 목계리',
#   37.625665999999995,
#   128.8625156],
#  [61,
#   '사천진해변공원',
#   '해수욕장,해변',
#   0.0,
#   '2',
#   '강원 강릉시 사천면 사천진리',
#   37.8435195,
#   128.8684982],
#  [62, '용지기념각', '문화유적', 0.0, '0', '강원 강릉시 포남동 1138-8', 37.7603559, 128.9042446],
#  [63,
#   '닭목령',
#   '고개',
#   0.0,
#   '2',
#   '강원 강릉시 왕산면 왕산리',
#   37.651880600000005,
#   128.7800211],
#  [64,
#   '괘방산',
#   '산',
#   4.5,
#   '16',
#   '강원 강릉시 강동면 모전리 26-3',
#   37.707970700000004,
#   128.9993365],
#  [65,
#   '허난설헌생가터',
#   '생가,고택',
#   3.4,
#   '43',
#   '강원 강릉시 난설헌로193번길 1-16',
#   37.7919383,
#   128.9092743],
#  [66,
#   '노추산모정탑길',
#   '도보여행',
#   0.0,
#   '8',
#   '강원 강릉시 왕산면 대기리 산 716',
#   37.570945200000004,
#   128.7406375],
#  [67, '사천물회마을', '관광,명소', 5.0, '4', '강원 강릉시 사천면 사천진리', 37.8435195, 128.8684982],
#  [68,
#   '부연동계곡',
#   '계곡',
#   0.0,
#   '1',
#   '강원 강릉시 연곡면 삼산리 산 133-12',
#   37.8132591,
#   128.7053777],
#  [69, '음악시간펜션', '펜션', 3.0, '7', '강원 강릉시 사천면 해안로 1151', 37.833163, 128.8770374],
#  [71,
#   '고루포기산',
#   '산',
#   4.7,
#   '9',
#   '강원 강릉시 왕산면 왕산리 산 1',
#   37.686331,
#   128.80631699999998],
#  [72,
#   '명주군왕릉',
#   '릉,묘,총',
#   5.0,
#   '3',
#   '강원 강릉시 성산면 삼왕길 204-39',
#   37.7622436,
#   128.7968793],
#  [73,
#   '애니멀스토리',
#   '동물원',
#   0.0,
#   '11',
#   '강원 강릉시 성산면 성연로 212-10',
#   37.7339859,
#   128.811375],
#  [74, '강릉향교', '향교,서당', 0.0, '5', '강원 강릉시 명륜로 29', 37.7634, 128.895101],
#  [75, '남대천', '하천', 0.0, '4', '강원 강릉시 성산면 구산리', 37.7193495, 128.8287811],
#  [80, '죽헌저수지', '저수지', 0.0, '0', '강원 강릉시 지변동', 37.7745945, 128.86716950000002],
#  [82,
#   '월화거리관광안내센터',
#   '관광안내소',
#   0.0,
#   '3',
#   '강원 강릉시 성남동 41-12',
#   37.7543412,
#   128.8993541],
#  [83,
#   '강릉원주대학교 강릉캠퍼스 해람지',
#   '호수',
#   0.0,
#   '0',
#   '강원 강릉시 죽헌길 7',
#   37.7664551,
#   128.8712017],
#  [85,
#   '정동진 인증센터',
#   '자전거여행',
#   0.0,
#   '2',
#   '강원 강릉시 강동면 정동진리 569-2',
#   37.687172499999996,
#   129.0376985],
#  [86,
#   '바다여행펜션',
#   '펜션',
#   0.0,
#   '1',
#   '강원 강릉시 경포로371번길 23',
#   37.79728660000001,
#   128.8966997],
#  [88, '경포인공폭포', '폭포', 0.0, '0', '강원 강릉시 창해로 563', 37.8084768, 128.9028744],
#  [89,
#   '도직해변',
#   '해수욕장,해변',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 도직리 97-12',
#   37.609390399999995,
#   129.06767539999998],
#  [90,
#   '강릉여행굿캠핑&펜션',
#   '펜션',
#   5.0,
#   '3',
#   '강원 강릉시 사천면 해안로 904-8',
#   37.8319051,
#   128.8757503],
#  [92, '단경골계곡', '계곡', 3.5, '1', '강원 강릉시 강동면 언별리', 37.6645164, 128.9241222],
#  [94,
#   '석병산',
#   '산',
#   0.0,
#   '12',
#   '강원 강릉시 옥계면 산계리 산 428',
#   37.5789,
#   128.94787250000002],
#  [96,
#   '강릉정동진해안단구',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 심곡리 1-11',
#   37.6662501,
#   129.05454709999998],
#  [98,
#   '강릉구라미온천',
#   '온천',
#   1.7,
#   '1',
#   '강원 강릉시 사천면 구라미등길 25-15',
#   37.843541200000004,
#   128.8396741],
#  [99,
#   '능경봉',
#   '산봉우리',
#   4.0,
#   '2',
#   '강원 강릉시 왕산면 왕산리 산 1-8',
#   37.6744834,
#   128.7694837],
#  [100,
#   '강릉임영관 삼문',
#   '문',
#   4.0,
#   '4',
#   '강원 강릉시 임영로131번길 6',
#   37.7531104,
#   128.8917655],
#  [101,
#   '사천진 바위섬',
#   '바위',
#   5.0,
#   '1',
#   '강원 강릉시 사천면 사천진리 1-26',
#   37.839771500000005,
#   128.87578870000002],
#  [102,
#   '송천약수',
#   '샘터,약수터',
#   4.5,
#   '1',
#   '강원 강릉시 연곡면 삼산리 산 195-1',
#   37.83994939999999,
#   128.6566871],
#  [103, '소금강', '강', 0.0, '6', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [104,
#   '제왕산',
#   '산',
#   5.0,
#   '8',
#   '강원 강릉시 왕산면 왕산리 산 1',
#   37.686331,
#   128.80631699999998],
#  [106, '사기막저수지', '저수지', 0.0, '0', '강원 강릉시 사천면 사기막리', 37.778613, 128.7736565],
#  [107,
#   '대관령옛길표지석',
#   '탑,비석',
#   4.0,
#   '0',
#   '강원 강릉시 성산면 어흘리 산 2-21',
#   37.7248749,
#   128.813972],
#  [108, '양양남대천', '하천', 0.0, '0', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [109, '향호', '저수지', 0.0, '7', '강원 강릉시 주문진읍 향호리', 37.8996511, 128.7843327],
#  [111,
#   '동대산',
#   '산',
#   5.0,
#   '12',
#   '강원 강릉시 연곡면 삼산리 산 4',
#   37.83994939999999,
#   128.6566871],
#  [112,
#   '장덕리은행나무',
#   '문화유적',
#   4.0,
#   '0',
#   '강원 강릉시 주문진읍 장덕리 643',
#   37.87764749999999,
#   128.7831095],
#  [114, '강릉남대천', '하천', 4.0, '2', '강원 강릉시 성남동', 37.7524714, 128.89898970000002],
#  [115,
#   '굴산사지당간지주',
#   '문화유적',
#   0.0,
#   '10',
#   '강원 강릉시 구정면 학산리 1181',
#   37.707269000000004,
#   128.8918012],
#  [116,
#   '기린온천사우나',
#   '온천',
#   1.0,
#   '0',
#   '강원 강릉시 남부로125번길 18',
#   37.7434915,
#   128.893503],
#  [117,
#   '모래시계소나무',
#   '촬영지',
#   5.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [120,
#   '부채바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 심곡리 12-12',
#   37.67332820000001,
#   129.0573198],
#  [121, '향호지', '저수지', 0.0, '1', '강원 강릉시 주문진읍 향호리', 37.8996511, 128.7843327],
#  [122,
#   '구룡폭포',
#   '폭포',
#   4.0,
#   '1',
#   '강원 강릉시 연곡면 소금강길 500',
#   37.813579600000004,
#   128.7044652],
#  [123,
#   '영동고속도로 대관령구간',
#   '드라이브코스',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 왕산리',
#   37.651880600000005,
#   128.7800211],
#  [124,
#   '신사임당사친사비',
#   '탑,비석',
#   4.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 산 2-12',
#   37.7283347,
#   128.8184182],
#  [125,
#   '강릉여행 굿캠핑',
#   '카라반',
#   5.0,
#   '8',
#   '강원 강릉시 사천면 해안로 904-8',
#   37.8319051,
#   128.8757503],
#  [126,
#   '강릉여행자플랫폼',
#   '관광안내소',
#   5.0,
#   '0',
#   '강원 강릉시 죽헌길9번길 17',
#   37.768888200000006,
#   128.87383290000002],
#  [127,
#   '월화정',
#   '문화유적',
#   3.0,
#   '3',
#   '강원 강릉시 강변로312번길 1-7',
#   37.750975200000006,
#   128.9025168],
#  [129,
#   '경포가시연습지 습지광장',
#   '광장',
#   0.0,
#   '1',
#   '강원 강릉시 운정동 14',
#   37.79153839999999,
#   128.8964338],
#  [130,
#   '원대재산림욕장',
#   '자연휴양림',
#   5.0,
#   '2',
#   '강원 강릉시 교동 1071-1',
#   37.761162,
#   128.8838576],
#  [131,
#   '신왕저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 신왕리',
#   37.816453499999994,
#   128.7640752],
#  [132,
#   '오봉저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 오봉리 408',
#   37.6961366,
#   128.8114885],
#  [133,
#   '라파트리치오신부순교터',
#   '종교유적지',
#   5.0,
#   '1',
#   '강원 강릉시 옥계면 낙풍리 산 47-3',
#   37.63516120000001,
#   129.0211949],
#  [134,
#   '대관령옛길',
#   '도보여행',
#   2.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 761',
#   37.7028179,
#   128.7884916],
#  [135,
#   '모래시계공원 모래시계탑',
#   '관광,명소',
#   5.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 7-1',
#   37.689512,
#   129.03202620000002],
#  [137,
#   '경포관광안내센터',
#   '관광안내소',
#   0.0,
#   '1',
#   '강원 강릉시 안현동 산 2-11',
#   37.801911100000005,
#   128.8758249],
#  [139,
#   '수청동계곡',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 신왕길 443-4',
#   37.8232912,
#   128.7703002],
#  [140,
#   '닭목재',
#   '드라이브코스',
#   0.0,
#   '1',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [141, '삼일운동기념탑', '탑,비석', 4.0, '2', '강원 강릉시 저동', 37.7981294, 128.8925034],
#  [142,
#   '고성목해수욕장',
#   '해수욕장,해변',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [143,
#   '월대산',
#   '산',
#   5.0,
#   '0',
#   '강원 강릉시 두산동 산 55',
#   37.762700200000005,
#   128.9211396],
#  [144, '신복사지', '문화유적', 0.0, '0', '강원 강릉시 내곡동', 37.7390776, 128.8808633],
#  [145, '강릉해운정', '문화유적', 0.0, '5', '강원 강릉시 운정길 125', 37.7861329, 128.8912551],
#  [146,
#   '삼교지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 삼교리',
#   37.8860651,
#   128.72118079999998],
#  [147,
#   '모정의탑',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 1526',
#   37.57821989999999,
#   128.7490804],
#  [148,
#   '대관령영동고속도로 준공비',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 어흘리 산 2-14',
#   37.6860585,
#   128.761372],
#  [149,
#   '옥계저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 북동리',
#   37.6226354,
#   128.96262190000002],
#  [150, '연곡천', '하천', 0.0, '1', '강원 강릉시 연곡면 동덕리', 37.8517901, 128.8393749],
#  [151,
#   '송담서원',
#   '서원',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 송담서원길 27-7',
#   37.692901899999995,
#   128.92917179999998],
#  [152,
#   '기마봉',
#   '산봉우리',
#   3.7,
#   '6',
#   '강원 강릉시 옥계면 금진리 산 81',
#   37.6441514,
#   129.0318912],
#  [153,
#   '주문진관광안내소',
#   '관광안내소',
#   2.0,
#   '0',
#   '강원 강릉시 주문진읍 해안로 1734',
#   37.8895823,
#   128.8286288],
#  [154,
#   '하슬라아트월드 하늘전망대',
#   '테마파크시설',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 율곡로 1441',
#   37.7056021,
#   129.0080007],
#  [156, '부연약수', '샘터,약수터', 5.0, '0', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [157,
#   '오봉서원',
#   '서원',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 오봉서원길 32',
#   37.7107775,
#   128.81941940000002],
#  [158,
#   '경포가시연습지 방문자센터',
#   '관광안내소',
#   0.0,
#   '3',
#   '강원 강릉시 저동 144-4',
#   37.7917299,
#   128.8961284],
#  [159, '죽도봉', '산봉우리', 0.0, '2', '강원 강릉시 견소동 11-1', 37.7704204, 128.9504858],
#  [161,
#   '오죽헌 율곡인성교육관',
#   '유적지',
#   0.0,
#   '1',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [162,
#   '석란정',
#   '문화유적',
#   4.5,
#   '0',
#   '강원 강릉시 강문동 258-14',
#   37.803507700000004,
#   128.9086246],
#  [163,
#   '경포대허브농원',
#   '관광농원',
#   0.0,
#   '3',
#   '강원 강릉시 사천면 손맞이길 91-23',
#   37.843697799999994,
#   128.86644679999998],
#  [164,
#   '대관령국사여성황사',
#   '사당,제단',
#   5.0,
#   '0',
#   '강원 강릉시 경강로1804번길 12-12',
#   37.7453316,
#   128.8658275],
#  [165,
#   '괘방산 등산코스',
#   '등산로',
#   4.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 17',
#   37.6911646,
#   129.0330457],
#  [166, '화부산', '산', 0.0, '0', '강원 강릉시 교동 산 153-3', 37.7644528, 128.8932694],
#  [168,
#   '동막저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 어단리',
#   37.6785816,
#   128.89343689999998],
#  [169,
#   '하시동고분군',
#   '릉,묘,총',
#   0.0,
#   '1',
#   '강원 강릉시 강동면 풍호길 300-83',
#   37.7496391,
#   128.97020279999998],
#  [170,
#   '단경골휴양지',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 단경로 841',
#   37.6723487,
#   128.9164916],
#  [171,
#   '정동진헌화로',
#   '드라이브코스',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [172,
#   '장현저수지',
#   '저수지',
#   4.5,
#   '2',
#   '강원 강릉시 장현동',
#   37.728821200000006,
#   128.8939201],
#  [173, '헌화로', '드라이브코스', 3.5, '12', '강원 강릉시 강동면 심곡리', 37.6672988, 129.0416628],
#  [174,
#   '담정관광농원',
#   '관광농원',
#   3.0,
#   '3',
#   '강원 강릉시 강동면 언별리 산 253',
#   37.6460441,
#   128.92168909999998],
#  [175,
#   '최선평가옥',
#   '생가,고택',
#   5.0,
#   '0',
#   '강원 강릉시 주문진읍 신리천로 342',
#   37.878467,
#   128.7961997],
#  [176,
#   '초당마을숲',
#   '숲',
#   0.0,
#   '0',
#   '강원 강릉시 난설헌로193번길 1-16',
#   37.7919383,
#   128.9092743],
#  [177,
#   '칠성산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 목계리 산 460-1',
#   37.61781920000001,
#   128.87906329999998],
#  [178,
#   '신복사지삼층석탑',
#   '탑,비석',
#   0.0,
#   '3',
#   '강원 강릉시 내곡동 403-2',
#   37.7427739,
#   128.8855576],
#  [179,
#   '사천천',
#   '하천',
#   0.0,
#   '1',
#   '강원 강릉시 사천면 덕실리',
#   37.805178399999996,
#   128.8410131],
#  [180,
#   '성산먹거리촌',
#   '먹자골목',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 구산리 350-1',
#   37.71538839999999,
#   128.8299289],
#  [181, '홍장암', '문화유적', 0.0, '3', '강원 강릉시 저동 2-4', 37.8012114, 128.9029517],
#  [182,
#   '칠성저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 어단리',
#   37.6785816,
#   128.89343689999998],
#  [183,
#   '파도여행펜션게스트하우스',
#   '게스트하우스',
#   2.7,
#   '1',
#   '강원 강릉시 창해로2번길 28 2,3층',
#   37.7714436,
#   128.9481777],
#  [185,
#   '강릉초당동유적',
#   '유적지',
#   0.0,
#   '0',
#   '강원 강릉시 초당동 84-2',
#   37.7861761,
#   128.91651159999998],
#  [186,
#   '칠봉산',
#   '산',
#   0.0,
#   '1',
#   '강원 강릉시 구정면 제비리 산 173',
#   37.71571429999999,
#   128.84769690000002],
#  [187, '임경당', '유적지', 0.0, '0', '강원 강릉시 성산면 금산리 445', 37.7397432, 128.8513939],
#  [188,
#   '대굴령전통먹거리마을',
#   '관광단지',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 삼왕길 193-22',
#   37.759688700000005,
#   128.7917403],
#  [189,
#   '강릉부관아',
#   '종교유적지',
#   0.0,
#   '0',
#   '강원 강릉시 임영로131번길 6',
#   37.7531104,
#   128.8917655],
#  [190,
#   '대굴령마을',
#   '관광,명소',
#   5.0,
#   '1',
#   '강원 강릉시 성산면 성연로 17',
#   37.7228451,
#   128.8151159],
#  [191, '월파정', '문화유적', 4.3, '2', '강원 강릉시 초당동 549', 37.7971771, 128.904666],
#  [193,
#   '화부산사',
#   '사당,제단',
#   0.0,
#   '0',
#   '강원 강릉시 교동 727-5',
#   37.767759399999996,
#   128.89113329999998],
#  [194,
#   '호해정',
#   '관광,명소',
#   0.0,
#   '1',
#   '강원 강릉시 저동 433',
#   37.801649700000006,
#   128.8969977],
#  [195,
#   '강릉서지조진사댁',
#   '유적지',
#   4.0,
#   '0',
#   '강원 강릉시 난곡길76번길 43-9',
#   37.791393799999994,
#   128.88095900000002],
#  [196, '마명산', '산', 0.0, '0', '강원 강릉시 유천동 276-1', 37.7665253, 128.866322],
#  [197, '칠사당', '유적지', 0.0, '5', '강원 강릉시 경강로 2045', 37.7517814, 128.8918926],
#  [198, '모산봉', '산봉우리', 0.0, '2', '강원 강릉시 박월동 산 8-1', 37.7335356, 128.9058504],
#  [200,
#   '하슬라아트월드 바다정원',
#   '테마파크시설',
#   0.0,
#   '1',
#   '강원 강릉시 강동면 율곡로 1441',
#   37.7056021,
#   129.0080007],
#  [201,
#   '소황병산',
#   '산',
#   0.0,
#   '4',
#   '강원 강릉시 연곡면 삼산리 산 333',
#   37.83994939999999,
#   128.6566871],
#  [202, '죽헌저수지', '저수지', 0.0, '0', '강원 강릉시 죽헌동', 37.7813425, 128.8562267],
#  [203,
#   '보현사낭원대사오진탑',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 보현길 396',
#   37.736917,
#   128.7698582],
#  [204, '환선정', '관광,명소', 5.0, '0', '강원 강릉시 포남동 146-3', 37.785125, 128.9055],
#  [205,
#   '땅골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [206,
#   '무다리골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 장덕리',
#   37.873587799999996,
#   128.7797776],
#  [207, '경포저수지', '저수지', 0.0, '0', '강원 강릉시 죽헌동', 37.7813425, 128.8562267],
#  [208,
#   '신사임당동상',
#   '동상',
#   0.0,
#   '0',
#   '강원 강릉시 죽헌동 177-4',
#   37.777881799999996,
#   128.8769118],
#  [209,
#   '강릉 굴산사지석불좌상',
#   '불상,석불',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 학산리',
#   37.708818799999996,
#   128.890621],
#  [210,
#   '삼거리',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 안인리',
#   37.73289820000001,
#   128.97692320000002],
#  [211,
#   '허균문학비 허난설헌시비',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 초당동 472-2',
#   37.79364,
#   128.9081449],
#  [212,
#   '관음리오층석탑',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 관음리 774',
#   37.7480617,
#   128.82642420000002],
#  [213,
#   '대관령옛주막터',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 어흘리',
#   37.7107204,
#   128.7795353],
#  [214, '충혼탑', '탑,비석', 0.0, '2', '강원 강릉시 저동', 37.7981294, 128.8925034],
#  [215,
#   '미림식물원',
#   '수목원,식물원',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 공제로 241',
#   37.735609000000004,
#   128.8501088],
#  [216,
#   '방터골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 목계리',
#   37.625665999999995,
#   128.8625156],
#  [217,
#   '용연동 마을관리휴양지',
#   '유원지',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 중앙서로 657',
#   37.8057096,
#   128.8193664],
#  [219,
#   '금강산성',
#   '산성,성곽',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 1-1',
#   37.83994939999999,
#   128.6566871],
#  [220,
#   '강릉임영관 객사',
#   '문화유적',
#   5.0,
#   '0',
#   '강원 강릉시 임영로131번길 6 외 10',
#   37.7531104,
#   128.8917655],
#  [222,
#   '운산리은행나무',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 운산동 산 331-7',
#   37.7310404,
#   128.9283561],
#  [223, '두로봉', '산봉우리', 0.0, '1', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [224, '경호정', '문화유적', 0.0, '0', '강원 강릉시 경포로371번길 49', 37.7991683, 128.8985472],
#  [225, '서지골', '계곡', 0.0, '0', '강원 강릉시 난곡동', 37.7908354, 128.8784577],
#  [226,
#   '강릉 산계리석탑',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 1232',
#   37.5789,
#   128.94787250000002],
#  [227,
#   '강릉선교장 활래정',
#   '문화유적',
#   4.0,
#   '0',
#   '강원 강릉시 운정길 63',
#   37.7865935,
#   128.8851277],
#  [228,
#   '자병산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 산 428',
#   37.5789,
#   128.94787250000002],
#  [229,
#   '강릉반송댁',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 초당순두부길58번길 10',
#   37.7878506,
#   128.9146011],
#  [230,
#   '용수폭포',
#   '폭포',
#   3.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 1-12',
#   37.83994939999999,
#   128.6566871],
#  [231, '버들고개', '고개', 0.0, '0', '강원 강릉시 성산면 산북리', 37.7030827, 128.8381761],
#  [232,
#   '시간여행스파펜션',
#   '펜션',
#   0.0,
#   '2',
#   '강원 강릉시 사천면 해안로 1151',
#   37.833163,
#   128.8770374],
#  [233,
#   '방동리 무궁화',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 가마골길 22-8',
#   37.827501700000006,
#   128.8638129],
#  [234,
#   '바람부리',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [235,
#   '평화의소녀상',
#   '동상',
#   0.0,
#   '1',
#   '강원 강릉시 저동 645 경포 3·1운동기념공원 내',
#   37.795036100000004,
#   128.8966374],
#  [237, '대창리당간지주', '문화유적', 0.0, '1', '강원 강릉시 옥천동 334', 37.7608127, 128.901195],
#  [238,
#   '향호지 수변로',
#   '숲',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 향호리 1063-2',
#   37.8996511,
#   128.7843327],
#  [239,
#   '등명락가사 등명약수터',
#   '샘터,약수터',
#   0.0,
#   '1',
#   '강원 강릉시 강동면 정동진리 547-14',
#   37.689200799999995,
#   129.0243271],
#  [240,
#   '강릉송라사 석조약사여래좌상',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 송라길 63-20',
#   37.86038569999999,
#   128.82099],
#  [241,
#   '기마봉 데크전망대',
#   '전망대',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 금진리 산 54-1',
#   37.655025099999996,
#   129.0292957],
#  [242,
#   '국립대관령자연휴양림 잔디광장',
#   '광장',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 어흘리 산 368',
#   37.710246500000004,
#   128.7877344],
#  [243, '퇴곡이리', '계곡', 0.0, '0', '강원 강릉시 연곡면 퇴곡리', 37.854748, 128.7321447],
#  [244, '학우리골', '계곡', 0.0, '0', '강원 강릉시 학동', 37.75495170000001, 128.9326169],
#  [245, '옥천동은행나무', '문화유적', 4.5, '0', '강원 강릉시 옥천동 61', 37.7549315, 128.8989856],
#  [246, '황산사', '사당,제단', 0.0, '0', '강원 강릉시 운정길21번길 27', 37.7868031, 128.8813348],
#  [248,
#   '김윤기가옥',
#   '생가,고택',
#   0.0,
#   '1',
#   '강원 강릉시 노가니길 55-11',
#   37.747787100000004,
#   128.9032554],
#  [249,
#   '소금강약용식물원',
#   '수목원,식물원',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 소금강길 13-42',
#   37.841959100000004,
#   128.7054861],
#  [250,
#   '상임경당',
#   '유적지',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 갈매간길 8-3',
#   37.734777799999996,
#   128.8417129],
#  [251,
#   '화란봉',
#   '산봉우리',
#   0.0,
#   '1',
#   '강원 강릉시 왕산면 왕산리 산 2',
#   37.64150479999999,
#   128.79538159999998],
#  [252, '구라미골', '계곡', 0.0, '0', '강원 강릉시 사천면 석교리', 37.8327442, 128.8192363],
#  [253,
#   '향호지 제방',
#   '방조제',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 향호리 891-1',
#   37.8996511,
#   128.7843327],
#  [254, '송천계곡', '계곡', 0.0, '0', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [255,
#   '만물상',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 333',
#   37.83994939999999,
#   128.6566871],
#  [256,
#   '본동골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 산대월리',
#   37.8140851,
#   128.87542520000002],
#  [257,
#   '신복사지 석조보살좌상',
#   '불상,석불',
#   0.0,
#   '0',
#   '강원 강릉시 내곡동 403-2',
#   37.7427739,
#   128.8855576],
#  [258,
#   '강릉방해정',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 경포로 449',
#   37.80075679999999,
#   128.90184250000001],
#  [259,
#   '김동명시비',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 노동리 71',
#   37.8204135,
#   128.8381184],
#  [260,
#   '섬석천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 청량동 512-3',
#   37.74342620000001,
#   128.9210731],
#  [261, '하제민원', '계곡', 0.0, '0', '강원 강릉시 성산면 어흘리', 37.7107204, 128.7795353],
#  [262,
#   '신리천',
#   '하천',
#   0.0,
#   '1',
#   '강원 강릉시 주문진읍 삼교리',
#   37.8860651,
#   128.72118079999998],
#  [263, '원통골', '계곡', 0.0, '0', '강원 강릉시 죽헌동', 37.7813425, 128.8562267],
#  [264,
#   '강릉김윤기가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 유죽길465번길 35',
#   37.7831665,
#   128.86848700000002],
#  [265, '오봉산', '산', 0.0, '0', '강원 강릉시 성산면 어흘리 산 341', 37.708702, 128.7984639],
#  [266,
#   '보광가족관광농원',
#   '관광농원',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 보현길 151-1',
#   37.7382356,
#   128.7912905],
#  [267, '강릉남대천', '하천', 0.0, '2', '강원 강릉시 성산면 구산리', 37.7193495, 128.8287811],
#  [268, '강릉남대천', '하천', 0.0, '1', '강원 강릉시 입암동', 37.7553367, 128.9152179],
#  [269,
#   '땅재봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 유천동 산 207',
#   37.76394030000001,
#   128.863257],
#  [270, '춘갑봉', '산봉우리', 0.0, '0', '강원 강릉시 포남동', 37.774855200000005, 128.9078407],
#  [271, '담정계곡', '계곡', 0.0, '0', '강원 강릉시 강동면 언별리', 37.6645164, 128.9241222],
#  [272, '낙풍천', '하천', 0.0, '1', '강원 강릉시 옥계면 낙풍리', 37.6247828, 129.0127625],
#  [273,
#   '매봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 신왕리 산 1',
#   37.792700399999994,
#   128.7474389],
#  [274,
#   '피래산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 임곡리 산 194',
#   37.65292609999999,
#   128.97330159999999],
#  [275,
#   '장덕고개',
#   '고개',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 장덕리',
#   37.873587799999996,
#   128.7797776],
#  [276,
#   '합궁골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 금진리 산 6',
#   37.657684100000004,
#   129.0536707],
#  [277,
#   '등명락가사 등명사지오층석탑',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 565',
#   37.689200799999995,
#   129.0243271],
#  [278,
#   '명주최보영가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 작은다리길 16',
#   37.8904559,
#   128.8261249],
#  [279,
#   '노추산로',
#   '드라이브코스',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 2929-5',
#   37.57821989999999,
#   128.7490804],
#  [280,
#   '소금강산',
#   '산',
#   5.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 333',
#   37.83994939999999,
#   128.6566871],
#  [281,
#   '올림픽아리바우길 4코스',
#   '도보여행',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [282, '초막골', '계곡', 0.0, '0', '강원 강릉시 성산면 어흘리', 37.7107204, 128.7795353],
#  [283,
#   '영진리고분군',
#   '릉,묘,총',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 영진리 산 40',
#   37.86510579999999,
#   128.8464844],
#  [284,
#   '강릉대도호부 아문',
#   '문',
#   0.0,
#   '0',
#   '강원 강릉시 성내동 27-1',
#   37.752491299999996,
#   128.8922665],
#  [285,
#   '주문진리조트 퍼팅장',
#   '호수',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 향호리 8-57',
#   37.9121357,
#   128.8173057],
#  [286,
#   '강릉선교장 열화당',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 운정길 63',
#   37.7865935,
#   128.8851277],
#  [287,
#   '최대석가옥',
#   '유적지',
#   0.0,
#   '0',
#   '강원 강릉시 모산로224번길 55-12',
#   37.73248239999999,
#   128.90607690000002],
#  [288,
#   '옥계굴',
#   '동굴',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 산 428',
#   37.5789,
#   128.94787250000002],
#  [289,
#   '궁궁동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 삼교리',
#   37.8860651,
#   128.72118079999998],
#  [290, '강릉남대천', '하천', 0.0, '1', '강원 강릉시 구정면 제비리', 37.7203412, 128.8525517],
#  [291, '오리바위', '바위', 4.5, '0', '강원 강릉시 안현동', 37.801911100000005, 128.8758249],
#  [292,
#   '정동진천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [293, '시루봉', '산봉우리', 0.0, '1', '강원 강릉시 난곡동 산 5', 37.7940612, 128.8845196],
#  [294,
#   '6.25 남침사적탑',
#   '탑,비석',
#   0.0,
#   '1',
#   '강원 강릉시 강동면 정동진리 524-14',
#   37.7079586,
#   129.012171],
#  [295, '경포로', '드라이브코스', 0.0, '0', '강원 강릉시 운정동', 37.7880229, 128.8952955],
#  [296,
#   '비선굴',
#   '동굴',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 산 415',
#   37.5789,
#   128.94787250000002],
#  [297,
#   '석병산 샘터',
#   '샘터,약수터',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리',
#   37.5789,
#   128.94787250000002],
#  [298,
#   '고성산',
#   '산',
#   5.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 267-4',
#   37.689200799999995,
#   129.0243271],
#  [299, '강릉수리골고택', '생가,고택', 0.0, '1', '강원 강릉시 운정길 123', 37.786017, 128.8910834],
#  [300, '갯골', '계곡', 0.0, '0', '강원 강릉시 주문진읍 향호리', 37.8996511, 128.7843327],
#  [301, '주수천', '하천', 0.0, '0', '강원 강릉시 옥계면 조산리', 37.6230244, 129.052086],
#  [302,
#   '강릉보광리 석조여래좌상',
#   '불상,석불',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 삼왕길 139-98',
#   37.75216339999999,
#   128.78593850000001],
#  [303,
#   '당두공원길',
#   '도보여행',
#   0.0,
#   '0',
#   '강원 강릉시 교동 산 132-1',
#   37.76772709999999,
#   128.896816],
#  [304,
#   '태장봉',
#   '산봉우리',
#   0.0,
#   '1',
#   '강원 강릉시 대전동 산 41-3',
#   37.795079799999996,
#   128.857649],
#  [305,
#   '바우길부대담장길',
#   '도보여행',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 참샘길 38',
#   37.91364069999999,
#   128.80619879999998],
#  [306,
#   '삼폭포',
#   '폭포',
#   4.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 1-12',
#   37.83994939999999,
#   128.6566871],
#  [308,
#   '유니온관광 정동진역',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 329-1',
#   37.689512,
#   129.03202620000002],
#  [309, '오죽헌지', '저수지', 0.0, '0', '강원 강릉시 운정동', 37.7880229, 128.8952955],
#  [310,
#   '옥녀봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 남양리',
#   37.561585799999996,
#   129.00788290000003],
#  [311, '애골', '계곡', 0.0, '0', '강원 강릉시 주문진읍 교항리', 37.8789811, 128.8177091],
#  [312, '납들', '계곡', 0.0, '0', '강원 강릉시 신석동', 37.7312956, 128.9242578],
#  [314,
#   '산계소류지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리',
#   37.5789,
#   128.94787250000002],
#  [315, '활래정', '생가,고택', 3.0, '0', '강원 강릉시 운정길 107-22', 37.786497, 128.8879001],
#  [316,
#   '옹기백화점',
#   '도자기,도예촌',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로 3049',
#   37.7739052,
#   128.8885134],
#  [317,
#   '낙영폭포',
#   '폭포',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 1-12',
#   37.83994939999999,
#   128.6566871],
#  [318, '교동', '계곡', 0.0, '0', '강원 강릉시 옥계면 현내리', 37.6089752, 129.0291988],
#  [319, '안고단', '계곡', 0.0, '0', '강원 강릉시 왕산면 고단리', 37.5327984, 128.8232836],
#  [320,
#   '강릉대공산성',
#   '산성,성곽',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 보광리 산 544',
#   37.7369414,
#   128.7691585],
#  [321, '강골', '계곡', 0.0, '0', '강원 강릉시 안현동', 37.801911100000005, 128.8758249],
#  [322,
#   '계련당',
#   '유적지',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로 2920-12',
#   37.7633184,
#   128.89314679999998],
#  [323,
#   '강릉최씨동원군종택',
#   '생가,고택',
#   0.0,
#   '1',
#   '강원 강릉시 주문진읍 신리천로 192-3',
#   37.8787049,
#   128.81124340000002],
#  [324, '대포동', '계곡', 0.0, '0', '강원 강릉시 강동면 안인진리', 37.728188, 128.9866112],
#  [325,
#   '삼산리소나무',
#   '문화유적',
#   1.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 116',
#   37.827806,
#   128.6553172],
#  [326, '대궁산', '산', 0.0, '1', '강원 강릉시 사천면 사기막리 산 1', 37.7667604, 128.7500686],
#  [327,
#   '까치골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [328,
#   '죽도봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 강문동',
#   37.789733899999995,
#   128.92000009999998],
#  [329, '문묘 대성전', '향교,서당', 0.0, '0', '강원 강릉시 명륜로 29', 37.7634, 128.895101],
#  [330, '질골', '계곡', 0.0, '0', '강원 강릉시 사천면 방동리', 37.82181, 128.86641029999998],
#  [331, '임영고개', '고개', 0.0, '0', '강원 강릉시 교동', 37.7670917, 128.88662490000002],
#  [332, '경양사', '사당,제단', 0.0, '0', '강원 강릉시 저동길 113', 37.7961797, 128.8903459],
#  [333,
#   '쌍한정',
#   '관광,명소',
#   0.0,
#   '2',
#   '강원 강릉시 사천면 해안로 918',
#   37.8321683,
#   128.8751217],
#  [334, '뒷섬', '섬(내륙)', 2.0, '0', '강원 강릉시 사천면 사천진리', 37.8435195, 128.8684982],
#  [335,
#   '왕산천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 왕산리',
#   37.651880600000005,
#   128.7800211],
#  [336,
#   '강릉수문리당간지주',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 옥천동 43-9',
#   37.75644260000001,
#   128.90380770000002],
#  [337, '모학당', '생가,고택', 0.0, '0', '강원 강릉시 모산로 170-52', 37.7264305, 128.9039352],
#  [338,
#   '굴산사지 승탑',
#   '탑,비석',
#   0.0,
#   '2',
#   '강원 강릉시 구정면 금평로 118-32',
#   37.707634999999996,
#   128.88687109999998],
#  [339, '연곡천', '하천', 0.0, '0', '강원 강릉시 연곡면 퇴곡리', 37.854748, 128.7321447],
#  [340,
#   '바우길183고지',
#   '도보여행',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 산 103-1',
#   37.687172499999996,
#   129.0376985],
#  [341, '새목재', '고개', 0.0, '0', '강원 강릉시 왕산면 고단리', 37.5327984, 128.8232836],
#  [342,
#   '매봉산',
#   '산',
#   0.0,
#   '0',
#   '강원 동해시 비천동 산 41',
#   37.544546999999994,
#   129.029092],
#  [343,
#   '동주최씨제실',
#   '사당,제단',
#   0.0,
#   '0',
#   '강원 강릉시 성덕로176번길 6',
#   37.7615746,
#   128.9342113],
#  [344,
#   '망덕봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 언별리 산 274-1',
#   37.6657836,
#   128.9188331],
#  [345,
#   '보광리분청자요지',
#   '유적지',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 보광리 711-2',
#   37.765897700000004,
#   128.7909189],
#  [346, '강릉남대천', '하천', 0.0, '1', '강원 강릉시 회산동', 37.73815, 128.863319],
#  [347,
#   '함대식가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 위촌길 216-3',
#   37.7599486,
#   128.84525520000003],
#  [348,
#   '장천마을휴양지',
#   '관광,명소',
#   1.0,
#   '2',
#   '강원 강릉시 연곡면 진고개로 1502',
#   37.8465424,
#   128.7045957],
#  [349, '큰골', '계곡', 0.0, '0', '강원 강릉시 왕산면 도마리', 37.6597088, 128.83178059999997],
#  [350,
#   '하슬라아트월드 소나무정원',
#   '테마파크시설',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 율곡로 1441',
#   37.7056021,
#   129.0080007],
#  [351,
#   '삿갓봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 북동리 산 525-2',
#   37.601535,
#   128.9511971],
#  [352,
#   '박치규가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 미노리 111',
#   37.83032539999999,
#   128.86652560000002],
#  [353,
#   '삼우봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 산 17',
#   37.711249200000005,
#   129.0063317],
#  [354, '강릉남대천', '하천', 0.0, '1', '강원 강릉시 내곡동', 37.7390776, 128.8808633],
#  [355,
#   '덕우리재',
#   '고개',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 북동리',
#   37.6226354,
#   128.96262190000002],
#  [356, '탑동', '계곡', 0.0, '0', '강원 강릉시 왕산면 도마리', 37.6597088, 128.83178059999997],
#  [357,
#   '터미널관광안내소',
#   '관광안내소',
#   0.0,
#   '0',
#   '강원 강릉시 하슬라로 27',
#   37.7546716,
#   128.878003],
#  [358,
#   '밥봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 천남리 산 76',
#   37.599574100000005,
#   129.0517793],
#  [359,
#   '강릉시호고택',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 시동길 91-9',
#   37.73483710000001,
#   128.95777379999998],
#  [360, '절골', '계곡', 0.0, '0', '강원 강릉시 구정면 제비리', 37.7203412, 128.8525517],
#  [361,
#   '모래시계 관광안내소',
#   '관광안내소',
#   0.0,
#   '1',
#   '강원 강릉시 강동면 정동진리 7-1',
#   37.689512,
#   129.03202620000002],
#  [362,
#   '강릉이광노가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 난설헌로193번길 1-16',
#   37.7919383,
#   128.9092743],
#  [363,
#   '강릉김재성가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 지변길 175-12',
#   37.777260999999996,
#   128.8723014],
#  [364,
#   '장작골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 모전리',
#   37.71053029999999,
#   128.9755973],
#  [365,
#   '석두봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 산 1-1',
#   37.57821989999999,
#   128.7490804],
#  [366,
#   '한송사지석불좌상',
#   '불상,석불',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [367, '십리바위', '바위', 5.0, '1', '강원 강릉시 안현동', 37.801911100000005, 128.8758249],
#  [368,
#   '대기천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [369,
#   '강릉오금집',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 강릉대로210번길 23-9',
#   37.7562985,
#   128.89398500000001],
#  [370, '경포천', '하천', 0.0, '0', '강원 강릉시 대전동', 37.79388970000001, 128.8550747],
#  [371,
#   '피덕령',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [372,
#   '서대굴',
#   '동굴',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 산 428',
#   37.5789,
#   128.94787250000002],
#  [373,
#   '안현천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 산대월리',
#   37.8140851,
#   128.87542520000002],
#  [374,
#   '청학산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 산성우리 산 273',
#   37.6845435,
#   128.98680259999998],
#  [375,
#   '모정탑길',
#   '도보여행',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [376, '벌말', '계곡', 0.0, '0', '강원 강릉시 왕산면 대기리', 37.57821989999999, 128.7490804],
#  [377,
#   '왕고개',
#   '고개',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 여찬리',
#   37.7209372,
#   128.87483319999998],
#  [378,
#   '강릉역 관광통역안내센터',
#   '관광안내소',
#   0.0,
#   '0',
#   '강원 강릉시 용지로 176',
#   37.763599600000006,
#   128.8989373],
#  [379,
#   '방아다리골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 판교리',
#   37.839308700000004,
#   128.854862],
#  [380,
#   '석병산 서당바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리',
#   37.5789,
#   128.94787250000002],
#  [381,
#   '석화동굴',
#   '동굴',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 산 428',
#   37.5789,
#   128.94787250000002],
#  [382,
#   '남양천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 천남리',
#   37.601915399999996,
#   129.0410603],
#  [383, '동대굴', '동굴', 0.0, '0', '강원 강릉시 옥계면 산계리 산 257', 37.5819309, 128.9464449],
#  [384, '보진당', '유적지', 0.0, '0', '강원 강릉시 은행나무길 9', 37.7551713, 128.8987343],
#  [385,
#   '사달산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 산 3',
#   37.570945200000004,
#   128.7406375],
#  [386,
#   '고려성',
#   '산성,성곽',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 508-1',
#   37.685305299999996,
#   129.0375618],
#  [387,
#   '삼한성지',
#   '산성,성곽',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 산성우리 산 229-1',
#   37.678010799999996,
#   129.01956909999998],
#  [388,
#   '명주김득래가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 왕고개길 66-15',
#   37.7204093,
#   128.88561570000002],
#  [389, '청량골', '계곡', 0.0, '0', '강원 강릉시 청량동', 37.74485620000001, 128.9257744],
#  [390,
#   '칠성골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 어단리',
#   37.6785816,
#   128.89343689999998],
#  [391,
#   '해수박골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 삼교리',
#   37.8860651,
#   128.72118079999998],
#  [392,
#   '취영정',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 강문동 269',
#   37.7974566,
#   128.91374979999998],
#  [393,
#   '오성정',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 강변로 224-12',
#   37.747301799999995,
#   128.89339679999998],
#  [394,
#   '뱀골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 유등리',
#   37.819581799999995,
#   128.7454661],
#  [395, '큰가마골', '계곡', 0.0, '0', '강원 강릉시 성산면 어흘리', 37.7107204, 128.7795353],
#  [396,
#   '증산소류지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 남양리',
#   37.561585799999996,
#   129.00788290000003],
#  [397, '경포골', '계곡', 0.0, '0', '강원 강릉시 저동', 37.7981294, 128.8925034],
#  [398, '갓바위골', '계곡', 0.0, '0', '강원 강릉시 성산면 보광리', 37.74729, 128.78251880000002],
#  [399, '작은골길', '계곡', 0.0, '0', '강원 강릉시 옥계면 도직리', 37.605498, 129.0626627],
#  [400, '지암골', '계곡', 0.0, '0', '강원 강릉시 성산면 송암리', 37.7762297, 128.8309174],
#  [401,
#   '향현사',
#   '사당,제단',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로 2920-16',
#   37.7634402,
#   128.8937134],
#  [402, '금광천', '하천', 0.0, '0', '강원 강릉시 박월동', 37.728406400000004, 128.9108081],
#  [403,
#   '남대굴',
#   '동굴',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 1170',
#   37.5789,
#   128.94787250000002],
#  [405,
#   '대화실산',
#   '산',
#   0.0,
#   '1',
#   '강원 강릉시 왕산면 대기리 산 1-12',
#   37.57821989999999,
#   128.7490804],
#  [406,
#   '높은다리골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 보광리',
#   37.74729,
#   128.78251880000002],
#  [408,
#   '고곡동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 관음리',
#   37.74101539999999,
#   128.82543020000003],
#  [409,
#   '황산골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 왕산리',
#   37.651880600000005,
#   128.7800211],
#  [410, '임곡천', '하천', 0.0, '0', '강원 강릉시 강동면 임곡리', 37.6641691, 128.9612013],
#  [411,
#   '도마천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 목계리',
#   37.625665999999995,
#   128.8625156],
#  [412, '군선천', '하천', 0.0, '0', '강원 강릉시 강동면 언별리', 37.6645164, 128.9241222],
#  [414,
#   '별빛여행펜션',
#   '펜션',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 들꽃마을길 18',
#   37.6499273,
#   128.8558331],
#  [415, '우경골', '계곡', 0.0, '0', '강원 강릉시 입암동', 37.7553367, 128.9152179],
#  [416,
#   '절골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 천남리',
#   37.601915399999996,
#   129.0410603],
#  [417, '바두재', '고개', 0.0, '0', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [418, '보리골', '계곡', 0.0, '0', '강원 강릉시 주문진읍 교항리', 37.8789811, 128.8177091],
#  [419,
#   '나리골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [420, '강릉시', '계곡', 0.0, '0', '강원 강릉시 주문진읍 향호리', 37.8996511, 128.7843327],
#  [421, '쟁골저수지', '저수지', 0.0, '0', '강원 강릉시 강동면 상시동리', 37.7209898, 128.9481805],
#  [422, '경포천', '하천', 0.0, '0', '강원 강릉시 성산면 송암리', 37.7762297, 128.8309174],
#  [423,
#   '망운산',
#   '산',
#   5.0,
#   '1',
#   '강원 강릉시 옥계면 남양리 산 795-1',
#   37.585021399999995,
#   129.05583059999998],
#  [424,
#   '김남명가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 하시동리 36',
#   37.747057500000004,
#   128.9574559],
#  [425, '몽탕골', '계곡', 0.0, '0', '강원 강릉시 옥계면 낙풍리', 37.6247828, 129.0127625],
#  [426,
#   '숭덕재',
#   '릉,묘,총',
#   0.0,
#   '0',
#   '강원 강릉시 동해대로 699-25',
#   37.800638799999994,
#   128.8601456],
#  [427, '싸래골', '계곡', 0.0, '0', '강원 강릉시 주문진읍 주문리', 37.8990315, 128.8227808],
#  [428, '위촌저류지', '저수지', 0.0, '1', '강원 강릉시 죽헌동', 37.7813425, 128.8562267],
#  [429,
#   '신사임당초서병풍',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [430, '할미집골', '계곡', 0.0, '0', '강원 강릉시 왕산면 고단리', 37.5327984, 128.8232836],
#  [431, '진골', '계곡', 0.0, '0', '강원 강릉시 구정면 제비리', 37.7203412, 128.8525517],
#  [432,
#   '버금골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 장덕리',
#   37.873587799999996,
#   128.7797776],
#  [433,
#   '대공산성',
#   '산성,성곽',
#   0.0,
#   '1',
#   '강원 강릉시 성산면 보광리 산 544',
#   37.7369414,
#   128.7691585],
#  [434, '서당골', '계곡', 0.0, '0', '강원 강릉시 성산면 보광리', 37.74729, 128.78251880000002],
#  [435,
#   '눈물바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 학산리',
#   37.708818799999996,
#   128.890621],
#  [436, '넙은골', '계곡', 0.0, '0', '강원 강릉시 회산동', 37.73815, 128.863319],
#  [437,
#   '창랑정',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 강문동 258-14',
#   37.803507700000004,
#   128.9086246],
#  [438,
#   '오봉저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 오봉리',
#   37.706627399999995,
#   128.8142664],
#  [439, '작은도추골', '계곡', 0.0, '0', '강원 강릉시 운산동', 37.7262976, 128.93377949999999],
#  [440,
#   '덕실골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 덕실리',
#   37.805178399999996,
#   128.8410131],
#  [441,
#   '용금정',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 어단리 1141',
#   37.7027596,
#   128.9102761],
#  [442, '옥녀봉', '산봉우리', 0.0, '0', '강원 평창군 대관령면 수하리', 37.6196502, 128.7042174],
#  [443,
#   '노추산등산코스',
#   '등산로',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 산 3',
#   37.570945200000004,
#   128.7406375],
#  [444, '동대산 샘터', '샘터,약수터', 0.0, '0', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [445,
#   '산계리금옥계방 역사적비및종선비',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 787',
#   37.5789,
#   128.94787250000002],
#  [446, '서리바웃골', '계곡', 0.0, '0', '강원 강릉시 대전동', 37.79388970000001, 128.8550747],
#  [447,
#   '새끼뫼',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 여찬리',
#   37.7209372,
#   128.87483319999998],
#  [448, '갈보데이', '계곡', 0.0, '0', '강원 강릉시 강동면 임곡리', 37.6641691, 128.9612013],
#  [449, '돼지밭골', '계곡', 0.0, '0', '강원 강릉시 성산면 어흘리', 37.7107204, 128.7795353],
#  [450, '음달말골', '계곡', 0.0, '0', '강원 강릉시 성산면 산북리', 37.7030827, 128.8381761],
#  [451, '경포천', '하천', 0.0, '0', '강원 강릉시 운정동', 37.7880229, 128.8952955],
#  [452, '노양골', '계곡', 0.0, '0', '강원 강릉시 옥계면 금진리', 37.6432124, 129.0367071],
#  [453, '소토골', '계곡', 0.0, '0', '강원 강릉시 대전동', 37.79388970000001, 128.8550747],
#  [454,
#   '방내리삼층석탑',
#   '탑,비석',
#   3.0,
#   '0',
#   '강원 강릉시 연곡면 향교말길 22',
#   37.8576074,
#   128.8255764],
#  [455,
#   '대양산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 산 72',
#   37.687172499999996,
#   129.0376985],
#  [456,
#   '매봉산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 송현리 산 242-1',
#   37.5769162,
#   128.8441635],
#  [457, '금란정', '문화유적', 0.0, '0', '강원 강릉시 경포로371번길 57', 37.7995585, 128.8993593],
#  [458,
#   '생쥐골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 송림리',
#   37.8521881,
#   128.81237099999998],
#  [459,
#   '강릉선교장 안채주옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 운정길 63',
#   37.7865935,
#   128.8851277],
#  [460,
#   '장기바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 목계리',
#   37.625665999999995,
#   128.8625156],
#  [461, '사화산', '산', 0.0, '0', '강원 강릉시 사천면 판교리 561-1', 37.8402891, 128.8495217],
#  [462, '자조와리', '계곡', 0.0, '0', '강원 강릉시 내곡동', 37.7390776, 128.8808633],
#  [463,
#   '태봉산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 모전리 산 259',
#   37.718545500000005,
#   128.96422900000002],
#  [464,
#   '전충사',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 저동길100번길 56-10',
#   37.7944081,
#   128.89477779999999],
#  [465, '속동산', '산', 0.0, '0', '강원 강릉시 강동면 심곡리 1-78', 37.6672988, 129.0416628],
#  [466, '장적골', '계곡', 0.0, '0', '강원 강릉시 강동면 언별리', 37.6645164, 128.9241222],
#  [467, '절골', '계곡', 0.0, '0', '강원 강릉시 연곡면 송림리', 37.8521881, 128.81237099999998],
#  [468, '구래골', '계곡', 5.0, '0', '강원 강릉시 사천면 노동리', 37.8158224, 128.8147526],
#  [469, '괴병산', '산', 0.0, '0', '강원 강릉시 왕산면 대기리 1719-1', 37.5881597, 128.7783093],
#  [470,
#   '둔치마을',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 도마리',
#   37.6597088,
#   128.83178059999997],
#  [471,
#   '매봉산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 어단리 산 362',
#   37.666918200000005,
#   128.8867933],
#  [472,
#   '동산리',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 천남리',
#   37.601915399999996,
#   129.0410603],
#  [473,
#   '송이골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 삼교리',
#   37.8860651,
#   128.72118079999998],
#  [474, '여우골', '계곡', 0.0, '0', '강원 강릉시 주문진읍 향호리', 37.8996511, 128.7843327],
#  [475,
#   '나팔재산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 남양리 산 324-1',
#   37.5450468,
#   128.99559250000001],
#  [476, '산두골', '계곡', 0.0, '0', '강원 강릉시 성산면 산북리', 37.7030827, 128.8381761],
#  [477,
#   '허균허난설헌공원 오문장비',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 초당동 474-9',
#   37.7912213,
#   128.9092382],
#  [478,
#   '개매리골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 산성우리',
#   37.66371229999999,
#   129.0034209],
#  [479,
#   '최근배가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로 2669-6',
#   37.7466845,
#   128.9107185],
#  [480, '안고개', '고개', 0.0, '0', '강원 강릉시 안현동', 37.801911100000005, 128.8758249],
#  [481, '한밭골', '계곡', 0.0, '0', '강원 강릉시 대전동', 37.79388970000001, 128.8550747],
#  [482, '큰골', '계곡', 0.0, '0', '강원 강릉시 연곡면 행정리', 37.8565524, 128.77651070000002],
#  [483,
#   '정의윤가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 범일로 283-7',
#   37.715477,
#   128.88706770000002],
#  [484, '이리재', '고개', 0.0, '0', '강원 강릉시 성산면 송암리 20-2', 37.7721411, 128.8416141],
#  [485, '강릉향교 사료관', '향교,서당', 0.0, '0', '강원 강릉시 명륜로 29', 37.7634, 128.895101],
#  [486,
#   '못골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 산대월리',
#   37.8140851,
#   128.87542520000002],
#  [487,
#   '옥녀봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 산 2-1',
#   37.5881597,
#   128.7783093],
#  [488, '시목골', '계곡', 0.0, '0', '강원 강릉시 유천동', 37.767111299999996, 128.8586435],
#  [489,
#   '이이수필격몽요결',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로3139번길 24 오죽헌시립박물관',
#   37.7780704,
#   128.878503],
#  [490, '절터미골', '계곡', 0.0, '0', '강원 강릉시 구정면 제비리', 37.7203412, 128.8525517],
#  [491,
#   '강릉조광현가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 교항리 863-2',
#   37.8815824,
#   128.81741019999998],
#  [492,
#   '성산봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 산북리 산 4',
#   37.7154955,
#   128.83658459999998],
#  [493, '절골', '계곡', 0.0, '0', '강원 강릉시 왕산면 도마리', 37.6597088, 128.83178059999997],
#  [494, '굴면동', '계곡', 0.0, '0', '강원 강릉시 성산면 어흘리', 37.7107204, 128.7795353],
#  [495, '아랫낙풍', '계곡', 0.0, '0', '강원 강릉시 옥계면 낙풍리', 37.6247828, 129.0127625],
#  [496, '애지골', '계곡', 0.0, '0', '강원 강릉시 입암동', 37.7553367, 128.9152179],
#  [497, '덕우봉', '산봉우리', 0.0, '0', '강원 강릉시 담산동 산 4', 37.7268387, 128.9047547],
#  [498,
#   '이울골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 덕실리',
#   37.805178399999996,
#   128.8410131],
#  [499,
#   '아래숯터',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [500, '어심밭골', '계곡', 0.0, '0', '강원 강릉시 구정면 구정리', 37.6879535, 128.8653185],
#  [501,
#   '테라로사 커피공장',
#   '커피전문점',
#   3.5,
#   '871',
#   '강원 강릉시 구정면 현천길 7',
#   37.6960049,
#   128.89188719999999],
#  [502,
#   '엄지네포장마차 본점',
#   '실내포장마차',
#   3.8,
#   '1,597',
#   '강원 강릉시 경강로2255번길 21 엄지빌딩 1층',
#   37.7663374,
#   128.9069912],
#  [503,
#   '곳',
#   '디저트카페',
#   3.6,
#   '443',
#   '강원 강릉시 사천면 진리해변길 143 1~3층',
#   37.839526299999996,
#   128.87401770000002],
#  [504,
#   '테라로사 경포호수점',
#   '커피전문점',
#   3.2,
#   '438',
#   '강원 강릉시 난설헌로 145',
#   37.7868489,
#   128.9060121],
#  [505,
#   '순두부젤라또 1호점',
#   '아이스크림',
#   3.5,
#   '854',
#   '강원 강릉시 초당순두부길 95-5',
#   37.791711299999996,
#   128.9154298],
#  [506,
#   '강릉빵다방 본점',
#   '제과,베이커리',
#   3.4,
#   '445',
#   '강원 강릉시 남강초교1길 24',
#   37.768988799999995,
#   128.9180848],
#  [507,
#   '순두부젤라또 2호점',
#   '아이스크림',
#   3.3,
#   '760',
#   '강원 강릉시 경강로 2642 1~4층',
#   37.77128270000001,
#   128.9471337],
#  [508, '벌집', '국수', 3.2, '377', '강원 강릉시 경강로2069번길 15', 37.7545049, 128.892756],
#  [509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [510,
#   '만동제과',
#   '제과,베이커리',
#   4.7,
#   '260',
#   '강원 강릉시 금성로 6',
#   37.755143200000006,
#   128.89946709999998],
#  [511,
#   '보헤미안박이추커피공장',
#   '커피전문점',
#   3.2,
#   '315',
#   '강원 강릉시 사천면 해안로 1107',
#   37.846880999999996,
#   128.86682040000002],
#  [512,
#   '원조강릉교동반점 본점',
#   '중화요리',
#   3.2,
#   '450',
#   '강원 강릉시 강릉대로 205',
#   37.758351,
#   128.89304280000002],
#  [513,
#   '돌체테리아',
#   '카페',
#   2.2,
#   '253',
#   '강원 강릉시 하슬라로206번길 4-3 1층',
#   37.7676881,
#   128.8761274],
#  [514,
#   '버드나무브루어리',
#   '호프,요리주점',
#   4.0,
#   '304',
#   '강원 강릉시 경강로 1961',
#   37.74822959999999,
#   128.88435959999998],
#  [515,
#   '풍년갈비',
#   '육류,고기',
#   3.7,
#   '1,758',
#   '강원 강릉시 강릉대로587번길 10-5',
#   37.7844299,
#   128.91952120000002],
#  [516,
#   '차현희순두부청국장',
#   '두부전문점',
#   3.4,
#   '367',
#   '강원 강릉시 초당순두부길 96',
#   37.790931799999996,
#   128.9161378],
#  [517,
#   '현대장칼국수',
#   '국수',
#   3.3,
#   '351',
#   '강원 강릉시 임영로182번길 7-1',
#   37.75746029999999,
#   128.8926371],
#  [518,
#   '초당할머니순두부',
#   '두부전문점',
#   2.9,
#   '390',
#   '강원 강릉시 초당순두부길 77',
#   37.7909005,
#   128.9149108],
#  [519,
#   '독도네꼬막 본점',
#   '조개',
#   4.6,
#   '586',
#   '강원 강릉시 옥천로 47 1층',
#   37.759226899999994,
#   128.9004925],
#  [520,
#   '해미가',
#   '회',
#   4.1,
#   '314',
#   '강원 강릉시 솔올로 103',
#   37.7710365,
#   128.87888999999998],
#  [521,
#   '테라로사 사천점',
#   '커피전문점',
#   3.5,
#   '208',
#   '강원 강릉시 사천면 순포안길 6 1, 2층',
#   37.8224255,
#   128.88480800000002],
#  [522,
#   '팔도전복해물뚝배기',
#   '해물,생선',
#   4.6,
#   '342',
#   '강원 강릉시 창해로 375',
#   37.7959574,
#   128.9162884],
#  [523,
#   '테라로사 경포대점',
#   '카페',
#   2.4,
#   '30',
#   '강원 강릉시 창해로 419',
#   37.7989517,
#   128.91428259999998],
#  [524,
#   '삼교리동치미막국수 본점',
#   '국수',
#   3.8,
#   '176',
#   '강원 강릉시 구정면 범일로 364',
#   37.716294,
#   128.8967289],
#  [525,
#   '금학칼국수',
#   '국수',
#   3.0,
#   '263',
#   '강원 강릉시 대학길 12-6',
#   37.75441970000001,
#   128.8962638],
#  [526,
#   '소나무집초당순두부',
#   '두부전문점',
#   2.6,
#   '668',
#   '강원 강릉시 초당순두부길 95-5',
#   37.791711299999996,
#   128.9154298],
#  [527,
#   '동해막국수',
#   '국수',
#   3.6,
#   '103',
#   '강원 강릉시 연곡면 성안길 47-3',
#   37.8592565,
#   128.8314326],
#  [528,
#   '강릉수제버거',
#   '햄버거',
#   4.2,
#   '538',
#   '강원 강릉시 주문진읍 주문북로 222-30 1층',
#   37.91135209999999,
#   128.8176985],
#  [529,
#   '폴&메리 강문점',
#   '햄버거',
#   2.6,
#   '432',
#   '강원 강릉시 창해로350번길 33',
#   37.7967264,
#   128.9168123],
#  [530, '퍼베이드', '카페', 3.8, '320', '강원 강릉시 화부산로 78', 37.7631986, 128.8868236],
#  [531,
#   '강릉중화짬뽕빵',
#   '제과,베이커리',
#   3.2,
#   '540',
#   '강원 강릉시 금성로13번길 17',
#   37.753244200000005,
#   128.90012040000002],
#  [532,
#   '오월',
#   '카페',
#   3.6,
#   '379',
#   '강원 강릉시 경강로2046번길 11-2',
#   37.7507555,
#   128.8931455],
#  [533,
#   '장안회집',
#   '회',
#   3.4,
#   '152',
#   '강원 강릉시 사천면 진리항구길 51',
#   37.8376125,
#   128.8753303],
#  [534,
#   '형제칼국수',
#   '국수',
#   2.8,
#   '319',
#   '강원 강릉시 강릉대로204번길 2',
#   37.7578827,
#   128.89300649999998],
#  [535,
#   '보사노바 강릉본점',
#   '카페',
#   3.8,
#   '266',
#   '강원 강릉시 창해로14번길 28',
#   37.772169700000006,
#   128.94774089999999],
#  [536,
#   '만석닭강정 안목직영점',
#   '닭강정',
#   3.8,
#   '110',
#   '강원 강릉시 창해로2번길 32 2층',
#   37.7713378,
#   128.94855320000002],
#  [537,
#   '이모네생선찜',
#   '해물,생선',
#   3.1,
#   '131',
#   '강원 강릉시 가작로 8',
#   37.76916629999999,
#   128.87642639999999],
#  [538,
#   '커피바다',
#   '카페',
#   4.3,
#   '125',
#   '강원 강릉시 주문진읍 해안로 1822 2층',
#   37.8944925,
#   128.8339037],
#  [539,
#   '삼교리동치미막국수 강릉남항진점',
#   '국수',
#   4.0,
#   '217',
#   '강원 강릉시 공항길127번길 42',
#   37.7655969,
#   128.952542],
#  [540,
#   '김우정 초당짬뽕순두부',
#   '두부전문점',
#   2.1,
#   '376',
#   '강원 강릉시 초당순두부길 114',
#   37.79251199999999,
#   128.9172098],
#  [541,
#   '대영유통',
#   '게,대게',
#   3.8,
#   '938',
#   '강원 강릉시 주문진읍 해안로 1767',
#   37.892841499999996,
#   128.82872340000003],
#  [542,
#   '건도리횟집',
#   '회',
#   3.0,
#   '122',
#   '강원 강릉시 창해로 427',
#   37.799471000000004,
#   128.9136565],
#  [543,
#   '금천칼국수',
#   '국수',
#   3.6,
#   '140',
#   '강원 강릉시 강릉대로 445-1',
#   37.773269799999994,
#   128.9121206],
#  [544,
#   '최대게',
#   '게,대게',
#   3.6,
#   '481',
#   '강원 강릉시 주문진읍 해안로 1729',
#   37.8894492,
#   128.8280805],
#  [545,
#   '카페 뤼미에르',
# ...
#  [876, '진영두부마을', '두부전문점', 5.0, '10', '강원 강릉시 옥가로 20', 37.7579816, 128.8994424],
#  [877,
#   '실비생선구이 2호점',
#   '해물,생선',
#   4.0,
#   '152',
#   '강원 강릉시 주문진읍 해안로 1723',
#   37.88884609999999,
#   128.8281374],
#  [878,
#   '젠주',
#   '카페',
#   3.6,
#   '73',
#   '강원 강릉시 창해로14번길 16 6층',
#   37.772920299999996,
#   128.94684009999997],
#  [879,
#   '통일집불고기',
#   '육류,고기',
#   3.0,
#   '10',
#   '강원 강릉시 금성로61번길 11-1',
#   37.751171,
#   128.8959784],
#  [880,
#   '위촌리전통한우',
#   '육류,고기',
#   4.0,
#   '20',
#   '강원 강릉시 성산면 소목길 203-10',
#   37.753553600000004,
#   128.84733400000002],
#  [881, '메밀촌', '국수', 3.8, '18', '강원 강릉시 창해로 33', 37.7745874, 128.9436671],
#  [882,
#   '강릉대학사식당',
#   '한식',
#   3.9,
#   '25',
#   '강원 강릉시 지변길 10',
#   37.7734211,
#   128.87372620000002],
#  [883, '카페살림', '카페', 3.9, '47', '강원 강릉시 홍제로 63', 37.7533314, 128.8848039],
#  [884,
#   '더바베큐 포남점',
#   '육류,고기',
#   4.6,
#   '26',
#   '강원 강릉시 하평1길 6',
#   37.7707287,
#   128.9114594],
#  [885,
#   '장군시오야끼 포남점',
#   '불고기,두루치기',
#   4.0,
#   '82',
#   '강원 강릉시 하평길 20',
#   37.77009210000001,
#   128.9108148],
#  [886,
#   '어국',
#   '회',
#   2.4,
#   '29',
#   '강원 강릉시 강동면 정동진리 50-153',
#   37.683463399999994,
#   129.0438501],
#  [887, '포지타노', '이탈리안', 5.0, '22', '강원 강릉시 입암로91번길 47', 37.756005, 128.9110234],
#  [888,
#   '라티엔다',
#   '뷔페',
#   2.3,
#   '77',
#   '강원 강릉시 난곡길 219',
#   37.80188649999999,
#   128.87449750000002],
#  [889,
#   '해미가수산',
#   '회',
#   4.9,
#   '31',
#   '강원 강릉시 솔올로 97 1층',
#   37.77051229999999,
#   128.8788599],
#  [890,
#   '주문진남매식당',
#   '한정식',
#   4.8,
#   '15',
#   '강원 강릉시 주문진읍 작은다리길 31',
#   37.890516,
#   128.827831],
#  [891, '피노', '이탈리안', 3.3, '16', '강원 강릉시 팔송길 42-1', 37.7756849, 128.9341219],
#  [892, '카페썬', '카페', 2.6, '28', '강원 강릉시 강동면 정동역길 6', 37.691866, 129.031552],
#  [893,
#   '오엘이프',
#   '양식',
#   5.0,
#   '21',
#   '강원 강릉시 구정면 구정중앙로 242 1층',
#   37.7183549,
#   128.8808069],
#  [894,
#   '불향쭈꾸미',
#   '해물,생선',
#   0.0,
#   '36',
#   '강원 강릉시 율곡초교길11번길 21',
#   37.7666127,
#   128.8794664],
#  [895,
#   '딸부자막국수',
#   '국수',
#   5.0,
#   '8',
#   '강원 강릉시 강동면 대동안길 17',
#   37.72538839999999,
#   128.9780504],
#  [896,
#   '카르페디엠커피',
#   '커피전문점',
#   4.4,
#   '36',
#   '강원 강릉시 연곡면 해안로 1443',
#   37.86845039999999,
#   128.84583510000002],
#  [897,
#   '어림지 강릉점',
#   '해장국',
#   3.2,
#   '14',
#   '강원 강릉시 강릉대로 340',
#   37.7657217,
#   128.9046879],
#  [898, '산촌식당', '한식', 4.4, '23', '강원 강릉시 성산면 구산길 83', 37.7144658, 128.8281265],
#  [899,
#   '불향쭈꾸미볶음 강릉1호점',
#   '해물,생선',
#   4.3,
#   '19',
#   '강원 강릉시 중앙시장3길 15-2',
#   37.7514153,
#   128.8966826],
#  [900, '여왕개미식당', '국수', 4.2, '39', '강원 강릉시 금성로23번길 4', 37.7537546, 128.8980669],
#  [901,
#   '중앙닭강정',
#   '닭강정',
#   5.0,
#   '17',
#   '강원 강릉시 금성로13번길 8-1 1층',
#   37.753851899999994,
#   128.8992426],
#  [902, '더식탁', '양식', 3.5, '141', '강원 강릉시 강릉대로210번길 28', 37.755727, 128.89343],
#  [903,
#   '태백실비식당',
#   '갈비',
#   1.0,
#   '70',
#   '강원 강릉시 경포로 33-15 1층',
#   37.7719781,
#   128.8780328],
#  [904,
#   '소반',
#   '한정식',
#   4.7,
#   '16',
#   '강원 강릉시 하슬라로232번길 7-12',
#   37.771148,
#   128.8769764],
#  [905, '난설헌메밀촌', '국수', 4.6, '15', '강원 강릉시 난설헌로 105', 37.7868489, 128.9060121],
#  [906,
#   '소고기야시장 강릉본점',
#   '육류,고기',
#   3.7,
#   '17',
#   '강원 강릉시 정원로 44',
#   37.7622992,
#   128.8768436],
#  [907, '알뜨', '카페', 4.9, '21', '강원 강릉시 용지로 171', 37.7632021, 128.8997905],
#  [908,
#   '주문진회도매센타',
#   '회',
#   3.8,
#   '3',
#   '강원 강릉시 경포로463번길 36',
#   37.80435629999999,
#   128.9033795],
#  [909, '남애횟집', '회', 4.8, '11', '강원 강릉시 강릉대로457번길 3', 37.7740835, 128.9124609],
#  [910,
#   '강릉삼삼이네횟집',
#   '회',
#   5.0,
#   '14',
#   '강원 강릉시 가작로 78 주공1차아파트 상가',
#   37.7674566,
#   128.8849478],
#  [911,
#   '쿠우쿠우 강릉점(2021년7월예정)',
#   '해산물뷔페',
#   3.1,
#   '107',
#   '강원 강릉시 금성로 41 선프라자 5층',
#   37.7526119,
#   128.8964338],
#  [912,
#   '홍돼지국밥 본점',
#   '국밥',
#   3.9,
#   '19',
#   '강원 강릉시 강릉대로 237',
#   37.7596576,
#   128.8961148],
#  [913,
#   '달선이네조개마당',
#   '조개',
#   2.9,
#   '41',
#   '강원 강릉시 창해로14번길 28-2',
#   37.772169700000006,
#   128.94774089999999],
#  [914,
#   '용골감나무집',
#   '육류,고기',
#   3.0,
#   '61',
#   '강원 강릉시 진재골길29번길 45',
#   37.7371716,
#   128.8931752],
#  [915,
#   '바우카페',
#   '카페',
#   4.7,
#   '45',
#   '강원 강릉시 연곡면 해안로 1437',
#   37.868188200000006,
#   128.84646740000002],
#  [916,
#   '장수촌손칼국수',
#   '국수',
#   4.2,
#   '19',
#   '강원 강릉시 임영로164번길 4',
#   37.755768200000006,
#   128.8921538],
#  [917,
#   '토박이해물',
#   '해물,생선',
#   4.5,
#   '16',
#   '강원 강릉시 주문진읍 해안로 1615-1',
#   37.8799506,
#   128.832977],
#  [918,
#   '사돈네닭강정',
#   '닭강정',
#   4.4,
#   '20',
#   '강원 강릉시 주문진읍 주문북로 7',
#   37.8955023,
#   128.8312602],
#  [919,
#   '강릉브루어리',
#   '호프,요리주점',
#   4.1,
#   '18',
#   '강원 강릉시 율곡초교길11번길 9',
#   37.7675597,
#   128.87969669999998],
#  [920,
#   '지베이스',
#   '테마카페',
#   5.0,
#   '42',
#   '강원 강릉시 금성로56번길 6 2층',
#   37.7524285,
#   128.8950812],
#  [921,
#   '엠꼼마카롱 강릉점',
#   '디저트카페',
#   4.5,
#   '24',
#   '강원 강릉시 경강로2115번길 15 1층',
#   37.7569003,
#   128.896734],
#  [922,
#   '은총횟집',
#   '회',
#   4.7,
#   '115',
#   '강원 강릉시 금성로 21 지하1층 41호',
#   37.75400020000001,
#   128.89858279999999],
#  [923,
#   '디오슬로',
#   '카페',
#   4.0,
#   '108',
#   '강원 강릉시 난설헌로78번길 11',
#   37.780359000000004,
#   128.9030156],
#  [924,
#   '숲속집',
#   '순대',
#   3.9,
#   '23',
#   '강원 강릉시 성산면 칠봉로 15-7',
#   37.714696999999994,
#   128.8324108],
#  [925,
#   '제일강산',
#   '삼계탕',
#   4.3,
#   '15',
#   '강원 강릉시 홍제로85번길 29',
#   37.753361299999995,
#   128.8810571],
#  [926,
#   '진화해변횟집',
#   '회',
#   4.2,
#   '13',
#   '강원 강릉시 주문진읍 해안로 1825',
#   37.8950251,
#   128.8340189],
#  [927,
#   '주문진생선구이',
#   '해물,생선',
#   4.2,
#   '52',
#   '강원 강릉시 주문진읍 해안로 1795',
#   37.8948878,
#   128.8308815],
#  [928,
#   '강릉갈비찜',
#   '갈비',
#   5.0,
#   '35',
#   '강원 강릉시 위촌길 55 1층',
#   37.75844779999999,
#   128.86194070000002],
#  [929,
#   '오드커피',
#   '카페',
#   4.4,
#   '48',
#   '강원 강릉시 주문진읍 해안로 1597',
#   37.8787791,
#   128.8340243],
#  [930,
#   '카페다온로즈with테라로사',
#   '카페',
#   5.0,
#   '0',
#   '강원 강릉시 동해대로 3288-17 로비 1층',
#   37.786088,
#   128.8756123],
#  [931,
#   '버닝72.5',
#   '카페',
#   4.8,
#   '28',
#   '강원 강릉시 율곡초교길 13-1',
#   37.7679888,
#   128.8793057],
#  [932,
#   '성원궁횟집',
#   '회',
#   4.1,
#   '167',
#   '강원 강릉시 주문진읍 해안로 1839-5',
#   37.895858000000004,
#   128.8336997],
#  [933,
#   '한우만무한리필',
#   '육류,고기',
#   4.2,
#   '42',
#   '강원 강릉시 정원로 74-23 1층',
#   37.764564299999996,
#   128.8740635],
#  [934, '봉쥬르', '카페', 0.0, '26', '강원 강릉시 가작로 292', 37.7703167, 128.907048],
#  [935,
#   '남애수산횟집',
#   '회',
#   4.2,
#   '10',
#   '강원 강릉시 하슬라로232번길 14-6',
#   37.7699686,
#   128.8770976],
#  [936,
#   '초당젤라또 도깨비점',
#   '아이스크림',
#   3.0,
#   '67',
#   '강원 강릉시 주문진읍 해안로 1605 1, 2층',
#   37.879385600000006,
#   128.833747],
#  [937,
#   '강릉대게',
#   '게,대게',
#   4.5,
#   '43',
#   '강원 강릉시 하슬라로 18 1층',
#   37.7552029,
#   128.8798534],
#  [938,
#   '오감만족 강릉본점',
#   '족발,보쌈',
#   4.6,
#   '80',
#   '강원 강릉시 경강로2267번길 18 1층',
#   37.7669494,
#   128.9083621],
#  [939,
#   '소영이네돈까스물회',
#   '돈까스,우동',
#   4.2,
#   '48',
#   '강원 강릉시 정원로 54 1층',
#   37.7624613,
#   128.8758955],
#  [940,
#   '뚱할머니순두부',
#   '두부전문점',
#   4.3,
#   '17',
#   '강원 강릉시 난설헌로 211',
#   37.7919037,
#   128.91245859999998],
#  [941,
#   '커피인',
#   '카페',
#   5.0,
#   '29',
#   '강원 강릉시 주문진읍 해안로 1581 1층',
#   37.8775901,
#   128.8352443],
#  [942,
#   '쇠네스독일앤틱 독일빈티지독일카페 강릉본점',
#   '카페',
#   2.7,
#   '15',
#   '강원 강릉시 안현로 114-2',
#   37.803123799999995,
#   128.875915],
#  [943, '선풍', '회', 4.4, '33', '강원 강릉시 율곡초교길43번길 8', 37.7670295, 128.8793866],
#  [944,
#   '빵앗간',
#   '제과,베이커리',
#   3.7,
#   '67',
#   '강원 강릉시 하평길 74 1층',
#   37.77033970000001,
#   128.9166498],
#  [945,
#   '초시막국수',
#   '국수',
#   3.9,
#   '17',
#   '강원 강릉시 연곡면 초시길 33-1',
#   37.851387,
#   128.8379268],
#  [946, '커피쓰다', '카페', 4.7, '32', '강원 강릉시 강릉대로 300 1층', 37.7632948, 128.9013386],
#  [947, '해랑', '회', 2.8, '5', '강원 강릉시 주문진읍 해안로 1609', 37.879534, 128.8335259],
#  [948, '경포칼국수', '국수', 4.2, '12', '강원 강릉시 안현로 300 1층', 37.8036692, 128.8684568],
#  [949, '나의하루', '카페', 4.9, '27', '강원 강릉시 강동면 정동3길 43', 37.686265, 129.0360095],
#  [950,
#   '진보양푼이물회섭국',
#   '회',
#   3.3,
#   '9',
#   '강원 강릉시 사천면 진리해변길 67',
#   37.8384122,
#   128.8761021],
#  [951,
#   '뒷섬장치찜',
#   '해물,생선',
#   3.4,
#   '17',
#   '강원 강릉시 정원로 73-16',
#   37.7614794,
#   128.8728333],
#  [952, '삼우옹심이', '한식', 4.6, '12', '강원 강릉시 공항길 35', 37.7627207, 128.9401025],
#  [953,
#   '옛빙그레김밥',
#   '분식',
#   2.9,
#   '36',
#   '강원 강릉시 임영로116번안길 12',
#   37.7530739,
#   128.8940903],
#  [954,
#   '주문진신짬뽕',
#   '중화요리',
#   3.7,
#   '27',
#   '강원 강릉시 주문진읍 장성로 54 1층',
#   37.88780670000001,
#   128.82603170000002],
#  [955,
#   '그옛날 초당순두부',
#   '두부전문점',
#   3.8,
#   '14',
#   '강원 강릉시 초당순두부길 57',
#   37.7885984,
#   128.9143753],
#  [956,
#   '홍두깨',
#   '육류,고기',
#   3.8,
#   '88',
#   '강원 강릉시 율곡초교길43번길 14',
#   37.7648698,
#   128.8798669],
#  [957,
#   '미스터홍게',
#   '해물,생선',
#   4.4,
#   '12',
#   '강원 강릉시 하슬라로 123',
#   37.761045700000004,
#   128.872995],
#  [958,
#   '소돌막국수',
#   '국수',
#   5.0,
#   '20',
#   '강원 강릉시 주문진읍 연주로 571',
#   37.8871355,
#   128.8255882],
#  [959,
#   '전망대횟집',
#   '회',
#   4.0,
#   '15',
#   '강원 강릉시 강동면 헌화로 982-2',
#   37.685699,
#   129.0404278],
#  [960,
#   '옛소라회센타',
#   '회',
#   3.6,
#   '21',
#   '강원 강릉시 창해로350번길 13',
#   37.795426899999995,
#   128.9179918],
#  [961,
#   '보헤미안박이추커피 본점',
#   '카페',
#   5.0,
#   '9',
#   '강원 강릉시 연곡면 홍질목길 55-11',
#   37.8645982,
#   128.8423849],
#  [962,
#   '화로상회 강릉입암점',
#   '육류,고기',
#   1.0,
#   '32',
#   '강원 강릉시 성덕포남로 53 1층',
#   37.75964039999999,
#   128.9189442],
#  [963,
#   '후타고라멘 강릉점',
#   '일본식라면',
#   4.4,
#   '40',
#   '강원 강릉시 하슬라로232번길 22-11',
#   37.7695946,
#   128.8783156],
#  [964,
#   '정혜영쿡디자인',
#   '양식',
#   3.8,
#   '11',
#   '강원 강릉시 사천면 본동길 242',
#   37.827836700000006,
#   128.8594296],
#  [965,
#   '김윤미전복삼계탕',
#   '삼계탕',
#   4.1,
#   '24',
#   '강원 강릉시 팔송길 6',
#   37.774933700000005,
#   128.9328787],
#  [966,
#   '호텔탑스텐 뷔페포세이돈',
#   '뷔페',
#   2.6,
#   '10',
#   '강원 강릉시 옥계면 헌화로 455-34 2층',
#   37.6532823,
#   129.0514825],
#  [967,
#   '모구모구식당',
#   '일식',
#   3.8,
#   '34',
#   '강원 강릉시 선수촌로 124 1층',
#   37.748864000000005,
#   128.8824222],
#  [968,
#   '진리해변길71',
#   '이탈리안',
#   4.9,
#   '10',
#   '강원 강릉시 사천면 진리해변길 71',
#   37.83838679999999,
#   128.8762518],
#  [969,
#   '차이루',
#   '중화요리',
#   4.1,
#   '3',
#   '강원 강릉시 하슬라로232번길 14-8',
#   37.769788399999996,
#   128.87709089999998],
#  [970,
#   '신리면옥 강릉점',
#   '냉면',
#   4.4,
#   '16',
#   '강원 강릉시 하슬라로177번길 7',
#   37.7661829,
#   128.87450479999998],
#  [971, '고향횟집', '회', 3.5, '14', '강원 강릉시 강동면 염전길 149', 37.7408899, 128.9839432],
#  [972,
#   '연화마을',
#   '삼계탕',
#   5.0,
#   '73',
#   '강원 강릉시 강동면 풍호길 100-1',
#   37.737660399999996,
#   128.9534989],
#  [973,
#   '성왕돈까스',
#   '돈까스,우동',
#   4.1,
#   '32',
#   '강원 강릉시 성산면 구산길 55 1층',
#   37.7157321,
#   128.8310216],
#  [974,
#   '짠지 본점',
#   '찌개,전골',
#   5.0,
#   '23',
#   '강원 강릉시 토성로 181 1층',
#   37.756964399999994,
#   128.8957645],
#  [975,
#   '알베로',
#   '커피전문점',
#   3.6,
#   '34',
#   '강원 강릉시 창해로14번길 36',
#   37.771531700000004,
#   128.9484263],
#  [976, '노아회식당', '회', 4.9, '5', '강원 강릉시 경강로 2617', 37.7728612, 128.9455601],
#  [977, '어부횟집', '회', 3.6, '27', '강원 강릉시 강동면 헌화로 993', 37.6862617, 129.0393563],
#  [978,
#   '일출횟집',
#   '회',
#   4.8,
#   '19',
#   '강원 강릉시 주문진읍 시장2길 4 주문진수산시장 내',
#   37.8910576,
#   128.82775230000001],
#  [979,
#   '명품횡성한우고집',
#   '육류,고기',
#   3.7,
#   '23',
#   '강원 강릉시 율곡초교길11번길 15',
#   37.7670461,
#   128.87957820000003],
#  [980,
#   '스웨이',
#   '카페',
#   5.0,
#   '65',
#   '강원 강릉시 경포로 489-6 2층',
#   37.804239700000004,
#   128.9048271],
#  [981,
#   '심춘옥청국장&순두부',
#   '국밥',
#   4.7,
#   '17',
#   '강원 강릉시 초당순두부길 89-11',
#   37.791778799999996,
#   128.9146223],
#  [982,
#   '메밀골동해막국수 강문점',
#   '국수',
#   4.0,
#   '13',
#   '강원 강릉시 창해로350번길 25',
#   37.7963081,
#   128.9170671],
#  [983,
#   '정동진심곡쉼터',
#   '한식',
#   4.4,
#   '17',
#   '강원 강릉시 강동면 헌화로 665-4',
#   37.6648936,
#   129.0502839],
#  [984,
#   '정감이능이백숙',
#   '닭요리',
#   3.9,
#   '10',
#   '강원 강릉시 강동면 둔지길 89-16',
#   37.71652220000001,
#   128.9575437],
#  [985, '강릉뚝배기', '국밥', 4.2, '14', '강원 강릉시 남부로 5', 37.7402088, 128.8809818],
#  [986,
#   '대관령눈꽃갈비',
#   '갈비',
#   5.0,
#   '48',
#   '강원 강릉시 성산면 솔밭길 11-10',
#   37.73546629999999,
#   128.85186570000002],
#  [987,
#   '강릉짬뽕순두부',
#   '두부전문점',
#   4.4,
#   '21',
#   '강원 강릉시 초당순두부길 116',
#   37.790108399999994,
#   128.9139757],
#  [988,
#   '연당커피',
#   '카페',
#   5.0,
#   '26',
#   '강원 강릉시 연당길 112 1층',
#   37.7871386,
#   128.91256370000002],
#  [989,
#   '미미네횟집',
#   '회',
#   4.8,
#   '4',
#   '강원 강릉시 주문진읍 해안로 1917',
#   37.90143279999999,
#   128.8309767],
#  [990,
#   '돈비촌',
#   '갈비',
#   3.3,
#   '22',
#   '강원 강릉시 하슬라로206번길 23',
#   37.767854299999996,
#   128.8782508],
#  [991,
#   '천사곱창 강릉포남점',
#   '곱창,막창',
#   0.0,
#   '48',
#   '강원 강릉시 강릉대로 422-7',
#   37.7708563,
#   128.9109252],
#  [992,
#   '빠스따보니따',
#   '이탈리안',
#   4.8,
#   '23',
#   '강원 강릉시 주문진읍 해안로 1667',
#   37.883955,
#   128.82987079999998],
#  [993,
#   '빙그레김밥',
#   '분식',
#   4.0,
#   '19',
#   '강원 강릉시 토성로 153',
#   37.755339899999996,
#   128.8930338],
#  [994,
#   '등명맛집',
#   '회',
#   4.1,
#   '32',
#   '강원 강릉시 강동면 율곡로 1378',
#   37.702972499999994,
#   129.0157207],
#  [995,
#   '권오복 분틀메밀국수',
#   '국수',
#   4.5,
#   '13',
#   '강원 강릉시 율곡로 2713',
#   37.749515,
#   128.90716740000002],
#  [996, '엘바베큐', '육류,고기', 1.6, '54', '강원 강릉시 하남길 333', 37.8080816, 128.8994195],
#  [997,
#   '경포정육점식당&조개구이',
#   '육류,고기',
#   4.0,
#   '15',
#   '강원 강릉시 경포로463번길 36',
#   37.80435629999999,
#   128.9033795],
#  [998, '송천식당', '한식', 4.2, '9', '강원 강릉시 연곡면 진고개로 777', 37.8265466, 128.637643],
#  [999,
#   '육즙가득한고기집 육고집 강릉직영점',
#   '육류,고기',
#   5.0,
#   '14',
#   '강원 강릉시 사임당로 133',
#   37.766299,
#   128.8611138],
#  [1000,
#   '도로시피크닉',
#   '카페',
#   4.7,
#   '29',
#   '강원 강릉시 하슬라로232번길 6',
#   37.766580100000006,
#   128.8760505],
#  [2000,
#   '광고춘천펜션',
#   '펜션',
#   4.5,
#   '1',
#   '강원 춘천시 신북읍 신샘밭로 774',
#   37.9313649,
#   127.77650159999999],
#  [2001,
#   '소양강스카이워크',
#   '전망대',
#   3.3,
#   '425',
#   '강원 춘천시 영서로 2663',
#   37.8931677,
#   127.7232035],
#  [2002,
#   '남이섬',
#   '섬(내륙)',
#   2.8,
#   '461',
#   '강원 춘천시 남산면 남이섬길 1',
#   37.7899352,
#   127.52580719999999],
#  [2003,
#   '제이드가든수목원',
#   '수목원,식물원',
#   3.8,
#   '123',
#   '강원 춘천시 남산면 햇골길 80',
#   37.8325325,
#   127.5422982],
#  [2004,
#   '명동닭갈비골목',
#   '먹자골목',
#   3.5,
#   '40',
#   '강원 춘천시 조양동 138-15',
#   37.8790852,
#   127.7275235],
#  [2005,
#   '의암 스카이워크',
#   '전망대',
#   3.3,
#   '54',
#   '강원 춘천시 칠전동 468-1',
#   37.8453741,
#   127.67786650000001],
#  [2006,
#   '구봉산전망대',
#   '전망대',
#   3.3,
#   '7',
#   '강원 춘천시 동면 순환대로 1154-113',
#   37.892815899999995,
#   127.77678],
#  [2007,
#   '강원도립화목원',
#   '수목원,식물원',
#   4.5,
#   '70',
#   '강원 춘천시 화목원길 24',
#   37.92339460000001,
#   127.72443799999999],
#  [2008,
#   '건봉령승호대',
#   '관광,명소',
#   5.0,
#   '4',
#   '강원 춘천시 북산면 부귀리 산 59-9',
#   37.954737,
#   127.86388670000001],
#  [2009,
#   '김유정문학촌',
#   '관광,명소',
#   3.7,
#   '100',
#   '강원 춘천시 신동면 실레길 25',
#   37.819093200000005,
#   127.71881529999999],
#  [2010,
#   '레고랜드코리아리조트(2022년3월예정)',
#   '테마파크',
#   2.3,
#   '5',
#   '강원 춘천시 중도동 603-4',
#   37.8820784,
#   127.69660159999998],
#  [2011,
#   '구봉산전망대카페거리',
#   '카페거리',
#   4.0,
#   '30',
#   '강원 춘천시 동면 장학리',
#   37.9075284,
#   127.75823229999999],
#  [2012,
#   '삼악산',
#   '산',
#   4.3,
#   '73',
#   '강원 춘천시 서면 덕두원리 산 164-23',
#   37.839908799999996,
#   127.65722240000002],
#  [2013,
#   '공지천유원지',
#   '유원지',
#   3.8,
#   '56',
#   '강원 춘천시 근화동',
#   37.880565000000004,
#   127.7124994],
#  [2014,
#   '국립용화산자연휴양림',
#   '자연휴양림',
#   4.0,
#   '24',
#   '강원 춘천시 사북면 사여골길 294',
#   38.0113477,
#   127.7603378],
#  [2015,
#   '구곡폭포',
#   '폭포',
#   4.2,
#   '86',
#   '강원 춘천시 남산면 강촌리 432-37',
#   37.793923799999995,
#   127.6091805],
#  [2016,
#   '부귀리벚꽃길',
#   '테마거리',
#   4.7,
#   '3',
#   '강원 춘천시 북산면 부귀리 115-7',
#   37.9471249,
#   127.8766635],
#  [2017,
#   '의암호반길',
#   '드라이브코스',
#   3.9,
#   '0',
#   '강원 춘천시 서면 현암리 산 33-2',
#   37.88042670000001,
#   127.6808662],
#  [2018,
#   '강아지숲',
#   '테마파크',
#   3.8,
#   '8',
#   '강원 춘천시 남산면 충효로 437',
#   37.73593579999999,
#   127.6622656],
#  [2019, '소양강처녀상', '동상', 3.0, '77', '강원 춘천시 근화동 8-1', 37.8934139, 127.7243543],
#  [2020,
#   '집다리골자연휴양림',
#   '자연휴양림',
#   4.0,
#   '4',
#   '강원 춘천시 사북면 화악지암1길 130',
#   37.9776131,
#   127.58079199999999],
#  [2021,
#   '신매대교 인증센터',
#   '자전거여행',
#   4.3,
#   '8',
#   '강원 춘천시 서면 신매리 41-2',
#   37.9202714,
#   127.71300749999999],
#  [2022, '공지천', '하천', 4.3, '2', '강원 춘천시 근화동', 37.880565000000004, 127.7124994],
#  [2023,
#   '소양강',
#   '강',
#   5.0,
#   '3',
#   '강원 춘천시 동면 장학리 896',
#   37.910504100000004,
#   127.7466249],
#  [2024,
#   '강촌레일파크 경강역',
#   '테마파크',
#   4.0,
#   '7',
#   '강원 춘천시 남산면 서백길 57',
#   37.8427618,
#   127.5506962],
#  [2025,
#   '육림랜드',
#   '테마파크',
#   4.3,
#   '46',
#   '강원 춘천시 영서로 2965',
#   37.91774110000001,
#   127.719995],
#  [2026,
#   '춘천숲자연휴양림',
#   '자연휴양림',
#   4.7,
#   '9',
#   '강원 춘천시 동산면 종자리로 224-104',
#   37.7477873,
#   127.7434473],
#  [2027,
#   '의암호',
#   '호수',
#   4.4,
#   '13',
#   '강원 춘천시 삼천동',
#   37.868108899999996,
#   127.70041090000002],
#  [2028,
#   '월드온천',
#   '온천',
#   4.7,
#   '4',
#   '강원 춘천시 신북읍 장본길 35',
#   37.94973529999999,
#   127.7539249],
#  [2029,
#   '용화산',
#   '산',
#   4.0,
#   '26',
#   '강원 춘천시 사북면 고성리',
#   38.008004299999996,
#   127.74309299999999],
#  [2030,
#   '등선폭포',
#   '폭포',
#   4.6,
#   '31',
#   '강원 춘천시 서면 덕두원리 118-2',
#   37.8275841,
#   127.6583155],
#  [2031, '소양호', '호수', 4.5, '7', '강원 춘천시 북산면 내평리', 37.9553676, 127.8949604],
#  [2032,
#   '오봉산정상',
#   '산봉우리',
#   0.0,
#   '17',
#   '강원 춘천시 북산면 청평리',
#   37.9634966,
#   127.82530030000001],
#  [2033,
#   '춘천로데오거리',
#   '테마거리',
#   0.0,
#   '0',
#   '강원 춘천시 석사동',
#   37.861137400000004,
#   127.7496163],
#  [2035,
#   '추곡약수',
#   '샘터,약수터',
#   4.0,
#   '1',
#   '강원 춘천시 북산면 추곡리',
#   38.0270881,
#   127.88114420000001],
#  [2036,
#   '강촌테마랜드',
#   '테마파크',
#   1.0,
#   '19',
#   '강원 춘천시 남산면 강촌리 224-7',
#   37.8148633,
#   127.6340174],
#  ...]

# %% [markdown]
# csv 파일 list로 변환

# %%
place_name = place['place_name'].tolist()
detail_list = couple_vlog['블로그 내용'].tolist()

# %% [markdown]
# 여행지 이름 제거

# %%
place_name.remove('공감')
place_name.remove('강릉시')

# %% [markdown]
# # Okt

# %%
from konlpy.tag import Okt
okt = Okt()

# %% [markdown]
# # 커플 여행 블로그에서 여행경로 탐색하기

# %%
p = []
re = []
couple = []
s = set(place_name)
for i in range(len(detail_list)):
  data = detail_list[i]
  p.clear()
  p = okt.phrases(detail_list[i])
  re.append(p)
  ree = [x for x in re[i] if x in s]
  couple.append(ree)
  print(i,ree)
couple = [v for v in couple if v]
# Out:
# 0 []
# 1 ['항구마차', '헌화로']
# 2 ['경포대', '오죽헌']
# 3 []
# 4 []
# 5 ['금진해변', '헌화로']
# 6 ['경포대', '강문해변']
# 7 []
# 8 ['강문해변', '오죽헌', '경포대']
# 9 []
# 10 ['오죽헌']
# 11 []
# 12 []
# 13 ['경포대']
# 14 ['헌화로']
# 15 ['강문해변']
# 16 []
# 17 []
# 18 []
# 19 ['등명해변']
# 20 ['경포호', '경포대']
# 21 []
# 22 []
# 23 []
# 24 ['교동']
# 25 ['충혼탑']
# 26 []
# 27 []
# 28 ['강문해변']
# 29 ['정동진해변']
# 30 ['경포대']
# 31 []
# 32 []
# 33 []
# 34 []
# 35 ['경포대', '오죽헌', '동화가든', '교동']
# 36 []
# 37 ['버드나무브루어리']
# 38 []
# 39 ['경포대']
# 40 []
# 41 []
# 42 []
# 43 ['부채바위']
# 44 ['오죽헌']
# 45 []
# 46 ['등명해변']
# 47 []
# 48 []
# 49 []
# 50 ['헌화로', '항구마차']
# 51 ['남대천']
# 52 []
# 53 []
# 54 ['강문해변']
# 55 []
# 56 ['오죽헌', '경포대']
# 57 []
# 58 []
# 59 ['오죽헌', '경포대', '강문해변']
# 60 []
# 61 []
# 62 []
# 63 []
# 64 []
# 65 ['경포대']
# 66 []
# 67 []
# 68 []
# 69 ['경포대']
# 70 []
# 71 []
# 72 []
# 73 []
# 74 []
# 75 ['강문해변']
# 76 []
# 77 []
# 78 []
# 79 ['괘방산', '등명해변']
# 80 []
# 81 []
# 82 []
# 83 ['오죽헌']
# 84 []
# 85 ['경포대']
# 86 ['경포해변']
# 87 ['오죽헌']
# 88 []
# 89 []
# 90 []
# 91 []
# 92 []
# 93 []
# 94 ['안목해변']
# 95 []
# 96 []
# 97 ['경포대']
# 98 ['남대천']
# 99 []
# 100 ['남대천']
# 101 []
# 102 ['남대천', '오죽헌']
# 103 []
# 104 ['바로방', '벌집', '지베이스']
# 105 []
# 106 []
# 107 ['경포대']
# 108 []
# 109 ['항구마차', '헌화로']
# 110 ['경포대', '오죽헌']
# 111 []
# 112 []
# 113 ['금진해변', '헌화로']
# 114 ['경포대', '강문해변']
# 115 []
# 116 ['강문해변', '오죽헌', '경포대']
# 117 []
# 118 ['오죽헌']
# 119 []
# 120 []
# 121 ['경포대']
# 122 ['헌화로']
# 123 ['강문해변']
# 124 []
# 125 []
# 126 []
# 127 ['등명해변']
# 128 ['경포호', '경포대']
# 129 []
# 130 []
# 131 []
# 132 ['교동']
# 133 ['충혼탑']
# 134 []
# 135 []
# 136 ['강문해변']
# 137 ['정동진해변']
# 138 ['경포대']
# 139 []
# 140 []
# 141 []
# 142 []
# 143 ['경포대', '오죽헌', '동화가든', '교동']
# 144 []
# 145 ['버드나무브루어리']
# 146 []
# 147 ['경포대']
# 148 []
# 149 []
# 150 []
# 151 ['부채바위']
# 152 ['오죽헌']
# 153 []
# 154 ['등명해변']
# 155 []
# 156 []
# 157 []
# 158 ['헌화로', '항구마차']
# 159 ['남대천']
# 160 []
# 161 []
# 162 ['강문해변']
# 163 []
# 164 ['오죽헌', '경포대']
# 339 ['안목해변', '강릉남대천', '남대천']
# 340 ['안목해변', '송정해변', '강문해변']
# 341 ['송정해변']
# 342 []
# 343 ['오죽헌']
# 344 []
# 345 ['강문해변']
# 346 []
# 347 ['제왕산', '대굴령마을', '대관령옛길']
# 348 []
# 349 []
# 350 ['안목해변', '주문진해변']
# 351 []
# 352 ['강문해변', '오죽헌']
# 353 []
# 354 ['대관령옛길']
# 355 ['경포해변', '강문해변']
# 356 []
# 357 []
# 358 ['남대천']
# 359 ['수산시장']
# 360 ['안목해변', '남대천']
# 361 ['경포해변']
# 362 ['경포호']
# 363 ['오죽헌']
# 364 []
# 365 ['오죽헌']
# 366 ['오죽헌']
# 367 ['대관령옛길']
# 368 []
# 369 []
# 370 ['정감', '경포호']
# 371 []
# 372 []
# 373 []
# 374 ['경포대', '경포해변', '경포호']
# 375 []
# 376 ['곰배령']
# 377 []
# 378 ['안목해변', '오죽헌']
# 379 []
# 380 []
# 381 []
# 382 []
# 383 []
# 384 []
# 385 []
# 386 ['남대천']
# 387 ['깃대봉']
# 388 ['안목해변']
# 389 ['안목해변', '강문해변', '오죽헌', '경포호', '교동']
# 390 ['송정해변', '강문해변', '경포해변']
# 391 ['산토리니', '남대천']
# 392 []
# 393 ['남항진해변', '안목해변']
# 394 ['남대천']
# 395 ['송정해변']
# 396 ['송정해변', '경포해변']
# 397 []
# 398 []
# 399 []
# 400 []
# 401 []
# 402 []
# 403 []
# 404 ['남대천']
# 405 ['경포대']
# 406 []
# 407 []
# 408 []
# 409 []
# 410 []
# 411 []
# 412 []
# 413 ['경포해변', '강문해변', '엘빈', '안목해변', '산토리니']
# 414 ['강문해변', '오죽헌']
# 415 []
# 416 []
# 417 []
# 418 []
# 419 ['산토리니']
# 420 []
# 421 ['송정해변']
# 422 []
# 423 ['강문해변', '동화가든', '오죽헌']
# 424 ['강문해변', '오죽헌']
# 425 []
# 426 []
# 427 []
# 428 []
# 429 ['동화가든']
# 430 []
# 431 []
# 432 ['강문해변']
# 433 []
# 434 ['헌화로']
# 435 ['송정해변']
# 436 []
# 437 []
# 438 []
# 439 ['대관령옛길']
# 440 ['강릉향교']
# 441 []
# 442 []
# 443 []
# 444 []
# 445 []
# 446 []
# 447 []
# 448 []
# 449 []
# 450 []
# 451 []
# 452 []
# 453 []
# 454 ['오죽헌', '경포대']
# 455 []
# 456 ['오죽헌']
# 457 []
# 458 ['칠사당']
# 459 ['강문해변', '한점']
# 460 []
# 461 []
# 462 []
# 463 ['오죽헌']
# 464 []
# 465 ['영진해변']
# 466 ['안목해변']
# 467 []
# 468 ['안목해변', '산토리니', '엘빈']
# 469 []
# 470 []
# 471 ['대관령옛길', '오죽헌']
# 472 []
# 473 []
# 474 []
# 475 ['오죽헌', '경포대']
# 476 ['남대천']
# 477 []
# 478 []
# 479 ['오죽헌', '경포대']
# 480 ['한점', '강문해변', '남대천']
# 481 ['대관령옛길', '남대천']
# 482 ['경포대', '경포호']
# 483 ['경포해변', '교동', '경포대']
# 484 []
# 485 ['경포해변']
# 486 ['송정해변']
# 487 ['경포대']
# 488 []
# 489 ['남대천']
# 490 []
# 491 ['강문해변', '오죽헌']
# 492 []
# 493 []
# 494 []
# 495 ['강문해변']
# 496 []
# 497 []
# 498 ['경포대', '오죽헌']
# 499 []
# 500 ['안목해변']
# 501 []
# 502 []
# 503 []
# 504 []
# 505 ['경포대', '오죽헌', '동화가든', '교동']
# 506 []
# 507 ['남대천']
# 508 []
# 509 []
# 510 ['안목해변']
# 511 []
# 512 []
# 513 []
# 514 []
# 515 ['월성식당']
# 516 ['송정해변']
# 517 []
# 518 []
# 519 []
# 520 []
# 521 []
# 522 []
# 523 []
# 524 ['강문해변']
# 525 []
# 526 ['오죽헌']
# 527 ['안목해변']
# 528 []
# 529 []
# 530 ['강문해변', '오죽헌']
# 531 ['경포대']
# 532 []
# 533 []
# 534 []
# 535 ['남대천', '안목해변']
# 536 []
# 537 []
# 538 []
# 539 ['경포대', '강문해변']
# 540 []
# 541 ['강문해변', '오죽헌', '경포대']
# 542 ['경포대']
# 543 []
# 544 []
# 545 []
# 546 ['소금강', '노인봉']
# 547 ['명동칼국수']
# 548 ['남대천', '경포대']
# 549 []
# 550 []
# 551 []
# 552 ['강문해변', '오죽헌']
# 553 ['동화가든', '교동']
# 554 ['남대천', '안목해변']
# 555 []
# 556 []
# 557 []
# 558 []
# 559 ['오죽헌']
# 560 []
# 561 ['오죽헌']
# 562 []
# 563 []
# 564 []
# 565 []
# 566 ['대관령옛길']
# 567 []
# 568 []
# 569 ['강문해변', '경포대', '경포해변', '경포호']
# 570 []
# 571 ['강문해변', '안목해변', '남대천']
# 572 []
# 573 []
# 574 ['오월']
# 575 ['오죽헌']
# 576 ['경포대']
# 577 []
# 578 []
# 579 []
# 580 []
# 581 []
# 582 []
# 583 ['이만구교동짬뽕', '교동']
# 584 ['메밀꽃밭']
# 585 ['오죽헌', '교동']
# 586 ['경포대']
# 587 ['감자밭', '고산']
# 588 []
# 589 ['오죽헌']
# 590 []
# 591 ['안목해변']
# 592 []
# 593 []
# 594 []
# 595 ['강문해변', '오죽헌']
# 596 ['경포해변']
# 597 ['경포대', '오죽헌']
# 598 []
# 599 []
# 600 []
# 601 []
# 602 []
# 603 []
# 604 []
# 605 []
# 606 []
# 607 []
# 608 []
# 609 []
# 610 []
# 611 ['강릉남대천', '남대천', '강문해변']
# 612 []
# 613 ['경포대']
# 614 []
# 615 []
# 616 []
# 617 []
# 618 []
# 619 ['경포호']
# 620 ['안목해변']
# 621 []
# 622 []
# 623 ['오죽헌']
# 624 ['동화가든']
# 625 []
# 626 []
# 627 []
# 628 []
# 629 []
# 630 []
# 631 []
# 632 []
# 633 []
# 634 []
# 635 ['오죽헌']
# 636 []
# 637 ['남대천', '안목해변', '풀내음']
# 638 []
# 639 ['오죽헌', '경포대']
# 640 []
# 641 ['강문해변']
# 642 ['오죽헌', '남대천']
# 643 []
# 644 ['안목해변']
# 645 ['등명해변']
# 646 ['강문해변']
# 647 []
# 648 ['안목해변']
# 649 []
# 650 []
# 651 ['경포호']
# 652 []
# 653 []
# 654 []
# 2759 ['사천물회마을']
# 2760 ['경포호', '경포대']
# 2761 ['보헤미안']
# 2762 ['사천해변']
# 2763 ['사천해변']
# 2764 ['경포대']
# 2765 ['안목해변', '사천해변']
# 2766 []
# 2767 []
# 2768 ['한점']
# 2769 []
# 2770 ['사천해변']
# 2771 ['카페 뤼미에르', '사천해변']
# 2772 ['사천해변']
# 2773 ['사천해변']
# 2774 ['경포대']
# 2775 ['사천해변']
# 2776 []
# 2777 []
# 2778 []
# 2779 ['회관']
# 2780 []
# 2781 []
# 2782 ['경포대', '경포해변', '경포호']
# 2783 []
# 2784 []
# 2785 []
# 2786 ['경포대']
# 2787 ['사천해변']
# 2788 []
# 2789 []
# 2790 ['회관']
# 2791 ['사천해변']
# 2792 ['사천해변']
# 2793 []
# 2794 []
# 2795 ['사천해변']
# 2796 []
# 2797 []
# 2798 ['사천해변']
# 2799 ['사천해변']
# 2800 ['경포대']
# 2801 ['사천해변']
# 2802 ['오죽헌']
# 2803 ['사천해변']
# 2804 []
# 2805 []
# 2806 []
# 2807 ['안목해변', '사천해변']
# 2808 ['사천해변']
# 2809 []
# 2810 ['사천해변']
# 2811 []
# 2812 ['경포해변', '사천해변', '경포대']
# 2813 ['강문해변', '사천진해변', '회관']
# 2814 ['교동']
# 2815 ['사천해변']
# 2816 ['경포해변', '사천물회마을', '사천해변']
# 2817 []
# 2818 ['사천해변', '수산시장']
# 2819 ['사천해변']
# 2820 ['경포대']
# 2821 ['사천해변']
# 2822 ['사천해변']
# 2823 []
# 2824 []
# 2825 []
# 2826 ['사천해변']
# 2827 ['사천해변']
# 2828 ['사천해변']
# 2829 ['위도']
# 2830 ['오죽헌', '경포호']
# 2831 ['형제칼국수']
# 2832 []
# 2833 ['동화가든']
# 2834 []
# 2835 []
# 2836 ['사천해변']
# 2837 ['강문해변', '사천해변', '오죽헌']
# 2838 ['썸머키친']
# 2839 []
# 2840 ['오죽헌', '사천해변']
# 2841 ['형제칼국수', '경포대']
# 2842 ['사천해변']
# 2843 []
# 2844 []
# 2845 []
# 2846 []
# 2847 ['경포해변', '사천해변']
# 2848 ['사천해변']
# 2849 []
# 2850 []
# 2851 ['사천해변']
# 2852 ['사천해변']
# 2853 ['사천해변']
# 2854 ['사천해변', '오죽헌']
# 2855 ['경포해변', '사천해변']
# 2856 ['수산시장', '사천해변']
# 2857 []
# 2858 ['사천해변']
# 2859 ['사천해변']
# 2860 ['경포해변', '사천해변']
# 2861 ['해동횟집']
# 2862 []
# 2863 []
# 2864 ['사천해변', '경포대']
# 2865 ['카페 뤼미에르', '사천해변']
# 2866 []
# 2867 []
# 2868 ['오죽헌', '경포해변', '강문해변', '사천해변']
# 2869 []
# 2870 ['사천해변']
# 2871 []
# 2872 ['사천해변']
# 2873 ['사천해변', '경포대']
# 2874 ['옛카나리아', '테라로사 커피공장']
# 2875 ['사천해변', '사천물회마을', '경포대']
# 2876 []
# 2877 []
# 2878 ['안목해변', '사천해변']
# 2879 []
# 2880 ['경포대', '경포해변']
# 2881 ['사천해변']
# 2882 ['보헤미안']
# 2883 ['사천해변']
# 2884 []
# 2885 []
# 2886 ['사천해변']
# 2887 ['사천해변']
# 2888 ['사천해변']
# 2889 ['사천해변']
# 2890 []
# 2891 []
# 2892 ['사천해변']
# 2893 ['경포해변', '사천해변']
# 2894 []
# 2895 []
# 2896 []
# 2897 []
# 2898 []
# 2899 ['버드나무브루어리']
# 2900 []
# 2901 []
# 2902 []
# 2903 ['경포대']
# 2904 ['사천해변']
# 2905 ['사천해변']
# 2906 ['사천해변']
# 2907 []
# 2908 []
# 2909 ['사천해변']
# 2910 ['사천해변']
# 2911 ['사천해변']
# 2912 ['수산시장']
# 2913 ['수산시장']
# 2914 ['사천해변']
# 2915 []
# 2916 ['강문해변']
# 2917 ['사천해변']
# 2918 []
# 2919 []
# 2920 []
# 2921 []
# 2922 ['경포해변']
# 2923 ['교동']
# 2924 []
# 2925 ['경포해변', '강릉바우길', '사천해변']
# 2926 ['사천해변']
# 2927 []
# 2928 ['경포대', '사천해변', '경포호']
# 2929 ['사천해변']
# 2930 ['사천해변']
# 2931 ['사천해변']
# 2932 []
# 2933 ['사천해변']
# 2934 ['경포해변', '사천해변']
# 2935 ['경포대']
# 2936 ['사천해변']
# 2937 ['사천해변']
# 2938 []
# 2939 []
# 2940 []
# 2941 ['보헤미안']
# 2942 []
# 2943 ['사천해변']
# 2944 ['사천해변']
# 2945 []
# 2946 []
# 2947 []
# 2948 []
# 2949 []
# 2950 []
# 2951 []
# 2952 ['포남사골옹심이']
# 2953 []
# 2954 []
# 2955 ['옛카나리아']
# 2956 ['안목해변', '미르마르']
# 2957 []
# 2958 ['강문해변']
# 2959 []
# 2960 ['경포호']
# 2961 []
# 2962 []
# 2963 []
# 2964 []
# 2965 ['토부', '교동']
# 2966 []
# 2967 []
# 2968 ['남대천']
# 2969 []
# 2970 []
# 2971 []
# 2972 []
# 2973 []
# 2974 []
# 2975 []
# 2976 []
# 2977 []
# 2978 []
# 2979 []
# 2980 []
# 2981 []
# 2982 []
# 2983 []
# 2984 []
# 2985 []
# 2986 []
# 2987 []
# 2988 []
# 2989 ['강문해변']
# 2990 []
# 2991 []
# 2992 []
# 2993 ['교동']
# 2994 []
# 2995 []
# 2996 []
# 2997 []
# 2998 ['보헤미안']
# 2999 []
# 3000 ['강릉대도호부 관아']
# 3001 []
# 3002 ['셰프 수']
# 3003 []
# 3004 []
# 3005 []
# 3006 []
# 3007 []
# 3008 []
# 3009 []
# 3010 []
# 3011 []
# 3012 ['만동제과']
# 3013 []
# 3014 []
# 3015 []
# 3016 []
# 3017 []
# 3018 []
# 3019 []
# 3020 []
# 3021 []
# 3022 []
# 3023 []
# 3024 ['한점']
# 3025 []
# 3026 []
# 3027 ['풍년갈비']
# 3028 ['강릉향교', '교동']
# 3029 []
# 3030 []
# 3031 []
# 3032 []
# 3033 []
# 3034 ['테라로사 커피공장']
# 3035 []
# 3036 ['당도']
# 3037 []
# 3038 []
# 3039 []
# 3040 []
# 3041 []
# 3042 ['안목해변']
# 3043 []
# 3044 []
# 3045 ['정감']
# 3969 ['안목해변']
# 3970 ['남대천', '안목해변']
# 3971 ['안목해변']
# 3972 ['안목해변']
# 3973 ['안목해변', '엘빈']
# 3974 ['사천해변']
# 3975 ['오죽헌']
# 3976 []
# 3977 ['순두부젤라또 2호점', '당도']
# 3978 []
# 3979 ['경포대', '강문해변', '엘빈', '산토리니']
# 3980 ['사천해변']
# 3981 []
# 3982 ['남대천']
# 3983 ['안목해변', '산토리니', '알베로', '엘빈']
# 3984 ['경포해변', '산토리니']
# 3985 []
# 3986 ['오죽헌']
# 3987 []
# 3988 ['안목해변']
# 3989 ['경포호', '경포대', '오죽헌', '교동', '산토리니']
# 3990 ['경포대']
# 3991 []
# 3992 ['산토리니', '강릉카페거리', '안목해변', '경포호', '강릉바우길', '엘빈']
# 3993 []
# 3994 ['위도']
# 3995 ['안목해변', '강릉남대천', '남대천']
# 3996 []
# 3997 ['엘빈']
# 3998 []

# %%
couple
# Out:
# [['항구마차', '헌화로'],
#  ['경포대', '오죽헌'],
#  ['금진해변', '헌화로'],
#  ['경포대', '강문해변'],
#  ['강문해변', '오죽헌', '경포대'],
#  ['오죽헌'],
#  ['경포대'],
#  ['헌화로'],
#  ['강문해변'],
#  ['등명해변'],
#  ['경포호', '경포대'],
#  ['교동'],
#  ['충혼탑'],
#  ['강문해변'],
#  ['정동진해변'],
#  ['경포대'],
#  ['경포대', '오죽헌', '동화가든', '교동'],
#  ['버드나무브루어리'],
#  ['경포대'],
#  ['부채바위'],
#  ['오죽헌'],
#  ['등명해변'],
#  ['헌화로', '항구마차'],
#  ['남대천'],
#  ['강문해변'],
#  ['오죽헌', '경포대'],
#  ['오죽헌', '경포대', '강문해변'],
#  ['경포대'],
#  ['경포대'],
#  ['강문해변'],
#  ['괘방산', '등명해변'],
#  ['오죽헌'],
#  ['경포대'],
#  ['경포해변'],
#  ['오죽헌'],
#  ['안목해변'],
#  ['경포대'],
#  ['남대천'],
#  ['남대천'],
#  ['남대천', '오죽헌'],
#  ['바로방', '벌집', '지베이스'],
#  ['경포대'],
#  ['항구마차', '헌화로'],
#  ['경포대', '오죽헌'],
#  ['금진해변', '헌화로'],
#  ['경포대', '강문해변'],
#  ['강문해변', '오죽헌', '경포대'],
#  ['오죽헌'],
#  ['경포대'],
#  ['헌화로'],
#  ['강문해변'],
#  ['등명해변'],
#  ['경포호', '경포대'],
#  ['교동'],
#  ['충혼탑'],
#  ['강문해변'],
#  ['정동진해변'],
#  ['경포대'],
#  ['경포대', '오죽헌', '동화가든', '교동'],
#  ['버드나무브루어리'],
#  ['경포대'],
#  ['부채바위'],
#  ['오죽헌'],
#  ['등명해변'],
#  ['헌화로', '항구마차'],
#  ['남대천'],
#  ['강문해변'],
#  ['오죽헌', '경포대'],
#  ['오죽헌', '경포대', '강문해변'],
#  ['경포대'],
#  ['경포대'],
#  ['강문해변'],
#  ['괘방산', '등명해변'],
#  ['오죽헌'],
#  ['경포대'],
#  ['경포해변'],
#  ['오죽헌'],
#  ['안목해변'],
#  ['항구마차', '헌화로'],
#  ['경포대', '오죽헌'],
#  ['금진해변', '헌화로'],
#  ['경포대', '강문해변'],
#  ['강문해변', '오죽헌', '경포대'],
#  ['오죽헌'],
#  ['경포대'],
#  ['헌화로'],
#  ['강문해변'],
#  ['등명해변'],
#  ['교동'],
#  ['충혼탑'],
#  ['강문해변'],
#  ['정동진해변'],
#  ['경포대'],
#  ['경포대', '오죽헌', '동화가든', '교동'],
#  ['버드나무브루어리'],
#  ['경포대'],
#  ['부채바위'],
#  ['오죽헌'],
#  ['등명해변'],
#  ['헌화로', '항구마차'],
#  ['남대천'],
#  ['오죽헌', '경포대'],
#  ['오죽헌', '경포대', '강문해변'],
#  ['경포대'],
#  ['경포대'],
#  ['강문해변'],
#  ['괘방산', '등명해변'],
#  ['오죽헌'],
#  ['경포대'],
#  ['경포해변'],
#  ['오죽헌'],
#  ['안목해변', '경포해변'],
#  ['강문해변', '오죽헌'],
#  ['오죽헌'],
#  ['오죽헌'],
#  ['송정해변'],
#  ['남대천', '안목해변', '강문해변'],
#  ['오죽헌'],
#  ['경포대', '오죽헌'],
#  ['오죽헌'],
#  ['경포대'],
#  ['경포호', '경포대'],
#  ['고산'],
#  ['남대천'],
#  ['경포대', '오죽헌'],
#  ['강릉향교', '오죽헌'],
#  ['안목해변', '강릉남대천', '남대천'],
#  ['안목해변', '송정해변', '강문해변'],
#  ['송정해변'],
#  ['오죽헌'],
#  ['강문해변'],
#  ['제왕산', '대굴령마을', '대관령옛길'],
#  ['안목해변', '주문진해변'],
#  ['강문해변', '오죽헌'],
#  ['대관령옛길'],
#  ['경포해변', '강문해변'],
#  ['남대천'],
#  ['수산시장'],
#  ['안목해변', '남대천'],
#  ['경포해변'],
#  ['경포호'],
#  ['오죽헌'],
#  ['오죽헌'],
#  ['오죽헌'],
#  ['대관령옛길'],
#  ['정감', '경포호'],
#  ['경포대', '경포해변', '경포호'],
#  ['곰배령'],
#  ['안목해변', '오죽헌'],
#  ['남대천'],
#  ['깃대봉'],
#  ['안목해변'],
#  ['안목해변', '강문해변', '오죽헌', '경포호', '교동'],
#  ['송정해변', '강문해변', '경포해변'],
#  ['산토리니', '남대천'],
#  ['남항진해변', '안목해변'],
#  ['남대천'],
#  ['송정해변'],
#  ['송정해변', '경포해변'],
#  ['남대천'],
#  ['경포대'],
#  ['경포해변', '강문해변', '엘빈', '안목해변', '산토리니'],
#  ['강문해변', '오죽헌'],
#  ['산토리니'],
#  ['송정해변'],
#  ['강문해변', '동화가든', '오죽헌'],
#  ['강문해변', '오죽헌'],
#  ['동화가든'],
#  ['강문해변'],
#  ['헌화로'],
#  ['송정해변'],
#  ['대관령옛길'],
#  ['강릉향교'],
#  ['오죽헌', '경포대'],
#  ['오죽헌'],
#  ['칠사당'],
#  ['강문해변', '한점'],
#  ['오죽헌'],
#  ['영진해변'],
#  ['안목해변'],
#  ['안목해변', '산토리니', '엘빈'],
#  ['대관령옛길', '오죽헌'],
#  ['오죽헌', '경포대'],
#  ['남대천'],
#  ['오죽헌', '경포대'],
#  ['한점', '강문해변', '남대천'],
#  ['대관령옛길', '남대천'],
#  ['경포대', '경포호'],
#  ['경포해변', '교동', '경포대'],
#  ['경포해변'],
#  ['송정해변'],
#  ['경포대'],
#  ['남대천'],
#  ['강문해변', '오죽헌'],
#  ['강문해변'],
#  ['경포대', '오죽헌'],
#  ['안목해변'],
#  ['경포대', '오죽헌', '동화가든', '교동'],
#  ['남대천'],
#  ['안목해변'],
#  ['월성식당'],
#  ['송정해변'],
#  ['강문해변'],
#  ['오죽헌'],
#  ['안목해변'],
#  ['강문해변', '오죽헌'],
#  ['경포대'],
#  ['남대천', '안목해변'],
#  ['경포대', '강문해변'],
#  ['강문해변', '오죽헌', '경포대'],
#  ['경포대'],
#  ['소금강', '노인봉'],
#  ['명동칼국수'],
#  ['남대천', '경포대'],
#  ['강문해변', '오죽헌'],
#  ['동화가든', '교동'],
#  ['남대천', '안목해변'],
#  ['오죽헌'],
#  ['오죽헌'],
#  ['대관령옛길'],
#  ['강문해변', '경포대', '경포해변', '경포호'],
#  ['강문해변', '안목해변', '남대천'],
#  ['오월'],
#  ['오죽헌'],
#  ['경포대'],
#  ['이만구교동짬뽕', '교동'],
#  ['메밀꽃밭'],
#  ['오죽헌', '교동'],
#  ['경포대'],
#  ['감자밭', '고산'],
#  ['오죽헌'],
#  ['안목해변'],
#  ['강문해변', '오죽헌'],
#  ['경포해변'],
#  ['경포대', '오죽헌'],
#  ['강릉남대천', '남대천', '강문해변'],
#  ['경포대'],
#  ['경포호'],
#  ['안목해변'],
#  ['오죽헌'],
#  ['동화가든'],
#  ['오죽헌'],
#  ['남대천', '안목해변', '풀내음'],
#  ['오죽헌', '경포대'],
#  ['강문해변'],
#  ['오죽헌', '남대천'],
#  ['안목해변'],
#  ['등명해변'],
#  ['강문해변'],
#  ['안목해변'],
#  ['경포호'],
#  ['남대천', '사천해변'],
#  ['강문해변', '송정해변', '안목해변', '경포해변'],
#  ['강문해변', '오죽헌'],
#  ['수산시장'],
#  ['짬뽕1번지'],
#  ['경포호'],
#  ['소금강', '구룡폭포', '노인봉', '만물상'],
#  ['발산'],
#  ['오죽헌'],
#  ['강릉솔향수목원'],
#  ['송정해변'],
#  ['강문해변'],
#  ['송정해변', '강문해변', '경포해변'],
#  ['송정해변'],
#  ['오죽헌'],
#  ['오죽헌'],
#  ['대관령옛길'],
#  ['강문해변', '초당순두부마을', '동화가든'],
#  ['경포해변'],
#  ['남대천'],
#  ['강문해변'],
#  ['오죽헌'],
#  ['남대천'],
#  ['남대천'],
#  ['오죽헌'],
#  ['벌집'],
#  ['남대천'],
#  ['경포해변'],
#  ['사천해변'],
#  ['정감'],
#  ['BTS 버스정류장'],
#  ['사천해변'],
#  ['강문해변', '안산'],
#  ['플렉스'],
#  ['헌화로'],
#  ['경포해변', '경포대', '경포호'],
#  ['경포대'],
#  ['자스민'],
#  ['강문해변'],
#  ['사천해변', '감자밭', '경포호'],
#  ['경포대'],
#  ['수산시장'],
#  ['사천해변'],
#  ['사천진해변'],
#  ['BTS 버스정류장'],
#  ['경포대'],
#  ['교동'],
#  ['보헤미안'],
#  ['강문해변', '경포해변', '안목해변'],
#  ['경포로'],
#  ['교동'],
#  ['경포해변'],
#  ['남항진해변'],
#  ['경포대'],
#  ['영진해변'],
#  ['BTS 버스정류장'],
#  ['강릉수제버거'],
#  ['경포대'],
#  ['강문해변', '경포해변', '경포대'],
#  ['강문해변'],
#  ['강문해변'],
#  ['경포대'],
#  ['교동'],
#  ['경포대'],
#  ['BTS 버스정류장'],
#  ['남항진해변'],
#  ['신짬'],
#  ['주문진해변', '경포해변', '안목해변'],
#  ['비사이드그라운드'],
#  ['경포대'],
#  ['송정해변'],
#  ['경포로'],
#  ['교동'],
#  ['사천해변'],
#  ['강릉수제버거'],
#  ['안목해변', '젠주'],
#  ['남대천', '월화정'],
#  ['경포대'],
#  ['정감', '진재'],
#  ['명주배롱'],
#  ['경포대'],
#  ['강릉수제버거'],
#  ['강문해변'],
#  ['경포대'],
#  ['퍼베이드'],
#  ['교동', '106'],
#  ['강릉대도호부 관아', '돌담'],
#  ['경포해변', '강문해변', '교동'],
#  ['강릉수제버거'],
#  ['경포대', '사천해변'],
#  ['남대천'],
#  ['경포해변', '안목해변', '강문해변', '송정해변'],
#  ['명주배롱'],
#  ['오봉막국수'],
#  ['정감', '정감이능이백숙'],
#  ['경포호'],
#  ['경포대'],
#  ['안목해변'],
#  ['경포대'],
#  ['안목해변'],
#  ['오드커피'],
#  ['경포해변'],
#  ['강문해변'],
#  ['경포대'],
#  ['고산'],
#  ['BTS 버스정류장'],
#  ['허씨커피'],
#  ['회관'],
#  ['멍에전망대'],
#  ['교동'],
#  ['BTS 버스정류장'],
#  ['온정'],
#  ['정화식당'],
#  ['BTS 버스정류장'],
#  ['테라로사 커피공장'],
#  ['경포해변'],
#  ['경포해변'],
#  ['경포해변'],
#  ['벌집'],
#  ['테라로사 경포호수점', '경포호'],
#  ['정감'],
#  ['정화식당'],
#  ['안목해변'],
#  ['금학가온'],
#  ['BTS 버스정류장'],
#  ['교동'],
#  ['BTS 버스정류장'],
#  ['교동'],
#  ['경포해변'],
#  ['경포대'],
#  ['강릉수제버거'],
#  ['경포해변'],
#  ['강릉수제버거'],
#  ['보헤미안', '사천해변'],
#  ['금학가온', '삼거리'],
#  ['경포대'],
#  ['퍼베이드'],
#  ['경포대'],
#  ['안목해변'],
#  ['경포호'],
#  ['명주배롱'],
#  ['어바웃유', '교동'],
#  ['비키니'],
#  ['월화정'],
#  ['횡성한우촌'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대', '경포해변'],
#  ['106'],
#  ['교동'],
#  ['BTS 버스정류장'],
#  ['BTS 버스정류장'],
#  ['어바웃유', '교동'],
#  ['경포호'],
#  ['안목해변'],
#  ['BTS 버스정류장'],
#  ['허씨커피'],
#  ['보헤미안'],
#  ['경포해변'],
#  ['헌화로'],
#  ['강릉수제버거'],
#  ['교동'],
#  ['강문해변'],
#  ['경포호'],
#  ['안목해변'],
#  ['경포대'],
#  ['경포해변', '경포호'],
#  ['봉봉방앗간'],
#  ['금진해변'],
#  ['안목해변'],
#  ['수산시장'],
#  ['한점'],
#  ['BTS 버스정류장'],
#  ['오월', '정감', '명주배롱'],
#  ['사천해변', '니생각'],
#  ['강릉수제버거'],
#  ['교동'],
#  ['사천해변', '고심쌀롱'],
#  ['대동면옥', '교동'],
#  ['BTS 버스정류장'],
#  ['모구모구식당'],
#  ['옛카나리아'],
#  ['경포대'],
#  ['정감', '금진해변'],
#  ['동일장칼국수'],
#  ['노브일리'],
#  ['벌집'],
#  ['보헤미안'],
#  ['BTS 버스정류장'],
#  ['오죽헌', '서원', '수산시장'],
#  ['수산시장', '한점'],
#  ['경포대'],
#  ['바닷가라면', '사천해변'],
#  ['정화식당'],
#  ['해안도로'],
#  ['안목해변'],
#  ['BTS 버스정류장'],
#  ['안목해변', '남대천'],
#  ['BTS 버스정류장'],
#  ['경포해변'],
#  ['강릉수제버거'],
#  ['교동'],
#  ['금진해변', '헌화로'],
#  ['남대천'],
#  ['경포대'],
#  ['경포대'],
#  ['강릉수제버거'],
#  ['강릉수제버거'],
#  ['경포해변', '경포대'],
#  ['테라로사 사천점', '경포대'],
#  ['강문해변', '경포해변', '수산시장'],
#  ['경포해변', '경포대'],
#  ['경포대'],
#  ['경포대', '경포호', '오월'],
#  ['경포대'],
#  ['정감', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['교동', '경포대'],
#  ['경포대', '경포호'],
#  ['경포대'],
#  ['경포대', '남대천'],
#  ['경포대'],
#  ['경포대', '경포호', '오죽헌'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대', '해마', '경포호'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['강문해변', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포호', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['강문해변', '오죽헌', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대', '교동'],
#  ['경포대'],
#  ['경포대', '싸전', '강문해변'],
#  ['경포대'],
#  ['경포해변', '경포대', '경포호', '충혼탑', '강문해변'],
#  ['경포대', '남대천', '경포호'],
#  ['경포대', '도깨비시장'],
#  ['주문진해변', '경포대', '사천해변'],
#  ['경포대'],
#  ['경포대', '경포해변', '경포호'],
#  ['경포대'],
#  ['경포대', '강문해변'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['오월', '경포대', '교동'],
#  ['경포대'],
#  ['경포호', '경포해변', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['오월', '경포대'],
#  ['경포대', '비키니'],
#  ['경포대'],
#  ['경포대', '엘빈'],
#  ['경포해변', '사천해변', '경포대'],
#  ['사천해변'],
#  ['경포대'],
#  ['경포해변', '경포대'],
#  ['안목해변', '경포대'],
#  ['경포대'],
#  ['경포대', '강문해변'],
#  ['경포대', '강문해변'],
#  ['경포대', '경포호', '강문해변'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포해변', '사천해변', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포해변', '산토리니'],
#  ['경포대'],
#  ['경포대', '발산'],
#  ['형제칼국수', '경포대', '교동'],
#  ['경포대'],
#  ['경포해변', '사천해변'],
#  ['경포대'],
#  ['사천해변', '경포대', '교동', '경포호'],
#  ['경포해변', '강문해변', '경포대'],
#  ['경포대', '강문해변'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포호', '경포대', '오죽헌', '교동', '산토리니'],
#  ['경포대'],
#  ['강문해변', '강릉바우길', '사천해변'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대', '사천해변'],
#  ['경포대'],
#  ['경포대', '강문해변'],
#  ['경포대'],
#  ['안목해변', '경포대', '오죽헌', '경포호'],
#  ['경포대'],
#  ['경포대'],
#  ['경포해변', '경포대', '경포호'],
#  ['경포대'],
#  ['경포호', '경포대'],
#  ['경포대', '경포호'],
#  ['경포대', '경포호', '충혼탑'],
#  ['경포대'],
#  ['경포대', '비키니'],
#  ['경포대', '동화가든'],
#  ['경포대'],
#  ['경포대', '경포해변', '제일강산', '경포호'],
#  ['경포대'],
#  ['안목해변', '경포대'],
#  ['경포대', '강문해변'],
#  ['52블럭', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포해변', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포해변', '경포호', '강문해변', '경포대'],
#  ['경포호', '경포대'],
#  ['사천물회마을', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포해변', '비키니', '경포대'],
#  ['오죽헌', '경포해변', '경포호'],
#  ['보헤미안', '경포대'],
#  ['남대천', '경포대'],
#  ['강문해변', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['강문해변', '경포해변', '사천해변', '영진해변', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대', '경포호', '강문솟대다리'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포호', '경포대'],
#  ['강릉갈비찜', '경포대'],
#  ['경포대'],
#  ['안산', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['파도식당', '수산시장', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['안목해변', '산토리니', '경포대', '교동'],
#  ['경포대', '경포로', '경포호'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대', '강문해변'],
#  ['사천해변', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['수산시장', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대', '안목해변', '경포호'],
#  ['경포대', '경포해변', '경포호'],
#  ['경포대', '경포호'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포호', '경포대'],
#  ['경포대', '남대천'],
#  ['교동', '경포대'],
#  ['오죽헌', '경포대'],
#  ['소금강계곡', '소금강', '경포대'],
#  ['경포대', '경포천'],
#  ['경포대', '오죽헌'],
#  ['경포호', '경포대'],
#  ['경포대'],
#  ['경포호', '경포대'],
#  ['경포대', '강문해변'],
#  ['경포해변', '경포호', '경포대', '오죽헌'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['초당순두부마을', '경포대'],
#  ['사천해변'],
#  ['경포대'],
#  ['경포대'],
#  ['경포호', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대', '비키니'],
#  ['오죽헌', '경포대'],
#  ['경포대'],
#  ['경포해변', '경포대'],
#  ['경포대', '경포호'],
#  ['오죽헌', '경포대', '경포해변', '안목해변'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대', '경포해변'],
#  ['안목해변', '경포대'],
#  ['경포대'],
#  ['경포해변', '경포호', '경포대', '테라로사 경포대점'],
#  ['경포호', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['강릉솔향수목원', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포해변', '경포대'],
#  ['경포대', '강문해변'],
#  ['사천해변', '경포대', '교동'],
#  ['강문해변', '오죽헌', '경포대'],
#  ['오죽헌', '경포대'],
#  ['경포해변'],
#  ['경포해변'],
#  ['경포해변', '초당순두부마을', '안목해변'],
#  ['경포대'],
#  ['경포대'],
#  ['현대장칼국수'],
#  ['옛카나리아'],
#  ['강문해변', '경포대'],
#  ['경포해변'],
#  ['사천해변'],
#  ['안목해변', '사천해변'],
#  ['안목해변'],
#  ['경포해변'],
#  ['경포대', '동화가든'],
#  ['교동'],
#  ['경포대'],
#  ['강문해변'],
#  ['강릉대도호부 관아'],
#  ['경포해변'],
#  ['강릉수제버거'],
#  ['강릉수제버거'],
#  ['풍년갈비'],
#  ['테라로사 커피공장'],
#  ['경포호'],
#  ['정감'],
#  ['강문해변'],
#  ['사천해변'],
#  ['강문해변', '안산'],
#  ['플렉스'],
#  ['헌화로'],
#  ['보헤미안', '사천진해변', '경포대', '경포해변', '사천해변', '강릉커피콩빵 본점', '안목해변', '교동', '만동제과'],
#  ['하슬라아트월드', '등명해변', '일출전망대'],
#  ['자스민'],
#  ['강문해변'],
#  ['안목해변'],
#  ['사천해변', '감자밭', '경포호'],
#  ['수산시장'],
#  ['강릉카페거리'],
#  ['사천진해변'],
#  ['교동', '경포대', '경포호', '회관'],
#  ['사천해변'],
#  ['강문해변'],
#  ['교동'],
#  ['강릉수제버거'],
#  ['강문해변'],
#  ['경포해변'],
#  ['강문해변'],
#  ['발산', '강릉수제버거'],
#  ['남항진해변'],
#  ['영진해변'],
#  ['강릉수제버거'],
#  ['강문해변', '경포해변', '경포대'],
#  ['강문해변'],
#  ['사천해변'],
#  ['강문해변'],
#  ['교동'],
#  ['경포대'],
#  ['신짬'],
#  ['주문진해변', '경포해변', '안목해변'],
#  ['비사이드그라운드'],
#  ['경포대'],
#  ['송정해변'],
#  ['교동'],
#  ['안목해변'],
#  ['사천해변'],
#  ['강릉수제버거'],
#  ['강릉수제버거'],
#  ['동화가든', '강문해변', '현대장칼국수', '안목해변'],
#  ['금진해변'],
#  ['안목해변', '젠주'],
#  ['남대천', '월화정'],
#  ['강문해변'],
#  ['사근진해변'],
#  ['안목해변', '교동'],
#  ['강문해변'],
#  ['안목해변'],
#  ['명주배롱'],
#  ['강릉수제버거'],
#  ['강문해변'],
#  ['퍼베이드'],
#  ['강문해변', '안목해변'],
#  ['강릉대도호부 관아', '돌담'],
#  ['경포해변', '강문해변', '교동'],
#  ['강릉수제버거'],
#  ['남대천'],
#  ['경포해변', '안목해변', '강문해변', '송정해변'],
#  ['명주배롱'],
#  ['오봉막국수'],
#  ['강릉수제버거'],
#  ['경포호'],
#  ['경포호'],
#  ['경포호'],
#  ['금진해변'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['강문해변'],
#  ['초당순두부마을', '강문해변'],
#  ['안목해변'],
#  ['강문해변'],
#  ['수산시장'],
#  ['태백산맥', '주문진막국수', '안목해변', '강문해변'],
#  ['안목해변'],
#  ['커피바다'],
#  ['오드커피'],
#  ['강문해변'],
#  ['경포대'],
#  ['허씨커피'],
#  ['교동'],
#  ['온정'],
#  ['정화식당'],
#  ['경포해변'],
#  ['경포해변'],
#  ['경포대'],
#  ['경포해변'],
#  ['경포대'],
#  ['벌집'],
#  ['테라로사 경포호수점', '경포호'],
#  ['정화식당'],
#  ['동화가든', '테라로사 커피공장'],
#  ['초당순두부마을', '경포대', '교동', '토부'],
#  ['강릉수제버거'],
#  ['경포대'],
#  ['강릉수제버거', '향호'],
#  ['경포대'],
#  ['강문해변'],
#  ['안목해변'],
#  ['경포해변'],
#  ['사천해변', '경포대'],
#  ['경포호', '경포해변'],
#  ['강릉수제버거'],
#  ['경포해변'],
#  ['강릉수제버거'],
#  ['보헤미안', '사천해변'],
#  ['강문해변'],
#  ['안목해변'],
#  ['부채바위'],
#  ['노브일리', '안목해변'],
#  ['강문해변'],
#  ['경포호'],
#  ['명주배롱'],
#  ['안목해변'],
#  ['월화정'],
#  ['안목해변'],
#  ['강문해변', '아날로그소사이어티'],
#  ['경포대', '경포해변'],
#  ['경포해변'],
#  ['안목해변'],
#  ['교동'],
#  ['강문해변', '경포대', '오죽헌'],
#  ['어바웃유', '교동'],
#  ['사근진해변'],
#  ['강문해변'],
#  ['강문해변', '경포천', '산토리니'],
#  ['보헤미안'],
#  ['경포해변'],
#  ['헌화로'],
#  ['강릉수제버거'],
#  ['교동'],
#  ['강문해변'],
#  ['경포호'],
#  ['스웨이', '경포해변', '사천해변'],
#  ['경포해변', '경포호'],
#  ['금진해변'],
#  ['사천해변', '경포대'],
#  ['오월', '정감', '명주배롱'],
#  ['사천해변', '니생각'],
#  ['강릉수제버거'],
#  ['교동'],
#  ['사천해변', '고심쌀롱'],
#  ['옛카나리아'],
#  ['모먼트'],
#  ['경포호'],
#  ['정감', '금진해변'],
#  ['동화가든', '강문해변', '테라로사 경포호수점', '경포호'],
#  ['동일장칼국수'],
#  ['경포대'],
#  ['노브일리'],
#  ['해안도로'],
#  ['교동'],
#  ['벌집'],
#  ['보헤미안'],
#  ['오죽헌', '서원', '수산시장'],
#  ['경포대'],
#  ['안목해변', '교동'],
#  ['바닷가라면', '사천해변'],
#  ['안목해변'],
#  ['해안도로'],
#  ['안목해변', '남대천'],
#  ['버드나무브루어리'],
#  ['강릉수제버거'],
#  ['금진해변', '헌화로'],
#  ['교동'],
#  ['남대천'],
#  ['강문해변', '안목해변'],
#  ['강릉수제버거'],
#  ['강릉수제버거'],
#  ['안목해변', '오월'],
#  ['강릉수제버거'],
#  ['장안회집'],
#  ['사천해변'],
#  ['경포해변', '사천해변'],
#  ['사천해변', '경포대'],
#  ['사천해변'],
#  ['사천해변'],
#  ['오죽헌', '사천해변'],
#  ['보헤미안'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['오죽헌', '경포호'],
#  ['사천해변'],
#  ['한점', '교동'],
#  ['썸머키친'],
#  ['사천해변'],
#  ['강릉월화거리', '사천해변'],
#  ['오죽헌', '경포호'],
#  ['경포대', '경포해변', '경포호'],
#  ['사천해변'],
#  ['테라로사 커피공장'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변', '보헤미안'],
#  ['사천물회마을'],
#  ['경포호', '경포대'],
#  ['보헤미안'],
#  ['사천해변'],
#  ['사천해변'],
#  ['경포대'],
#  ['안목해변', '사천해변'],
#  ['한점'],
#  ['사천해변'],
#  ['카페 뤼미에르', '사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['경포대'],
#  ['사천해변'],
#  ['회관'],
#  ['경포대', '경포해변', '경포호'],
#  ['경포대'],
#  ['사천해변'],
#  ['회관'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['경포대'],
#  ['사천해변'],
#  ['오죽헌'],
#  ['사천해변'],
#  ['안목해변', '사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['경포해변', '사천해변', '경포대'],
#  ['강문해변', '사천진해변', '회관'],
#  ['교동'],
#  ['사천해변'],
#  ['경포해변', '사천물회마을', '사천해변'],
#  ['사천해변', '수산시장'],
#  ['사천해변'],
#  ['경포대'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['위도'],
#  ['오죽헌', '경포호'],
#  ['형제칼국수'],
#  ['동화가든'],
#  ['사천해변'],
#  ['강문해변', '사천해변', '오죽헌'],
#  ['썸머키친'],
#  ['오죽헌', '사천해변'],
#  ['형제칼국수', '경포대'],
#  ['사천해변'],
#  ['경포해변', '사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변', '오죽헌'],
#  ['경포해변', '사천해변'],
#  ['수산시장', '사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['경포해변', '사천해변'],
#  ['해동횟집'],
#  ['사천해변', '경포대'],
#  ['카페 뤼미에르', '사천해변'],
#  ['오죽헌', '경포해변', '강문해변', '사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변', '경포대'],
#  ['옛카나리아', '테라로사 커피공장'],
#  ['사천해변', '사천물회마을', '경포대'],
#  ['안목해변', '사천해변'],
#  ['경포대', '경포해변'],
#  ['사천해변'],
#  ['보헤미안'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['사천해변'],
#  ['경포해변', '사천해변'],
#  ['버드나무브루어리'],
#  ['경포대'],
#  ['사천해변'],
#  ['사천해변'],
#  ...]

# %% [markdown]
# # pandas data 프레임

# %% [markdown]
# 블로그 여행경로와 장소 정보 합치기

# %%
r2 = []
no_p = p_li.copy()
for i in range(len(couple)):
  for j in range(len(couple[i])):
    a = couple[i][j]
    y = list(zip(*p_li))[1].index(a)
    r1 = [i+1996,'guesthouse',j+1] + p_li[y]
    r2.append(r1)
    if p_li[y] in list(zip(*no_p))[1]:
      no_p.remove(p_li[y])
#print(r2)

# %%
r2
# Out:
# [[1996,
#   'guesthouse',
#   1,
#   550,
#   '항구마차',
#   '해물,생선',
#   4.2,
#   '86',
#   '강원 강릉시 옥계면 금진리 149-3',
#   37.648442200000005,
#   129.0469042],
#  [1996,
#   'guesthouse',
#   2,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [1997,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [1997,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [1998,
#   'guesthouse',
#   1,
#   29,
#   '금진해변',
#   '해수욕장,해변',
#   4.1,
#   '10',
#   '강원 강릉시 옥계면 금진리',
#   37.6432124,
#   129.0367071],
#  [1998,
#   'guesthouse',
#   2,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [1999,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [1999,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2000,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2000,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2000,
#   'guesthouse',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2001,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2002,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2003,
#   'guesthouse',
#   1,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2004,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2005,
#   'guesthouse',
#   1,
#   37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [2006,
#   'guesthouse',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2006,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2007,
#   'guesthouse',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2008,
#   'guesthouse',
#   1,
#   214,
#   '충혼탑',
#   '탑,비석',
#   0.0,
#   '2',
#   '강원 강릉시 저동',
#   37.7981294,
#   128.8925034],
#  [2009,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2010,
#   'guesthouse',
#   1,
#   5,
#   '정동진해변',
#   '해수욕장,해변',
#   4.1,
#   '123',
#   '강원 강릉시 강동면 정동진리 64-3',
#   37.68909379999999,
#   129.0348209],
#  [2011,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2012,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2012,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2012,
#   'guesthouse',
#   3,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [2012,
#   'guesthouse',
#   4,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2013,
#   'guesthouse',
#   1,
#   514,
#   '버드나무브루어리',
#   '호프,요리주점',
#   4.0,
#   '304',
#   '강원 강릉시 경강로 1961',
#   37.74822959999999,
#   128.88435959999998],
#  [2014,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2015,
#   'guesthouse',
#   1,
#   120,
#   '부채바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 심곡리 12-12',
#   37.67332820000001,
#   129.0573198],
#  [2016,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2017,
#   'guesthouse',
#   1,
#   37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [2018,
#   'guesthouse',
#   1,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2018,
#   'guesthouse',
#   2,
#   550,
#   '항구마차',
#   '해물,생선',
#   4.2,
#   '86',
#   '강원 강릉시 옥계면 금진리 149-3',
#   37.648442200000005,
#   129.0469042],
#  [2019,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2020,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2021,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2021,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2022,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2022,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2022,
#   'guesthouse',
#   3,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2023,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2024,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2025,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2026,
#   'guesthouse',
#   1,
#   64,
#   '괘방산',
#   '산',
#   4.5,
#   '16',
#   '강원 강릉시 강동면 모전리 26-3',
#   37.707970700000004,
#   128.9993365],
#  [2026,
#   'guesthouse',
#   2,
#   37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [2027,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2028,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2029,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2030,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2031,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2032,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2033,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2034,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2035,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2035,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2036,
#   'guesthouse',
#   1,
#   562,
#   '바로방',
#   '제과,베이커리',
#   3.2,
#   '153',
#   '강원 강릉시 경강로 2092',
#   37.7543398,
#   128.89587360000002],
#  [2036,
#   'guesthouse',
#   2,
#   508,
#   '벌집',
#   '국수',
#   3.2,
#   '377',
#   '강원 강릉시 경강로2069번길 15',
#   37.7545049,
#   128.892756],
#  [2036,
#   'guesthouse',
#   3,
#   920,
#   '지베이스',
#   '테마카페',
#   5.0,
#   '42',
#   '강원 강릉시 금성로56번길 6 2층',
#   37.7524285,
#   128.8950812],
#  [2037,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2038,
#   'guesthouse',
#   1,
#   550,
#   '항구마차',
#   '해물,생선',
#   4.2,
#   '86',
#   '강원 강릉시 옥계면 금진리 149-3',
#   37.648442200000005,
#   129.0469042],
#  [2038,
#   'guesthouse',
#   2,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2039,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2039,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2040,
#   'guesthouse',
#   1,
#   29,
#   '금진해변',
#   '해수욕장,해변',
#   4.1,
#   '10',
#   '강원 강릉시 옥계면 금진리',
#   37.6432124,
#   129.0367071],
#  [2040,
#   'guesthouse',
#   2,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2041,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2041,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2042,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2042,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2042,
#   'guesthouse',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2043,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2044,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2045,
#   'guesthouse',
#   1,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2046,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2047,
#   'guesthouse',
#   1,
#   37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [2048,
#   'guesthouse',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2048,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2049,
#   'guesthouse',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2050,
#   'guesthouse',
#   1,
#   214,
#   '충혼탑',
#   '탑,비석',
#   0.0,
#   '2',
#   '강원 강릉시 저동',
#   37.7981294,
#   128.8925034],
#  [2051,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2052,
#   'guesthouse',
#   1,
#   5,
#   '정동진해변',
#   '해수욕장,해변',
#   4.1,
#   '123',
#   '강원 강릉시 강동면 정동진리 64-3',
#   37.68909379999999,
#   129.0348209],
#  [2053,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2054,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2054,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2054,
#   'guesthouse',
#   3,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [2054,
#   'guesthouse',
#   4,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2055,
#   'guesthouse',
#   1,
#   514,
#   '버드나무브루어리',
#   '호프,요리주점',
#   4.0,
#   '304',
#   '강원 강릉시 경강로 1961',
#   37.74822959999999,
#   128.88435959999998],
#  [2056,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2057,
#   'guesthouse',
#   1,
#   120,
#   '부채바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 심곡리 12-12',
#   37.67332820000001,
#   129.0573198],
#  [2058,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2059,
#   'guesthouse',
#   1,
#   37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [2060,
#   'guesthouse',
#   1,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2060,
#   'guesthouse',
#   2,
#   550,
#   '항구마차',
#   '해물,생선',
#   4.2,
#   '86',
#   '강원 강릉시 옥계면 금진리 149-3',
#   37.648442200000005,
#   129.0469042],
#  [2061,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2062,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2063,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2063,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2064,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2064,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2064,
#   'guesthouse',
#   3,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2065,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2066,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2067,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2068,
#   'guesthouse',
#   1,
#   64,
#   '괘방산',
#   '산',
#   4.5,
#   '16',
#   '강원 강릉시 강동면 모전리 26-3',
#   37.707970700000004,
#   128.9993365],
#  [2068,
#   'guesthouse',
#   2,
#   37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [2069,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2070,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2071,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2072,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2073,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2074,
#   'guesthouse',
#   1,
#   550,
#   '항구마차',
#   '해물,생선',
#   4.2,
#   '86',
#   '강원 강릉시 옥계면 금진리 149-3',
#   37.648442200000005,
#   129.0469042],
#  [2074,
#   'guesthouse',
#   2,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2075,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2075,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2076,
#   'guesthouse',
#   1,
#   29,
#   '금진해변',
#   '해수욕장,해변',
#   4.1,
#   '10',
#   '강원 강릉시 옥계면 금진리',
#   37.6432124,
#   129.0367071],
#  [2076,
#   'guesthouse',
#   2,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2077,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2077,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2078,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2078,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2078,
#   'guesthouse',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2079,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2080,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2081,
#   'guesthouse',
#   1,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2082,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2083,
#   'guesthouse',
#   1,
#   37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [2084,
#   'guesthouse',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2085,
#   'guesthouse',
#   1,
#   214,
#   '충혼탑',
#   '탑,비석',
#   0.0,
#   '2',
#   '강원 강릉시 저동',
#   37.7981294,
#   128.8925034],
#  [2086,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2087,
#   'guesthouse',
#   1,
#   5,
#   '정동진해변',
#   '해수욕장,해변',
#   4.1,
#   '123',
#   '강원 강릉시 강동면 정동진리 64-3',
#   37.68909379999999,
#   129.0348209],
#  [2088,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2089,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2089,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2089,
#   'guesthouse',
#   3,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [2089,
#   'guesthouse',
#   4,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2090,
#   'guesthouse',
#   1,
#   514,
#   '버드나무브루어리',
#   '호프,요리주점',
#   4.0,
#   '304',
#   '강원 강릉시 경강로 1961',
#   37.74822959999999,
#   128.88435959999998],
#  [2091,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2092,
#   'guesthouse',
#   1,
#   120,
#   '부채바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 심곡리 12-12',
#   37.67332820000001,
#   129.0573198],
#  [2093,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2094,
#   'guesthouse',
#   1,
#   37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [2095,
#   'guesthouse',
#   1,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2095,
#   'guesthouse',
#   2,
#   550,
#   '항구마차',
#   '해물,생선',
#   4.2,
#   '86',
#   '강원 강릉시 옥계면 금진리 149-3',
#   37.648442200000005,
#   129.0469042],
#  [2096,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2097,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2097,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2098,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2098,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2098,
#   'guesthouse',
#   3,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2099,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2100,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2101,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2102,
#   'guesthouse',
#   1,
#   64,
#   '괘방산',
#   '산',
#   4.5,
#   '16',
#   '강원 강릉시 강동면 모전리 26-3',
#   37.707970700000004,
#   128.9993365],
#  [2102,
#   'guesthouse',
#   2,
#   37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [2103,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2104,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2105,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2106,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2107,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2107,
#   'guesthouse',
#   2,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2108,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2108,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2109,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2110,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2111,
#   'guesthouse',
#   1,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [2112,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2112,
#   'guesthouse',
#   2,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2112,
#   'guesthouse',
#   3,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2113,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2114,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2114,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2115,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2116,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2117,
#   'guesthouse',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2117,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2118,
#   'guesthouse',
#   1,
#   2215,
#   '고산',
#   '산',
#   0.0,
#   '0',
#   '강원 춘천시 중도동 205-1',
#   37.9072944,
#   127.71500590000001],
#  [2119,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2120,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2120,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2121,
#   'guesthouse',
#   1,
#   74,
#   '강릉향교',
#   '향교,서당',
#   0.0,
#   '5',
#   '강원 강릉시 명륜로 29',
#   37.7634,
#   128.895101],
#  [2121,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2122,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2122,
#   'guesthouse',
#   2,
#   114,
#   '강릉남대천',
#   '하천',
#   4.0,
#   '2',
#   '강원 강릉시 성남동',
#   37.7524714,
#   128.89898970000002],
#  [2122,
#   'guesthouse',
#   3,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2123,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2123,
#   'guesthouse',
#   2,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [2123,
#   'guesthouse',
#   3,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2124,
#   'guesthouse',
#   1,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [2125,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2126,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2127,
#   'guesthouse',
#   1,
#   104,
#   '제왕산',
#   '산',
#   5.0,
#   '8',
#   '강원 강릉시 왕산면 왕산리 산 1',
#   37.686331,
#   128.80631699999998],
#  [2127,
#   'guesthouse',
#   2,
#   190,
#   '대굴령마을',
#   '관광,명소',
#   5.0,
#   '1',
#   '강원 강릉시 성산면 성연로 17',
#   37.7228451,
#   128.8151159],
#  [2127,
#   'guesthouse',
#   3,
#   134,
#   '대관령옛길',
#   '도보여행',
#   2.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 761',
#   37.7028179,
#   128.7884916],
#  [2128,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2128,
#   'guesthouse',
#   2,
#   19,
#   '주문진해변',
#   '해수욕장,해변',
#   4.4,
#   '39',
#   '강원 강릉시 주문진읍 향호리 8-35',
#   37.909236299999996,
#   128.8215305],
#  [2129,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2129,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2130,
#   'guesthouse',
#   1,
#   134,
#   '대관령옛길',
#   '도보여행',
#   2.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 761',
#   37.7028179,
#   128.7884916],
#  [2131,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2131,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2132,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2133,
#   'guesthouse',
#   1,
#   569,
#   '수산시장',
#   '회',
#   4.4,
#   '122',
#   '강원 강릉시 창해로 361-7',
#   37.794538200000005,
#   128.9175687],
#  [2134,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2134,
#   'guesthouse',
#   2,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2135,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2136,
#   'guesthouse',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2137,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2138,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2139,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2140,
#   'guesthouse',
#   1,
#   134,
#   '대관령옛길',
#   '도보여행',
#   2.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 761',
#   37.7028179,
#   128.7884916],
#  [2141,
#   'guesthouse',
#   1,
#   601,
#   '정감',
#   '퓨전요리',
#   3.8,
#   '151',
#   '강원 강릉시 가작로 34',
#   37.771342600000004,
#   128.9003281],
#  [2141,
#   'guesthouse',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2142,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2142,
#   'guesthouse',
#   2,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2142,
#   'guesthouse',
#   3,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2143,
#   'guesthouse',
#   1,
#   2647,
#   '곰배령',
#   '한식',
#   3.3,
#   '26',
#   '강원 춘천시 춘천로 19 1층',
#   37.86687870000001,
#   127.72121729999999],
#  [2144,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2144,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2145,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2146,
#   'guesthouse',
#   1,
#   2209,
#   '깃대봉',
#   '산봉우리',
#   5.0,
#   '0',
#   '강원 춘천시 동면 월곡리',
#   37.9250584,
#   127.8129502],
#  [2147,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2148,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2148,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2148,
#   'guesthouse',
#   3,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2148,
#   'guesthouse',
#   4,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2148,
#   'guesthouse',
#   5,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2149,
#   'guesthouse',
#   1,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [2149,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2149,
#   'guesthouse',
#   3,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2150,
#   'guesthouse',
#   1,
#   2503,
#   '산토리니',
#   '카페',
#   3.8,
#   '467',
#   '강원 춘천시 동면 순환대로 1154-97',
#   37.8914143,
#   127.7764909],
#  [2150,
#   'guesthouse',
#   2,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2151,
#   'guesthouse',
#   1,
#   32,
#   '남항진해변',
#   '해수욕장,해변',
#   3.7,
#   '9',
#   '강원 강릉시 공항길127번길 67',
#   37.7639352,
#   128.9543434],
#  [2151,
#   'guesthouse',
#   2,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2152,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2153,
#   'guesthouse',
#   1,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [2154,
#   'guesthouse',
#   1,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [2154,
#   'guesthouse',
#   2,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2155,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2156,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2157,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2157,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2157,
#   'guesthouse',
#   3,
#   615,
#   '엘빈',
#   '디저트카페',
#   3.5,
#   '136',
#   '강원 강릉시 창해로14번길 34-1',
#   37.7716474,
#   128.9482711],
#  [2157,
#   'guesthouse',
#   4,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2157,
#   'guesthouse',
#   5,
#   2503,
#   '산토리니',
#   '카페',
#   3.8,
#   '467',
#   '강원 춘천시 동면 순환대로 1154-97',
#   37.8914143,
#   127.7764909],
#  [2158,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2158,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2159,
#   'guesthouse',
#   1,
#   2503,
#   '산토리니',
#   '카페',
#   3.8,
#   '467',
#   '강원 춘천시 동면 순환대로 1154-97',
#   37.8914143,
#   127.7764909],
#  [2160,
#   'guesthouse',
#   1,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [2161,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2161,
#   'guesthouse',
#   2,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [2161,
#   'guesthouse',
#   3,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2162,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2162,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2163,
#   'guesthouse',
#   1,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [2164,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2165,
#   'guesthouse',
#   1,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [2166,
#   'guesthouse',
#   1,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [2167,
#   'guesthouse',
#   1,
#   134,
#   '대관령옛길',
#   '도보여행',
#   2.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 761',
#   37.7028179,
#   128.7884916],
#  [2168,
#   'guesthouse',
#   1,
#   74,
#   '강릉향교',
#   '향교,서당',
#   0.0,
#   '5',
#   '강원 강릉시 명륜로 29',
#   37.7634,
#   128.895101],
#  [2169,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2169,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2170,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2171,
#   'guesthouse',
#   1,
#   197,
#   '칠사당',
#   '유적지',
#   0.0,
#   '5',
#   '강원 강릉시 경강로 2045',
#   37.7517814,
#   128.8918926],
#  [2172,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2172,
#   'guesthouse',
#   2,
#   2793,
#   '한점',
#   '육류,고기',
#   5.0,
#   '94',
#   '강원 춘천시 남춘로36번길 46',
#   37.8616233,
#   127.7354239],
#  [2173,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2174,
#   'guesthouse',
#   1,
#   13,
#   '영진해변',
#   '해수욕장,해변',
#   4.1,
#   '43',
#   '강원 강릉시 연곡면 영진리 72-2',
#   37.8680886,
#   128.8469178],
#  [2175,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2176,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2176,
#   'guesthouse',
#   2,
#   2503,
#   '산토리니',
#   '카페',
#   3.8,
#   '467',
#   '강원 춘천시 동면 순환대로 1154-97',
#   37.8914143,
#   127.7764909],
#  [2176,
#   'guesthouse',
#   3,
#   615,
#   '엘빈',
#   '디저트카페',
#   3.5,
#   '136',
#   '강원 강릉시 창해로14번길 34-1',
#   37.7716474,
#   128.9482711],
#  [2177,
#   'guesthouse',
#   1,
#   134,
#   '대관령옛길',
#   '도보여행',
#   2.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 761',
#   37.7028179,
#   128.7884916],
#  [2177,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2178,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2178,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2179,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2180,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2180,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2181,
#   'guesthouse',
#   1,
#   2793,
#   '한점',
#   '육류,고기',
#   5.0,
#   '94',
#   '강원 춘천시 남춘로36번길 46',
#   37.8616233,
#   127.7354239],
#  [2181,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2181,
#   'guesthouse',
#   3,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2182,
#   'guesthouse',
#   1,
#   134,
#   '대관령옛길',
#   '도보여행',
#   2.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 761',
#   37.7028179,
#   128.7884916],
#  [2182,
#   'guesthouse',
#   2,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2183,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2183,
#   'guesthouse',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2184,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2184,
#   'guesthouse',
#   2,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2184,
#   'guesthouse',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2185,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2186,
#   'guesthouse',
#   1,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [2187,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2188,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2189,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2189,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2190,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2191,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2191,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2192,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2193,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2193,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2193,
#   'guesthouse',
#   3,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [2193,
#   'guesthouse',
#   4,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2194,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2195,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2196,
#   'guesthouse',
#   1,
#   610,
#   '월성식당',
#   '해물,생선',
#   3.2,
#   '75',
#   '강원 강릉시 주문진읍 시장3길 4-1',
#   37.8918603,
#   128.8282053],
#  [2197,
#   'guesthouse',
#   1,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [2198,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2199,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2200,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2201,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2201,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2202,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2203,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2203,
#   'guesthouse',
#   2,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2204,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2204,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2205,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2205,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2205,
#   'guesthouse',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2206,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2207,
#   'guesthouse',
#   1,
#   103,
#   '소금강',
#   '강',
#   0.0,
#   '6',
#   '강원 강릉시 연곡면 삼산리',
#   37.827806,
#   128.6553172],
#  [2207,
#   'guesthouse',
#   2,
#   53,
#   '노인봉',
#   '산봉우리',
#   4.2,
#   '46',
#   '강원 강릉시 연곡면 삼산리 산 1-2',
#   37.83994939999999,
#   128.6566871],
#  [2208,
#   'guesthouse',
#   1,
#   2882,
#   '명동칼국수',
#   '국수',
#   4.5,
#   '27',
#   '강원 춘천시 영서로 3138',
#   37.93223560000001,
#   127.72262930000001],
#  [2209,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2209,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2210,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2210,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2211,
#   'guesthouse',
#   1,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [2211,
#   'guesthouse',
#   2,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2212,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2212,
#   'guesthouse',
#   2,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2213,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2214,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2215,
#   'guesthouse',
#   1,
#   134,
#   '대관령옛길',
#   '도보여행',
#   2.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 761',
#   37.7028179,
#   128.7884916],
#  [2216,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2216,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2216,
#   'guesthouse',
#   3,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2216,
#   'guesthouse',
#   4,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2217,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2217,
#   'guesthouse',
#   2,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2217,
#   'guesthouse',
#   3,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2218,
#   'guesthouse',
#   1,
#   532,
#   '오월',
#   '카페',
#   3.6,
#   '379',
#   '강원 강릉시 경강로2046번길 11-2',
#   37.7507555,
#   128.8931455],
#  [2219,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2220,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2221,
#   'guesthouse',
#   1,
#   570,
#   '이만구교동짬뽕',
#   '중화요리',
#   2.4,
#   '156',
#   '강원 강릉시 강릉대로 199',
#   37.758357700000005,
#   128.8923914],
#  [2221,
#   'guesthouse',
#   2,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2222,
#   'guesthouse',
#   1,
#   2117,
#   '메밀꽃밭',
#   '관광,명소',
#   5.0,
#   '3',
#   '강원 춘천시 서면 신매리',
#   37.922585299999994,
#   127.7088169],
#  [2223,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2223,
#   'guesthouse',
#   2,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2224,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2225,
#   'guesthouse',
#   1,
#   2771,
#   '감자밭',
#   '국수',
#   4.0,
#   '8',
#   '강원 춘천시 동내면 거두택지길14번길 9',
#   37.8523426,
#   127.75361940000002],
#  [2225,
#   'guesthouse',
#   2,
#   2215,
#   '고산',
#   '산',
#   0.0,
#   '0',
#   '강원 춘천시 중도동 205-1',
#   37.9072944,
#   127.71500590000001],
#  [2226,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2227,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2228,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2228,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2229,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2230,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2230,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2231,
#   'guesthouse',
#   1,
#   114,
#   '강릉남대천',
#   '하천',
#   4.0,
#   '2',
#   '강원 강릉시 성남동',
#   37.7524714,
#   128.89898970000002],
#  [2231,
#   'guesthouse',
#   2,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2231,
#   'guesthouse',
#   3,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2232,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2233,
#   'guesthouse',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2234,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2235,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2236,
#   'guesthouse',
#   1,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [2237,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2238,
#   'guesthouse',
#   1,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2238,
#   'guesthouse',
#   2,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2238,
#   'guesthouse',
#   3,
#   2855,
#   '풀내음',
#   '한식',
#   3.7,
#   '16',
#   '강원 춘천시 신북읍 상천3길 36-1',
#   37.9335821,
#   127.78926829999999],
#  [2239,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2239,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2240,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2241,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
# ...
#   37.7193495,
#   128.8287811],
#  [2585,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2586,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2586,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2587,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2588,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2589,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2590,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2591,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2592,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2593,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2594,
#   'guesthouse',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2594,
#   'guesthouse',
#   2,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2594,
#   'guesthouse',
#   3,
#   15,
#   '사천해변',
#   '해수욕장,해변',
#   3.8,
#   '27',
#   '강원 강릉시 사천면 방동리 282-1',
#   37.8202946,
#   128.86527809999998],
#  [2594,
#   'guesthouse',
#   4,
#   13,
#   '영진해변',
#   '해수욕장,해변',
#   4.1,
#   '43',
#   '강원 강릉시 연곡면 영진리 72-2',
#   37.8680886,
#   128.8469178],
#  [2594,
#   'guesthouse',
#   5,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2595,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2596,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2597,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2598,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2598,
#   'guesthouse',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2598,
#   'guesthouse',
#   3,
#   48,
#   '강문솟대다리',
#   '관광,명소',
#   3.6,
#   '16',
#   '강원 강릉시 강문동 248-4',
#   37.7977587,
#   128.9167205],
#  [2599,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2600,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2601,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2602,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2603,
#   'guesthouse',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2603,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2604,
#   'guesthouse',
#   1,
#   928,
#   '강릉갈비찜',
#   '갈비',
#   5.0,
#   '35',
#   '강원 강릉시 위촌길 55 1층',
#   37.75844779999999,
#   128.86194070000002],
#  [2604,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2605,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2606,
#   'guesthouse',
#   1,
#   2273,
#   '안산',
#   '산',
#   0.0,
#   '0',
#   '강원 춘천시 남산면 방곡리 419-3',
#   37.8025544,
#   127.6317218],
#  [2606,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2607,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2608,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2609,
#   'guesthouse',
#   1,
#   831,
#   '파도식당',
#   '매운탕,해물탕',
#   3.3,
#   '18',
#   '강원 강릉시 주문진읍 주문로 168',
#   37.89508379999999,
#   128.832463],
#  [2609,
#   'guesthouse',
#   2,
#   569,
#   '수산시장',
#   '회',
#   4.4,
#   '122',
#   '강원 강릉시 창해로 361-7',
#   37.794538200000005,
#   128.9175687],
#  [2609,
#   'guesthouse',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2610,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2611,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2612,
#   'guesthouse',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2612,
#   'guesthouse',
#   2,
#   2503,
#   '산토리니',
#   '카페',
#   3.8,
#   '467',
#   '강원 춘천시 동면 순환대로 1154-97',
#   37.8914143,
#   127.7764909],
#  [2612,
#   'guesthouse',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2612,
#   'guesthouse',
#   4,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2613,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2613,
#   'guesthouse',
#   2,
#   295,
#   '경포로',
#   '드라이브코스',
#   0.0,
#   '0',
#   '강원 강릉시 운정동',
#   37.7880229,
#   128.8952955],
#  [2613,
#   'guesthouse',
#   3,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2614,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2615,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2616,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2617,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2617,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2618,
#   'guesthouse',
#   1,
#   15,
#   '사천해변',
#   '해수욕장,해변',
#   3.8,
#   '27',
#   '강원 강릉시 사천면 방동리 282-1',
#   37.8202946,
#   128.86527809999998],
#  [2618,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2619,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2620,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2621,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2622,
#   'guesthouse',
#   1,
#   569,
#   '수산시장',
#   '회',
#   4.4,
#   '122',
#   '강원 강릉시 창해로 361-7',
#   37.794538200000005,
#   128.9175687],
#  [2622,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2623,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2624,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2625,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2626,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2627,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2627,
#   'guesthouse',
#   2,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2627,
#   'guesthouse',
#   3,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2628,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2628,
#   'guesthouse',
#   2,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2628,
#   'guesthouse',
#   3,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2629,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2629,
#   'guesthouse',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2630,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2631,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2632,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2633,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2634,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2635,
#   'guesthouse',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2635,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2636,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2636,
#   'guesthouse',
#   2,
#   75,
#   '남대천',
#   '하천',
#   0.0,
#   '4',
#   '강원 강릉시 성산면 구산리',
#   37.7193495,
#   128.8287811],
#  [2637,
#   'guesthouse',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [2637,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2638,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2638,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2639,
#   'guesthouse',
#   1,
#   41,
#   '소금강계곡',
#   '계곡',
#   4.6,
#   '17',
#   '강원 강릉시 연곡면 삼산리',
#   37.827806,
#   128.6553172],
#  [2639,
#   'guesthouse',
#   2,
#   103,
#   '소금강',
#   '강',
#   0.0,
#   '6',
#   '강원 강릉시 연곡면 삼산리',
#   37.827806,
#   128.6553172],
#  [2639,
#   'guesthouse',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2640,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2640,
#   'guesthouse',
#   2,
#   370,
#   '경포천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 대전동',
#   37.79388970000001,
#   128.8550747],
#  [2641,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2641,
#   'guesthouse',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2642,
#   'guesthouse',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2642,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2643,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2644,
#   'guesthouse',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2644,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2645,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2645,
#   'guesthouse',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [2646,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2646,
#   'guesthouse',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2646,
#   'guesthouse',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2646,
#   'guesthouse',
#   4,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2647,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2648,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2649,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2650,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2651,
#   'guesthouse',
#   1,
#   16,
#   '초당순두부마을',
#   '테마거리',
#   3.1,
#   '33',
#   '강원 강릉시 초당순두부길 89-8',
#   37.791815299999996,
#   128.9151518],
#  [2651,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2652,
#   'guesthouse',
#   1,
#   15,
#   '사천해변',
#   '해수욕장,해변',
#   3.8,
#   '27',
#   '강원 강릉시 사천면 방동리 282-1',
#   37.8202946,
#   128.86527809999998],
#  [2653,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2654,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2655,
#   'guesthouse',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2655,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2656,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2657,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2658,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2658,
#   'guesthouse',
#   2,
#   814,
#   '비키니',
#   '카페',
#   3.9,
#   '122',
#   '강원 강릉시 해안로 355',
#   37.7946563,
#   128.9142002],
#  [2659,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2659,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2660,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2661,
#   'guesthouse',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2661,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2662,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2662,
#   'guesthouse',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [2663,
#   'guesthouse',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [2663,
#   'guesthouse',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [2663,
#   'guesthouse',
#   3,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [2663,
#   'guesthouse',
#   4,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [2664,
#   'guesthouse',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  ...]

# %%
total = pd.DataFrame(r2)
total.columns = ['user_id','trip','course','place_id','place_name','place_category','rating','review','place_address','place_lat','place_lng']
total['y'] = 1

# %%
total
# Out:
#       user_id        trip  course  ...  place_lat   place_lng  y
# 0        1996  guesthouse       1  ...  37.648442  129.046904  1
# 1        1996  guesthouse       2  ...  37.667299  129.041663  1
# 2        1997  guesthouse       1  ...  37.795075  128.896598  1
# 3        1997  guesthouse       2  ...  37.779184  128.879458  1
# 4        1998  guesthouse       1  ...  37.643212  129.036707  1
# ...       ...         ...     ...  ...        ...         ... ..
# 1772     3220  guesthouse       1  ...  37.926374  127.715627  1
# 1773     3221  guesthouse       1  ...  37.771932  128.948935  1
# 1774     3221  guesthouse       2  ...  37.752471  128.898990  1
# 1775     3221  guesthouse       3  ...  37.719349  128.828781  1
# 1776     3222  guesthouse       1  ...  37.771647  128.948271  1
#
# [1777 rows x 12 columns]

# %% [markdown]
# 여행자가 가지 않은 장소와 여행자 합치기

# %%
from random import *
r3 = []
for i in range(len(couple)):
  for j in range(len(no_p)):
    k = randint(1,10)
    r4 = [i+1996,'guesthouse',k] + no_p[j]
    r3.append(r4)

# %%
total1 = pd.DataFrame(r3)
total1.columns = ['user_id','trip','course','place_id','place_name','place_category','rating','review','place_address','place_lat','place_lng']
total1['y'] = 0

# %%
total1
# Out:
#          user_id        trip  course  ...  place_lat   place_lng  y
# 0           1996  guesthouse       1  ...  37.707959  129.012171  0
# 1           1996  guesthouse       3  ...  37.805779  128.907417  0
# 2           1996  guesthouse       2  ...  37.666250  129.054547  0
# 3           1996  guesthouse      10  ...  37.795486  128.917920  0
# 4           1996  guesthouse       4  ...  37.689094  129.034821  0
# ...          ...         ...     ...  ...        ...         ... ..
# 2402461     3222  guesthouse       3  ...  37.865485  127.750965  0
# 2402462     3222  guesthouse       6  ...  37.850043  127.748694  0
# 2402463     3222  guesthouse       1  ...  37.979383  127.816946  0
# 2402464     3222  guesthouse       9  ...  37.867057  127.752314  0
# 2402465     3222  guesthouse      10  ...  37.884303  127.743665  0
#
# [2402466 rows x 12 columns]

# %%
result1 = pd.concat([total,total1], ignore_index=True)
result1
# Out:
#          user_id        trip  course  ...  place_lat   place_lng  y
# 0           1996  guesthouse       1  ...  37.648442  129.046904  1
# 1           1996  guesthouse       2  ...  37.667299  129.041663  1
# 2           1997  guesthouse       1  ...  37.795075  128.896598  1
# 3           1997  guesthouse       2  ...  37.779184  128.879458  1
# 4           1998  guesthouse       1  ...  37.643212  129.036707  1
# ...          ...         ...     ...  ...        ...         ... ..
# 2404238     3222  guesthouse       3  ...  37.865485  127.750965  0
# 2404239     3222  guesthouse       6  ...  37.850043  127.748694  0
# 2404240     3222  guesthouse       1  ...  37.979383  127.816946  0
# 2404241     3222  guesthouse       9  ...  37.867057  127.752314  0
# 2404242     3222  guesthouse      10  ...  37.884303  127.743665  0
#
# [2404243 rows x 12 columns]

# %%
result1.to_csv('/content/drive/MyDrive/졸업프로젝트/강원도 명소 데이터/final data/questhouse_full.csv', index = False, encoding='utf-8')

# %% [markdown]
# y가 0인 데이터 100만개 이하로 줄이기

# %%
total2 = total1.sample(frac=0.003, random_state= 1)
total2
# Out:
#          user_id        trip  course  ...  place_lat   place_lng  y
# 363825      2181  guesthouse       6  ...  37.938133  127.783791  0
# 2318303     3180  guesthouse       7  ...  37.763935  128.954343  0
# 245515      2121  guesthouse       8  ...  37.768174  128.875934  0
# 2389994     3216  guesthouse       5  ...  37.905205  127.738606  0
# 480593      2241  guesthouse       4  ...  37.752429  128.895081  0
# ...          ...         ...     ...  ...        ...         ... ..
# 2041377     3038  guesthouse       8  ...  37.981000  127.812778  0
# 814309      2411  guesthouse       3  ...  37.936881  127.744707  0
# 1017331     2515  guesthouse       8  ...  38.040373  127.601917  0
# 1864115     2948  guesthouse       6  ...  37.743491  128.893503  0
# 208985      2102  guesthouse       1  ...  37.781336  127.824696  0
#
# [7207 rows x 12 columns]

# %%
result1 = pd.concat([total,total2], ignore_index=True)
result1
# Out:
#       user_id        trip  course  ...  place_lat   place_lng  y
# 0        1996  guesthouse       1  ...  37.648442  129.046904  1
# 1        1996  guesthouse       2  ...  37.667299  129.041663  1
# 2        1997  guesthouse       1  ...  37.795075  128.896598  1
# 3        1997  guesthouse       2  ...  37.779184  128.879458  1
# 4        1998  guesthouse       1  ...  37.643212  129.036707  1
# ...       ...         ...     ...  ...        ...         ... ..
# 8979     3038  guesthouse       8  ...  37.981000  127.812778  0
# 8980     2411  guesthouse       3  ...  37.936881  127.744707  0
# 8981     2515  guesthouse       8  ...  38.040373  127.601917  0
# 8982     2948  guesthouse       6  ...  37.743491  128.893503  0
# 8983     2102  guesthouse       1  ...  37.781336  127.824696  0
#
# [8984 rows x 12 columns]

# %% [markdown]
# couple 카테고리 csv

# %%
result1.to_csv('/content/drive/MyDrive/졸업프로젝트/강원도 명소 데이터/final data/guesthouse1.csv', index = False, encoding='utf-8')
