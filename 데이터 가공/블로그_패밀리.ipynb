# %% [markdown]
# # KoNLPy 설치하기

# %%
# !set -x \
&& pip install konlpy \
&& curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh | bash -x
# Out:
# + pip install konlpy
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from konlpy) (0.4.4)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# + curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh
# + bash -x
# + mecab_dicdir=/usr/local/lib/mecab/dic/mecab-ko-dic
# + set -e
# ++ uname
# + os=Linux
# + [[ ! Linux == \L\i\n\u\x ]]
# + hash sudo
# + sudo=sudo
# + python=python3
# + hash pyenv
# + at_user_site=
# ++ check_python_site_location_is_writable
# ++ python3 -
# + [[ 1 == \0 ]]
# + hash automake
# + hash mecab
# + echo 'mecab-ko is already installed'
# mecab-ko is already installed
# + [[ -d /usr/local/lib/mecab/dic/mecab-ko-dic ]]
# + echo 'mecab-ko-dic is already installed'
# mecab-ko-dic is already installed
# ++ python3 -c 'import pkgutil; print(1 if pkgutil.find_loader("MeCab") else 0)'
# + [[ 1 == \1 ]]
# + echo 'mecab-python is already installed'
# mecab-python is already installed
# + echo Done.
# Done.

# %% [markdown]
# # 구글드라이브에 있는 CSV 파일 불러오기

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
couple_vlog = pd.read_csv('/content/drive/MyDrive/졸업프로젝트/강원도 명소 데이터/family_blog.csv')
place = pd.read_csv('/content/drive/MyDrive/졸업프로젝트/강원도 명소 데이터/강릉_춘천_위도_경도_추가.csv', encoding='utf-8')

# %% [markdown]
# 여행지아이디,여행지 이름,주소,카테고리,평점 리스트

# %%
p_li = place.values.tolist()

# %%
p_li
# Out:
# [[1,
#   '하슬라아트월드',
#   '테마파크',
#   3.7,
#   '282',
#   '강원 강릉시 강동면 정동진리 524-19',
#   37.7079586,
#   129.012171],
#  [2, '경포해변', '해수욕장,해변', 4.1, '194', '강원 강릉시 창해로 514', 37.8057795, 128.9074169],
#  [3,
#   '정동심곡 바다부채길',
#   '관광,명소',
#   4.3,
#   '182',
#   '강원 강릉시 강동면 심곡리 114-3',
#   37.6662501,
#   129.05454709999998],
#  [4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [5,
#   '정동진해변',
#   '해수욕장,해변',
#   4.1,
#   '123',
#   '강원 강릉시 강동면 정동진리 64-3',
#   37.68909379999999,
#   129.0348209],
#  [6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [9,
#   '강릉카페거리',
#   '카페거리',
#   4.0,
#   '199',
#   '강원 강릉시 창해로14번길 20',
#   37.772646200000004,
#   128.9472033],
#  [10,
#   '주문진방사제',
#   '관광,명소',
#   3.9,
#   '86',
#   '강원 강릉시 주문진읍 교항리',
#   37.8789811,
#   128.8177091],
#  [11,
#   '멍에전망대',
#   '전망대',
#   4.1,
#   '37',
#   '강원 강릉시 왕산면 대기리 2214-272',
#   37.6261275,
#   128.7414602],
#  [12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [13,
#   '영진해변',
#   '해수욕장,해변',
#   4.1,
#   '43',
#   '강원 강릉시 연곡면 영진리 72-2',
#   37.8680886,
#   128.8469178],
#  [14, '강릉선교장', '문화유적', 3.1, '124', '강원 강릉시 운정길 63', 37.7865935, 128.8851277],
#  [15,
#   '사천해변',
#   '해수욕장,해변',
#   3.8,
#   '27',
#   '강원 강릉시 사천면 방동리 282-1',
#   37.8202946,
#   128.86527809999998],
#  [16,
#   '초당순두부마을',
#   '테마거리',
#   3.1,
#   '33',
#   '강원 강릉시 초당순두부길 89-8',
#   37.791815299999996,
#   128.9151518],
#  [17,
#   '강릉솔향수목원',
#   '수목원,식물원',
#   4.5,
#   '65',
#   '강원 강릉시 구정면 수목원길 156',
#   37.6927213,
#   128.8609497],
#  [18,
#   '사근진해변',
#   '해수욕장,해변',
#   4.4,
#   '23',
#   '강원 강릉시 해안로604번길 14',
#   37.8126601,
#   128.8988879],
#  [19,
#   '주문진해변',
#   '해수욕장,해변',
#   4.4,
#   '39',
#   '강원 강릉시 주문진읍 향호리 8-35',
#   37.909236299999996,
#   128.8215305],
#  [20, '경포호', '호수', 4.3, '88', '강원 강릉시 초당동', 37.7919049, 128.9158303],
#  [21,
#   '순긋해변',
#   '해수욕장,해변',
#   4.0,
#   '25',
#   '강원 강릉시 안현동 235-5',
#   37.801911100000005,
#   128.8758249],
#  [22,
#   'BTS 버스정류장',
#   '촬영지',
#   5.0,
#   '12',
#   '강원 강릉시 주문진읍 향호리 8-39',
#   37.909236299999996,
#   128.8215305],
#  [23,
#   '향호해변',
#   '해수욕장,해변',
#   5.0,
#   '35',
#   '강원 강릉시 주문진읍 향호리',
#   37.8996511,
#   128.7843327],
#  [24,
#   '해안도로',
#   '드라이브코스',
#   3.7,
#   '3',
#   '강원 강릉시 강동면 헌화로 641',
#   37.6647915,
#   129.05304579999998],
#  [25,
#   '사천진해변',
#   '해수욕장,해변',
#   3.4,
#   '31',
#   '강원 강릉시 사천면 진리해변길 131',
#   37.839526299999996,
#   128.87401770000002],
#  [26,
#   '옥계해변',
#   '해수욕장,해변',
#   3.8,
#   '14',
#   '강원 강릉시 옥계면 금진솔밭길 148-3',
#   37.6304348,
#   129.04512659999997],
#  [27,
#   '소돌해변',
#   '해수욕장,해변',
#   4.4,
#   '41',
#   '강원 강릉시 주문진읍 주문리',
#   37.8990315,
#   128.8227808],
#  [28,
#   '국립대관령자연휴양림',
#   '자연휴양림',
#   3.7,
#   '16',
#   '강원 강릉시 성산면 삼포암길 133',
#   37.7144152,
#   128.7848205],
#  [29, '금진해변', '해수욕장,해변', 4.1, '10', '강원 강릉시 옥계면 금진리', 37.6432124, 129.0367071],
#  [30,
#   '대관령아기동물목장',
#   '동물원',
#   3.3,
#   '61',
#   '강원 강릉시 사천면 송암골길 197-23',
#   37.797637,
#   128.828676],
#  [31,
#   '국립대관령치유의숲',
#   '숲',
#   4.6,
#   '11',
#   '강원 강릉시 성산면 대관령옛길 127-42',
#   37.7107795,
#   128.7968291],
#  [32,
#   '남항진해변',
#   '해수욕장,해변',
#   3.7,
#   '9',
#   '강원 강릉시 공항길127번길 67',
#   37.7639352,
#   128.9543434],
#  [33,
#   '강릉임해자연휴양림',
#   '자연휴양림',
#   4.8,
#   '9',
#   '강원 강릉시 강동면 율곡로 1715-85',
#   37.718520399999996,
#   128.9985277],
#  [34,
#   '일출전망대',
#   '전망대',
#   5.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 2214-187',
#   37.6261275,
#   128.7414602],
#  [35,
#   '오대산국립공원',
#   '국립공원',
#   4.4,
#   '13',
#   '강원 강릉시 연곡면',
#   37.85975870000001,
#   128.8368017],
#  [36, '강릉월화거리', '테마거리', 4.0, '82', '강원 강릉시 경강로 2111', 37.7562073, 128.8969844],
#  [37,
#   '등명해변',
#   '해수욕장,해변',
#   4.1,
#   '13',
#   '강원 강릉시 강동면 정동진리 490-1',
#   37.689200799999995,
#   129.0243271],
#  [38,
#   '안인해변',
#   '해수욕장,해변',
#   3.0,
#   '8',
#   '강원 강릉시 강동면 안인진리 316-2',
#   37.728188,
#   128.9866112],
#  [39,
#   '노추산모정탑',
#   '탑,비석',
#   5.0,
#   '5',
#   '강원 강릉시 왕산면 대기리 산 716',
#   37.570945200000004,
#   128.7406375],
#  [40, '경포도립공원', '도립공원', 4.0, '2', '강원 강릉시 창해로 473', 37.8029286, 128.9097587],
#  [41, '소금강계곡', '계곡', 4.6, '17', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [42, '소돌아들바위', '바위', 4.6, '5', '강원 강릉시 주문진읍 주문리', 37.8990315, 128.8227808],
#  [43,
#   '연곡해변',
#   '해수욕장,해변',
#   3.4,
#   '12',
#   '강원 강릉시 연곡면 해안로 1282',
#   37.858084399999996,
#   128.8530771],
#  [44,
#   '쌍둥이동물농장',
#   '동물원',
#   3.5,
#   '49',
#   '강원 강릉시 옥계면 천남리 384',
#   37.608512100000006,
#   129.0390821],
#  [45, '염전해변', '해수욕장,해변', 4.0, '4', '강원 강릉시 강동면 안인진리', 37.728188, 128.9866112],
#  [46,
#   '뒷뜨루',
#   '관광농원',
#   4.5,
#   '74',
#   '강원 강릉시 사천면 청솔공원길 108',
#   37.8352469,
#   128.8372205],
#  [47, '강릉대도호부 관아', '유적지', 4.3, '32', '강원 강릉시 명주동', 37.7507099, 128.8914359],
#  [48,
#   '강문솟대다리',
#   '관광,명소',
#   3.6,
#   '16',
#   '강원 강릉시 강문동 248-4',
#   37.7977587,
#   128.9167205],
#  [50,
#   '호텔탑스텐 금진온천',
#   '온천',
#   5.0,
#   '2',
#   '강원 강릉시 옥계면 헌화로 455-34 1층',
#   37.6532823,
#   129.0514825],
#  [51, '하평해변', '해수욕장,해변', 2.0, '6', '강원 강릉시 사천면 사천진리', 37.8435195, 128.8684982],
#  [52,
#   '런닝맨 강릉점',
#   '테마파크',
#   4.0,
#   '46',
#   '강원 강릉시 창해로 307 파인동 2층',
#   37.7911114,
#   128.92106869999998],
#  [53,
#   '노인봉',
#   '산봉우리',
#   4.2,
#   '46',
#   '강원 강릉시 연곡면 삼산리 산 1-2',
#   37.83994939999999,
#   128.6566871],
#  [54,
#   '강릉안반데기관광농원',
#   '관광농원',
#   0.0,
#   '8',
#   '강원 강릉시 왕산면 안반데기1길 203',
#   37.622628999999996,
#   128.73915549999998],
#  [55,
#   '호린파크',
#   '테마파크',
#   4.0,
#   '19',
#   '강원 강릉시 사천면 해안로 1119-51',
#   37.833163,
#   128.8770374],
#  [56,
#   '대관령전망대',
#   '전망대',
#   4.5,
#   '14',
#   '강원 강릉시 성산면 어흘리 803',
#   37.7107204,
#   128.7795353],
#  [57,
#   '경포해변인증센터',
#   '자전거여행',
#   0.0,
#   '4',
#   '강원 강릉시 안현동 산 1-10',
#   37.8054757,
#   128.90782990000002],
#  [58,
#   '강릉바우길',
#   '도보여행',
#   5.0,
#   '1',
#   '강원 강릉시 임영로180번길 25',
#   37.7571009,
#   128.89463130000001],
#  [59,
#   '순포해수욕장',
#   '해수욕장,해변',
#   4.6,
#   '1',
#   '강원 강릉시 사천면 산대월리 산 1',
#   37.8227298,
#   128.88591350000002],
#  [60,
#   '삽당령',
#   '바위',
#   0.0,
#   '8',
#   '강원 강릉시 왕산면 목계리',
#   37.625665999999995,
#   128.8625156],
#  [61,
#   '사천진해변공원',
#   '해수욕장,해변',
#   0.0,
#   '2',
#   '강원 강릉시 사천면 사천진리',
#   37.8435195,
#   128.8684982],
#  [62, '용지기념각', '문화유적', 0.0, '0', '강원 강릉시 포남동 1138-8', 37.7603559, 128.9042446],
#  [63,
#   '닭목령',
#   '고개',
#   0.0,
#   '2',
#   '강원 강릉시 왕산면 왕산리',
#   37.651880600000005,
#   128.7800211],
#  [64,
#   '괘방산',
#   '산',
#   4.5,
#   '16',
#   '강원 강릉시 강동면 모전리 26-3',
#   37.707970700000004,
#   128.9993365],
#  [65,
#   '허난설헌생가터',
#   '생가,고택',
#   3.4,
#   '43',
#   '강원 강릉시 난설헌로193번길 1-16',
#   37.7919383,
#   128.9092743],
#  [66,
#   '노추산모정탑길',
#   '도보여행',
#   0.0,
#   '8',
#   '강원 강릉시 왕산면 대기리 산 716',
#   37.570945200000004,
#   128.7406375],
#  [67, '사천물회마을', '관광,명소', 5.0, '4', '강원 강릉시 사천면 사천진리', 37.8435195, 128.8684982],
#  [68,
#   '부연동계곡',
#   '계곡',
#   0.0,
#   '1',
#   '강원 강릉시 연곡면 삼산리 산 133-12',
#   37.8132591,
#   128.7053777],
#  [69, '음악시간펜션', '펜션', 3.0, '7', '강원 강릉시 사천면 해안로 1151', 37.833163, 128.8770374],
#  [71,
#   '고루포기산',
#   '산',
#   4.7,
#   '9',
#   '강원 강릉시 왕산면 왕산리 산 1',
#   37.686331,
#   128.80631699999998],
#  [72,
#   '명주군왕릉',
#   '릉,묘,총',
#   5.0,
#   '3',
#   '강원 강릉시 성산면 삼왕길 204-39',
#   37.7622436,
#   128.7968793],
#  [73,
#   '애니멀스토리',
#   '동물원',
#   0.0,
#   '11',
#   '강원 강릉시 성산면 성연로 212-10',
#   37.7339859,
#   128.811375],
#  [74, '강릉향교', '향교,서당', 0.0, '5', '강원 강릉시 명륜로 29', 37.7634, 128.895101],
#  [75, '남대천', '하천', 0.0, '4', '강원 강릉시 성산면 구산리', 37.7193495, 128.8287811],
#  [80, '죽헌저수지', '저수지', 0.0, '0', '강원 강릉시 지변동', 37.7745945, 128.86716950000002],
#  [82,
#   '월화거리관광안내센터',
#   '관광안내소',
#   0.0,
#   '3',
#   '강원 강릉시 성남동 41-12',
#   37.7543412,
#   128.8993541],
#  [83,
#   '강릉원주대학교 강릉캠퍼스 해람지',
#   '호수',
#   0.0,
#   '0',
#   '강원 강릉시 죽헌길 7',
#   37.7664551,
#   128.8712017],
#  [85,
#   '정동진 인증센터',
#   '자전거여행',
#   0.0,
#   '2',
#   '강원 강릉시 강동면 정동진리 569-2',
#   37.687172499999996,
#   129.0376985],
#  [86,
#   '바다여행펜션',
#   '펜션',
#   0.0,
#   '1',
#   '강원 강릉시 경포로371번길 23',
#   37.79728660000001,
#   128.8966997],
#  [88, '경포인공폭포', '폭포', 0.0, '0', '강원 강릉시 창해로 563', 37.8084768, 128.9028744],
#  [89,
#   '도직해변',
#   '해수욕장,해변',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 도직리 97-12',
#   37.609390399999995,
#   129.06767539999998],
#  [90,
#   '강릉여행굿캠핑&펜션',
#   '펜션',
#   5.0,
#   '3',
#   '강원 강릉시 사천면 해안로 904-8',
#   37.8319051,
#   128.8757503],
#  [92, '단경골계곡', '계곡', 3.5, '1', '강원 강릉시 강동면 언별리', 37.6645164, 128.9241222],
#  [94,
#   '석병산',
#   '산',
#   0.0,
#   '12',
#   '강원 강릉시 옥계면 산계리 산 428',
#   37.5789,
#   128.94787250000002],
#  [96,
#   '강릉정동진해안단구',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 심곡리 1-11',
#   37.6662501,
#   129.05454709999998],
#  [98,
#   '강릉구라미온천',
#   '온천',
#   1.7,
#   '1',
#   '강원 강릉시 사천면 구라미등길 25-15',
#   37.843541200000004,
#   128.8396741],
#  [99,
#   '능경봉',
#   '산봉우리',
#   4.0,
#   '2',
#   '강원 강릉시 왕산면 왕산리 산 1-8',
#   37.6744834,
#   128.7694837],
#  [100,
#   '강릉임영관 삼문',
#   '문',
#   4.0,
#   '4',
#   '강원 강릉시 임영로131번길 6',
#   37.7531104,
#   128.8917655],
#  [101,
#   '사천진 바위섬',
#   '바위',
#   5.0,
#   '1',
#   '강원 강릉시 사천면 사천진리 1-26',
#   37.839771500000005,
#   128.87578870000002],
#  [102,
#   '송천약수',
#   '샘터,약수터',
#   4.5,
#   '1',
#   '강원 강릉시 연곡면 삼산리 산 195-1',
#   37.83994939999999,
#   128.6566871],
#  [103, '소금강', '강', 0.0, '6', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [104,
#   '제왕산',
#   '산',
#   5.0,
#   '8',
#   '강원 강릉시 왕산면 왕산리 산 1',
#   37.686331,
#   128.80631699999998],
#  [106, '사기막저수지', '저수지', 0.0, '0', '강원 강릉시 사천면 사기막리', 37.778613, 128.7736565],
#  [107,
#   '대관령옛길표지석',
#   '탑,비석',
#   4.0,
#   '0',
#   '강원 강릉시 성산면 어흘리 산 2-21',
#   37.7248749,
#   128.813972],
#  [108, '양양남대천', '하천', 0.0, '0', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [109, '향호', '저수지', 0.0, '7', '강원 강릉시 주문진읍 향호리', 37.8996511, 128.7843327],
#  [111,
#   '동대산',
#   '산',
#   5.0,
#   '12',
#   '강원 강릉시 연곡면 삼산리 산 4',
#   37.83994939999999,
#   128.6566871],
#  [112,
#   '장덕리은행나무',
#   '문화유적',
#   4.0,
#   '0',
#   '강원 강릉시 주문진읍 장덕리 643',
#   37.87764749999999,
#   128.7831095],
#  [114, '강릉남대천', '하천', 4.0, '2', '강원 강릉시 성남동', 37.7524714, 128.89898970000002],
#  [115,
#   '굴산사지당간지주',
#   '문화유적',
#   0.0,
#   '10',
#   '강원 강릉시 구정면 학산리 1181',
#   37.707269000000004,
#   128.8918012],
#  [116,
#   '기린온천사우나',
#   '온천',
#   1.0,
#   '0',
#   '강원 강릉시 남부로125번길 18',
#   37.7434915,
#   128.893503],
#  [117,
#   '모래시계소나무',
#   '촬영지',
#   5.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [120,
#   '부채바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 심곡리 12-12',
#   37.67332820000001,
#   129.0573198],
#  [121, '향호지', '저수지', 0.0, '1', '강원 강릉시 주문진읍 향호리', 37.8996511, 128.7843327],
#  [122,
#   '구룡폭포',
#   '폭포',
#   4.0,
#   '1',
#   '강원 강릉시 연곡면 소금강길 500',
#   37.813579600000004,
#   128.7044652],
#  [123,
#   '영동고속도로 대관령구간',
#   '드라이브코스',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 왕산리',
#   37.651880600000005,
#   128.7800211],
#  [124,
#   '신사임당사친사비',
#   '탑,비석',
#   4.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 산 2-12',
#   37.7283347,
#   128.8184182],
#  [125,
#   '강릉여행 굿캠핑',
#   '카라반',
#   5.0,
#   '8',
#   '강원 강릉시 사천면 해안로 904-8',
#   37.8319051,
#   128.8757503],
#  [126,
#   '강릉여행자플랫폼',
#   '관광안내소',
#   5.0,
#   '0',
#   '강원 강릉시 죽헌길9번길 17',
#   37.768888200000006,
#   128.87383290000002],
#  [127,
#   '월화정',
#   '문화유적',
#   3.0,
#   '3',
#   '강원 강릉시 강변로312번길 1-7',
#   37.750975200000006,
#   128.9025168],
#  [129,
#   '경포가시연습지 습지광장',
#   '광장',
#   0.0,
#   '1',
#   '강원 강릉시 운정동 14',
#   37.79153839999999,
#   128.8964338],
#  [130,
#   '원대재산림욕장',
#   '자연휴양림',
#   5.0,
#   '2',
#   '강원 강릉시 교동 1071-1',
#   37.761162,
#   128.8838576],
#  [131,
#   '신왕저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 신왕리',
#   37.816453499999994,
#   128.7640752],
#  [132,
#   '오봉저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 오봉리 408',
#   37.6961366,
#   128.8114885],
#  [133,
#   '라파트리치오신부순교터',
#   '종교유적지',
#   5.0,
#   '1',
#   '강원 강릉시 옥계면 낙풍리 산 47-3',
#   37.63516120000001,
#   129.0211949],
#  [134,
#   '대관령옛길',
#   '도보여행',
#   2.0,
#   '2',
#   '강원 강릉시 성산면 어흘리 761',
#   37.7028179,
#   128.7884916],
#  [135,
#   '모래시계공원 모래시계탑',
#   '관광,명소',
#   5.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 7-1',
#   37.689512,
#   129.03202620000002],
#  [137,
#   '경포관광안내센터',
#   '관광안내소',
#   0.0,
#   '1',
#   '강원 강릉시 안현동 산 2-11',
#   37.801911100000005,
#   128.8758249],
#  [139,
#   '수청동계곡',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 신왕길 443-4',
#   37.8232912,
#   128.7703002],
#  [140,
#   '닭목재',
#   '드라이브코스',
#   0.0,
#   '1',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [141, '삼일운동기념탑', '탑,비석', 4.0, '2', '강원 강릉시 저동', 37.7981294, 128.8925034],
#  [142,
#   '고성목해수욕장',
#   '해수욕장,해변',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [143,
#   '월대산',
#   '산',
#   5.0,
#   '0',
#   '강원 강릉시 두산동 산 55',
#   37.762700200000005,
#   128.9211396],
#  [144, '신복사지', '문화유적', 0.0, '0', '강원 강릉시 내곡동', 37.7390776, 128.8808633],
#  [145, '강릉해운정', '문화유적', 0.0, '5', '강원 강릉시 운정길 125', 37.7861329, 128.8912551],
#  [146,
#   '삼교지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 삼교리',
#   37.8860651,
#   128.72118079999998],
#  [147,
#   '모정의탑',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 1526',
#   37.57821989999999,
#   128.7490804],
#  [148,
#   '대관령영동고속도로 준공비',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 어흘리 산 2-14',
#   37.6860585,
#   128.761372],
#  [149,
#   '옥계저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 북동리',
#   37.6226354,
#   128.96262190000002],
#  [150, '연곡천', '하천', 0.0, '1', '강원 강릉시 연곡면 동덕리', 37.8517901, 128.8393749],
#  [151,
#   '송담서원',
#   '서원',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 송담서원길 27-7',
#   37.692901899999995,
#   128.92917179999998],
#  [152,
#   '기마봉',
#   '산봉우리',
#   3.7,
#   '6',
#   '강원 강릉시 옥계면 금진리 산 81',
#   37.6441514,
#   129.0318912],
#  [153,
#   '주문진관광안내소',
#   '관광안내소',
#   2.0,
#   '0',
#   '강원 강릉시 주문진읍 해안로 1734',
#   37.8895823,
#   128.8286288],
#  [154,
#   '하슬라아트월드 하늘전망대',
#   '테마파크시설',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 율곡로 1441',
#   37.7056021,
#   129.0080007],
#  [156, '부연약수', '샘터,약수터', 5.0, '0', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [157,
#   '오봉서원',
#   '서원',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 오봉서원길 32',
#   37.7107775,
#   128.81941940000002],
#  [158,
#   '경포가시연습지 방문자센터',
#   '관광안내소',
#   0.0,
#   '3',
#   '강원 강릉시 저동 144-4',
#   37.7917299,
#   128.8961284],
#  [159, '죽도봉', '산봉우리', 0.0, '2', '강원 강릉시 견소동 11-1', 37.7704204, 128.9504858],
#  [161,
#   '오죽헌 율곡인성교육관',
#   '유적지',
#   0.0,
#   '1',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [162,
#   '석란정',
#   '문화유적',
#   4.5,
#   '0',
#   '강원 강릉시 강문동 258-14',
#   37.803507700000004,
#   128.9086246],
#  [163,
#   '경포대허브농원',
#   '관광농원',
#   0.0,
#   '3',
#   '강원 강릉시 사천면 손맞이길 91-23',
#   37.843697799999994,
#   128.86644679999998],
#  [164,
#   '대관령국사여성황사',
#   '사당,제단',
#   5.0,
#   '0',
#   '강원 강릉시 경강로1804번길 12-12',
#   37.7453316,
#   128.8658275],
#  [165,
#   '괘방산 등산코스',
#   '등산로',
#   4.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 17',
#   37.6911646,
#   129.0330457],
#  [166, '화부산', '산', 0.0, '0', '강원 강릉시 교동 산 153-3', 37.7644528, 128.8932694],
#  [168,
#   '동막저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 어단리',
#   37.6785816,
#   128.89343689999998],
#  [169,
#   '하시동고분군',
#   '릉,묘,총',
#   0.0,
#   '1',
#   '강원 강릉시 강동면 풍호길 300-83',
#   37.7496391,
#   128.97020279999998],
#  [170,
#   '단경골휴양지',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 단경로 841',
#   37.6723487,
#   128.9164916],
#  [171,
#   '정동진헌화로',
#   '드라이브코스',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [172,
#   '장현저수지',
#   '저수지',
#   4.5,
#   '2',
#   '강원 강릉시 장현동',
#   37.728821200000006,
#   128.8939201],
#  [173, '헌화로', '드라이브코스', 3.5, '12', '강원 강릉시 강동면 심곡리', 37.6672988, 129.0416628],
#  [174,
#   '담정관광농원',
#   '관광농원',
#   3.0,
#   '3',
#   '강원 강릉시 강동면 언별리 산 253',
#   37.6460441,
#   128.92168909999998],
#  [175,
#   '최선평가옥',
#   '생가,고택',
#   5.0,
#   '0',
#   '강원 강릉시 주문진읍 신리천로 342',
#   37.878467,
#   128.7961997],
#  [176,
#   '초당마을숲',
#   '숲',
#   0.0,
#   '0',
#   '강원 강릉시 난설헌로193번길 1-16',
#   37.7919383,
#   128.9092743],
#  [177,
#   '칠성산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 목계리 산 460-1',
#   37.61781920000001,
#   128.87906329999998],
#  [178,
#   '신복사지삼층석탑',
#   '탑,비석',
#   0.0,
#   '3',
#   '강원 강릉시 내곡동 403-2',
#   37.7427739,
#   128.8855576],
#  [179,
#   '사천천',
#   '하천',
#   0.0,
#   '1',
#   '강원 강릉시 사천면 덕실리',
#   37.805178399999996,
#   128.8410131],
#  [180,
#   '성산먹거리촌',
#   '먹자골목',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 구산리 350-1',
#   37.71538839999999,
#   128.8299289],
#  [181, '홍장암', '문화유적', 0.0, '3', '강원 강릉시 저동 2-4', 37.8012114, 128.9029517],
#  [182,
#   '칠성저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 어단리',
#   37.6785816,
#   128.89343689999998],
#  [183,
#   '파도여행펜션게스트하우스',
#   '게스트하우스',
#   2.7,
#   '1',
#   '강원 강릉시 창해로2번길 28 2,3층',
#   37.7714436,
#   128.9481777],
#  [185,
#   '강릉초당동유적',
#   '유적지',
#   0.0,
#   '0',
#   '강원 강릉시 초당동 84-2',
#   37.7861761,
#   128.91651159999998],
#  [186,
#   '칠봉산',
#   '산',
#   0.0,
#   '1',
#   '강원 강릉시 구정면 제비리 산 173',
#   37.71571429999999,
#   128.84769690000002],
#  [187, '임경당', '유적지', 0.0, '0', '강원 강릉시 성산면 금산리 445', 37.7397432, 128.8513939],
#  [188,
#   '대굴령전통먹거리마을',
#   '관광단지',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 삼왕길 193-22',
#   37.759688700000005,
#   128.7917403],
#  [189,
#   '강릉부관아',
#   '종교유적지',
#   0.0,
#   '0',
#   '강원 강릉시 임영로131번길 6',
#   37.7531104,
#   128.8917655],
#  [190,
#   '대굴령마을',
#   '관광,명소',
#   5.0,
#   '1',
#   '강원 강릉시 성산면 성연로 17',
#   37.7228451,
#   128.8151159],
#  [191, '월파정', '문화유적', 4.3, '2', '강원 강릉시 초당동 549', 37.7971771, 128.904666],
#  [193,
#   '화부산사',
#   '사당,제단',
#   0.0,
#   '0',
#   '강원 강릉시 교동 727-5',
#   37.767759399999996,
#   128.89113329999998],
#  [194,
#   '호해정',
#   '관광,명소',
#   0.0,
#   '1',
#   '강원 강릉시 저동 433',
#   37.801649700000006,
#   128.8969977],
#  [195,
#   '강릉서지조진사댁',
#   '유적지',
#   4.0,
#   '0',
#   '강원 강릉시 난곡길76번길 43-9',
#   37.791393799999994,
#   128.88095900000002],
#  [196, '마명산', '산', 0.0, '0', '강원 강릉시 유천동 276-1', 37.7665253, 128.866322],
#  [197, '칠사당', '유적지', 0.0, '5', '강원 강릉시 경강로 2045', 37.7517814, 128.8918926],
#  [198, '모산봉', '산봉우리', 0.0, '2', '강원 강릉시 박월동 산 8-1', 37.7335356, 128.9058504],
#  [200,
#   '하슬라아트월드 바다정원',
#   '테마파크시설',
#   0.0,
#   '1',
#   '강원 강릉시 강동면 율곡로 1441',
#   37.7056021,
#   129.0080007],
#  [201,
#   '소황병산',
#   '산',
#   0.0,
#   '4',
#   '강원 강릉시 연곡면 삼산리 산 333',
#   37.83994939999999,
#   128.6566871],
#  [202, '죽헌저수지', '저수지', 0.0, '0', '강원 강릉시 죽헌동', 37.7813425, 128.8562267],
#  [203,
#   '보현사낭원대사오진탑',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 보현길 396',
#   37.736917,
#   128.7698582],
#  [204, '환선정', '관광,명소', 5.0, '0', '강원 강릉시 포남동 146-3', 37.785125, 128.9055],
#  [205,
#   '땅골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [206,
#   '무다리골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 장덕리',
#   37.873587799999996,
#   128.7797776],
#  [207, '경포저수지', '저수지', 0.0, '0', '강원 강릉시 죽헌동', 37.7813425, 128.8562267],
#  [208,
#   '신사임당동상',
#   '동상',
#   0.0,
#   '0',
#   '강원 강릉시 죽헌동 177-4',
#   37.777881799999996,
#   128.8769118],
#  [209,
#   '강릉 굴산사지석불좌상',
#   '불상,석불',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 학산리',
#   37.708818799999996,
#   128.890621],
#  [210,
#   '삼거리',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 안인리',
#   37.73289820000001,
#   128.97692320000002],
#  [211,
#   '허균문학비 허난설헌시비',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 초당동 472-2',
#   37.79364,
#   128.9081449],
#  [212,
#   '관음리오층석탑',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 관음리 774',
#   37.7480617,
#   128.82642420000002],
#  [213,
#   '대관령옛주막터',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 어흘리',
#   37.7107204,
#   128.7795353],
#  [214, '충혼탑', '탑,비석', 0.0, '2', '강원 강릉시 저동', 37.7981294, 128.8925034],
#  [215,
#   '미림식물원',
#   '수목원,식물원',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 공제로 241',
#   37.735609000000004,
#   128.8501088],
#  [216,
#   '방터골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 목계리',
#   37.625665999999995,
#   128.8625156],
#  [217,
#   '용연동 마을관리휴양지',
#   '유원지',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 중앙서로 657',
#   37.8057096,
#   128.8193664],
#  [219,
#   '금강산성',
#   '산성,성곽',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 1-1',
#   37.83994939999999,
#   128.6566871],
#  [220,
#   '강릉임영관 객사',
#   '문화유적',
#   5.0,
#   '0',
#   '강원 강릉시 임영로131번길 6 외 10',
#   37.7531104,
#   128.8917655],
#  [222,
#   '운산리은행나무',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 운산동 산 331-7',
#   37.7310404,
#   128.9283561],
#  [223, '두로봉', '산봉우리', 0.0, '1', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [224, '경호정', '문화유적', 0.0, '0', '강원 강릉시 경포로371번길 49', 37.7991683, 128.8985472],
#  [225, '서지골', '계곡', 0.0, '0', '강원 강릉시 난곡동', 37.7908354, 128.8784577],
#  [226,
#   '강릉 산계리석탑',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 1232',
#   37.5789,
#   128.94787250000002],
#  [227,
#   '강릉선교장 활래정',
#   '문화유적',
#   4.0,
#   '0',
#   '강원 강릉시 운정길 63',
#   37.7865935,
#   128.8851277],
#  [228,
#   '자병산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 산 428',
#   37.5789,
#   128.94787250000002],
#  [229,
#   '강릉반송댁',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 초당순두부길58번길 10',
#   37.7878506,
#   128.9146011],
#  [230,
#   '용수폭포',
#   '폭포',
#   3.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 1-12',
#   37.83994939999999,
#   128.6566871],
#  [231, '버들고개', '고개', 0.0, '0', '강원 강릉시 성산면 산북리', 37.7030827, 128.8381761],
#  [232,
#   '시간여행스파펜션',
#   '펜션',
#   0.0,
#   '2',
#   '강원 강릉시 사천면 해안로 1151',
#   37.833163,
#   128.8770374],
#  [233,
#   '방동리 무궁화',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 가마골길 22-8',
#   37.827501700000006,
#   128.8638129],
#  [234,
#   '바람부리',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [235,
#   '평화의소녀상',
#   '동상',
#   0.0,
#   '1',
#   '강원 강릉시 저동 645 경포 3·1운동기념공원 내',
#   37.795036100000004,
#   128.8966374],
#  [237, '대창리당간지주', '문화유적', 0.0, '1', '강원 강릉시 옥천동 334', 37.7608127, 128.901195],
#  [238,
#   '향호지 수변로',
#   '숲',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 향호리 1063-2',
#   37.8996511,
#   128.7843327],
#  [239,
#   '등명락가사 등명약수터',
#   '샘터,약수터',
#   0.0,
#   '1',
#   '강원 강릉시 강동면 정동진리 547-14',
#   37.689200799999995,
#   129.0243271],
#  [240,
#   '강릉송라사 석조약사여래좌상',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 송라길 63-20',
#   37.86038569999999,
#   128.82099],
#  [241,
#   '기마봉 데크전망대',
#   '전망대',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 금진리 산 54-1',
#   37.655025099999996,
#   129.0292957],
#  [242,
#   '국립대관령자연휴양림 잔디광장',
#   '광장',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 어흘리 산 368',
#   37.710246500000004,
#   128.7877344],
#  [243, '퇴곡이리', '계곡', 0.0, '0', '강원 강릉시 연곡면 퇴곡리', 37.854748, 128.7321447],
#  [244, '학우리골', '계곡', 0.0, '0', '강원 강릉시 학동', 37.75495170000001, 128.9326169],
#  [245, '옥천동은행나무', '문화유적', 4.5, '0', '강원 강릉시 옥천동 61', 37.7549315, 128.8989856],
#  [246, '황산사', '사당,제단', 0.0, '0', '강원 강릉시 운정길21번길 27', 37.7868031, 128.8813348],
#  [248,
#   '김윤기가옥',
#   '생가,고택',
#   0.0,
#   '1',
#   '강원 강릉시 노가니길 55-11',
#   37.747787100000004,
#   128.9032554],
#  [249,
#   '소금강약용식물원',
#   '수목원,식물원',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 소금강길 13-42',
#   37.841959100000004,
#   128.7054861],
#  [250,
#   '상임경당',
#   '유적지',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 갈매간길 8-3',
#   37.734777799999996,
#   128.8417129],
#  [251,
#   '화란봉',
#   '산봉우리',
#   0.0,
#   '1',
#   '강원 강릉시 왕산면 왕산리 산 2',
#   37.64150479999999,
#   128.79538159999998],
#  [252, '구라미골', '계곡', 0.0, '0', '강원 강릉시 사천면 석교리', 37.8327442, 128.8192363],
#  [253,
#   '향호지 제방',
#   '방조제',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 향호리 891-1',
#   37.8996511,
#   128.7843327],
#  [254, '송천계곡', '계곡', 0.0, '0', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [255,
#   '만물상',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 333',
#   37.83994939999999,
#   128.6566871],
#  [256,
#   '본동골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 산대월리',
#   37.8140851,
#   128.87542520000002],
#  [257,
#   '신복사지 석조보살좌상',
#   '불상,석불',
#   0.0,
#   '0',
#   '강원 강릉시 내곡동 403-2',
#   37.7427739,
#   128.8855576],
#  [258,
#   '강릉방해정',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 경포로 449',
#   37.80075679999999,
#   128.90184250000001],
#  [259,
#   '김동명시비',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 노동리 71',
#   37.8204135,
#   128.8381184],
#  [260,
#   '섬석천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 청량동 512-3',
#   37.74342620000001,
#   128.9210731],
#  [261, '하제민원', '계곡', 0.0, '0', '강원 강릉시 성산면 어흘리', 37.7107204, 128.7795353],
#  [262,
#   '신리천',
#   '하천',
#   0.0,
#   '1',
#   '강원 강릉시 주문진읍 삼교리',
#   37.8860651,
#   128.72118079999998],
#  [263, '원통골', '계곡', 0.0, '0', '강원 강릉시 죽헌동', 37.7813425, 128.8562267],
#  [264,
#   '강릉김윤기가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 유죽길465번길 35',
#   37.7831665,
#   128.86848700000002],
#  [265, '오봉산', '산', 0.0, '0', '강원 강릉시 성산면 어흘리 산 341', 37.708702, 128.7984639],
#  [266,
#   '보광가족관광농원',
#   '관광농원',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 보현길 151-1',
#   37.7382356,
#   128.7912905],
#  [267, '강릉남대천', '하천', 0.0, '2', '강원 강릉시 성산면 구산리', 37.7193495, 128.8287811],
#  [268, '강릉남대천', '하천', 0.0, '1', '강원 강릉시 입암동', 37.7553367, 128.9152179],
#  [269,
#   '땅재봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 유천동 산 207',
#   37.76394030000001,
#   128.863257],
#  [270, '춘갑봉', '산봉우리', 0.0, '0', '강원 강릉시 포남동', 37.774855200000005, 128.9078407],
#  [271, '담정계곡', '계곡', 0.0, '0', '강원 강릉시 강동면 언별리', 37.6645164, 128.9241222],
#  [272, '낙풍천', '하천', 0.0, '1', '강원 강릉시 옥계면 낙풍리', 37.6247828, 129.0127625],
#  [273,
#   '매봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 신왕리 산 1',
#   37.792700399999994,
#   128.7474389],
#  [274,
#   '피래산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 임곡리 산 194',
#   37.65292609999999,
#   128.97330159999999],
#  [275,
#   '장덕고개',
#   '고개',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 장덕리',
#   37.873587799999996,
#   128.7797776],
#  [276,
#   '합궁골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 금진리 산 6',
#   37.657684100000004,
#   129.0536707],
#  [277,
#   '등명락가사 등명사지오층석탑',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 565',
#   37.689200799999995,
#   129.0243271],
#  [278,
#   '명주최보영가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 작은다리길 16',
#   37.8904559,
#   128.8261249],
#  [279,
#   '노추산로',
#   '드라이브코스',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 2929-5',
#   37.57821989999999,
#   128.7490804],
#  [280,
#   '소금강산',
#   '산',
#   5.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 333',
#   37.83994939999999,
#   128.6566871],
#  [281,
#   '올림픽아리바우길 4코스',
#   '도보여행',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [282, '초막골', '계곡', 0.0, '0', '강원 강릉시 성산면 어흘리', 37.7107204, 128.7795353],
#  [283,
#   '영진리고분군',
#   '릉,묘,총',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 영진리 산 40',
#   37.86510579999999,
#   128.8464844],
#  [284,
#   '강릉대도호부 아문',
#   '문',
#   0.0,
#   '0',
#   '강원 강릉시 성내동 27-1',
#   37.752491299999996,
#   128.8922665],
#  [285,
#   '주문진리조트 퍼팅장',
#   '호수',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 향호리 8-57',
#   37.9121357,
#   128.8173057],
#  [286,
#   '강릉선교장 열화당',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 운정길 63',
#   37.7865935,
#   128.8851277],
#  [287,
#   '최대석가옥',
#   '유적지',
#   0.0,
#   '0',
#   '강원 강릉시 모산로224번길 55-12',
#   37.73248239999999,
#   128.90607690000002],
#  [288,
#   '옥계굴',
#   '동굴',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 산 428',
#   37.5789,
#   128.94787250000002],
#  [289,
#   '궁궁동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 삼교리',
#   37.8860651,
#   128.72118079999998],
#  [290, '강릉남대천', '하천', 0.0, '1', '강원 강릉시 구정면 제비리', 37.7203412, 128.8525517],
#  [291, '오리바위', '바위', 4.5, '0', '강원 강릉시 안현동', 37.801911100000005, 128.8758249],
#  [292,
#   '정동진천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [293, '시루봉', '산봉우리', 0.0, '1', '강원 강릉시 난곡동 산 5', 37.7940612, 128.8845196],
#  [294,
#   '6.25 남침사적탑',
#   '탑,비석',
#   0.0,
#   '1',
#   '강원 강릉시 강동면 정동진리 524-14',
#   37.7079586,
#   129.012171],
#  [295, '경포로', '드라이브코스', 0.0, '0', '강원 강릉시 운정동', 37.7880229, 128.8952955],
#  [296,
#   '비선굴',
#   '동굴',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 산 415',
#   37.5789,
#   128.94787250000002],
#  [297,
#   '석병산 샘터',
#   '샘터,약수터',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리',
#   37.5789,
#   128.94787250000002],
#  [298,
#   '고성산',
#   '산',
#   5.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 267-4',
#   37.689200799999995,
#   129.0243271],
#  [299, '강릉수리골고택', '생가,고택', 0.0, '1', '강원 강릉시 운정길 123', 37.786017, 128.8910834],
#  [300, '갯골', '계곡', 0.0, '0', '강원 강릉시 주문진읍 향호리', 37.8996511, 128.7843327],
#  [301, '주수천', '하천', 0.0, '0', '강원 강릉시 옥계면 조산리', 37.6230244, 129.052086],
#  [302,
#   '강릉보광리 석조여래좌상',
#   '불상,석불',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 삼왕길 139-98',
#   37.75216339999999,
#   128.78593850000001],
#  [303,
#   '당두공원길',
#   '도보여행',
#   0.0,
#   '0',
#   '강원 강릉시 교동 산 132-1',
#   37.76772709999999,
#   128.896816],
#  [304,
#   '태장봉',
#   '산봉우리',
#   0.0,
#   '1',
#   '강원 강릉시 대전동 산 41-3',
#   37.795079799999996,
#   128.857649],
#  [305,
#   '바우길부대담장길',
#   '도보여행',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 참샘길 38',
#   37.91364069999999,
#   128.80619879999998],
#  [306,
#   '삼폭포',
#   '폭포',
#   4.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 1-12',
#   37.83994939999999,
#   128.6566871],
#  [308,
#   '유니온관광 정동진역',
#   '관광,명소',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 329-1',
#   37.689512,
#   129.03202620000002],
#  [309, '오죽헌지', '저수지', 0.0, '0', '강원 강릉시 운정동', 37.7880229, 128.8952955],
#  [310,
#   '옥녀봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 남양리',
#   37.561585799999996,
#   129.00788290000003],
#  [311, '애골', '계곡', 0.0, '0', '강원 강릉시 주문진읍 교항리', 37.8789811, 128.8177091],
#  [312, '납들', '계곡', 0.0, '0', '강원 강릉시 신석동', 37.7312956, 128.9242578],
#  [314,
#   '산계소류지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리',
#   37.5789,
#   128.94787250000002],
#  [315, '활래정', '생가,고택', 3.0, '0', '강원 강릉시 운정길 107-22', 37.786497, 128.8879001],
#  [316,
#   '옹기백화점',
#   '도자기,도예촌',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로 3049',
#   37.7739052,
#   128.8885134],
#  [317,
#   '낙영폭포',
#   '폭포',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 산 1-12',
#   37.83994939999999,
#   128.6566871],
#  [318, '교동', '계곡', 0.0, '0', '강원 강릉시 옥계면 현내리', 37.6089752, 129.0291988],
#  [319, '안고단', '계곡', 0.0, '0', '강원 강릉시 왕산면 고단리', 37.5327984, 128.8232836],
#  [320,
#   '강릉대공산성',
#   '산성,성곽',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 보광리 산 544',
#   37.7369414,
#   128.7691585],
#  [321, '강골', '계곡', 0.0, '0', '강원 강릉시 안현동', 37.801911100000005, 128.8758249],
#  [322,
#   '계련당',
#   '유적지',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로 2920-12',
#   37.7633184,
#   128.89314679999998],
#  [323,
#   '강릉최씨동원군종택',
#   '생가,고택',
#   0.0,
#   '1',
#   '강원 강릉시 주문진읍 신리천로 192-3',
#   37.8787049,
#   128.81124340000002],
#  [324, '대포동', '계곡', 0.0, '0', '강원 강릉시 강동면 안인진리', 37.728188, 128.9866112],
#  [325,
#   '삼산리소나무',
#   '문화유적',
#   1.0,
#   '0',
#   '강원 강릉시 연곡면 삼산리 116',
#   37.827806,
#   128.6553172],
#  [326, '대궁산', '산', 0.0, '1', '강원 강릉시 사천면 사기막리 산 1', 37.7667604, 128.7500686],
#  [327,
#   '까치골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [328,
#   '죽도봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 강문동',
#   37.789733899999995,
#   128.92000009999998],
#  [329, '문묘 대성전', '향교,서당', 0.0, '0', '강원 강릉시 명륜로 29', 37.7634, 128.895101],
#  [330, '질골', '계곡', 0.0, '0', '강원 강릉시 사천면 방동리', 37.82181, 128.86641029999998],
#  [331, '임영고개', '고개', 0.0, '0', '강원 강릉시 교동', 37.7670917, 128.88662490000002],
#  [332, '경양사', '사당,제단', 0.0, '0', '강원 강릉시 저동길 113', 37.7961797, 128.8903459],
#  [333,
#   '쌍한정',
#   '관광,명소',
#   0.0,
#   '2',
#   '강원 강릉시 사천면 해안로 918',
#   37.8321683,
#   128.8751217],
#  [334, '뒷섬', '섬(내륙)', 2.0, '0', '강원 강릉시 사천면 사천진리', 37.8435195, 128.8684982],
#  [335,
#   '왕산천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 왕산리',
#   37.651880600000005,
#   128.7800211],
#  [336,
#   '강릉수문리당간지주',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 옥천동 43-9',
#   37.75644260000001,
#   128.90380770000002],
#  [337, '모학당', '생가,고택', 0.0, '0', '강원 강릉시 모산로 170-52', 37.7264305, 128.9039352],
#  [338,
#   '굴산사지 승탑',
#   '탑,비석',
#   0.0,
#   '2',
#   '강원 강릉시 구정면 금평로 118-32',
#   37.707634999999996,
#   128.88687109999998],
#  [339, '연곡천', '하천', 0.0, '0', '강원 강릉시 연곡면 퇴곡리', 37.854748, 128.7321447],
#  [340,
#   '바우길183고지',
#   '도보여행',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 산 103-1',
#   37.687172499999996,
#   129.0376985],
#  [341, '새목재', '고개', 0.0, '0', '강원 강릉시 왕산면 고단리', 37.5327984, 128.8232836],
#  [342,
#   '매봉산',
#   '산',
#   0.0,
#   '0',
#   '강원 동해시 비천동 산 41',
#   37.544546999999994,
#   129.029092],
#  [343,
#   '동주최씨제실',
#   '사당,제단',
#   0.0,
#   '0',
#   '강원 강릉시 성덕로176번길 6',
#   37.7615746,
#   128.9342113],
#  [344,
#   '망덕봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 언별리 산 274-1',
#   37.6657836,
#   128.9188331],
#  [345,
#   '보광리분청자요지',
#   '유적지',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 보광리 711-2',
#   37.765897700000004,
#   128.7909189],
#  [346, '강릉남대천', '하천', 0.0, '1', '강원 강릉시 회산동', 37.73815, 128.863319],
#  [347,
#   '함대식가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 위촌길 216-3',
#   37.7599486,
#   128.84525520000003],
#  [348,
#   '장천마을휴양지',
#   '관광,명소',
#   1.0,
#   '2',
#   '강원 강릉시 연곡면 진고개로 1502',
#   37.8465424,
#   128.7045957],
#  [349, '큰골', '계곡', 0.0, '0', '강원 강릉시 왕산면 도마리', 37.6597088, 128.83178059999997],
#  [350,
#   '하슬라아트월드 소나무정원',
#   '테마파크시설',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 율곡로 1441',
#   37.7056021,
#   129.0080007],
#  [351,
#   '삿갓봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 북동리 산 525-2',
#   37.601535,
#   128.9511971],
#  [352,
#   '박치규가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 미노리 111',
#   37.83032539999999,
#   128.86652560000002],
#  [353,
#   '삼우봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 산 17',
#   37.711249200000005,
#   129.0063317],
#  [354, '강릉남대천', '하천', 0.0, '1', '강원 강릉시 내곡동', 37.7390776, 128.8808633],
#  [355,
#   '덕우리재',
#   '고개',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 북동리',
#   37.6226354,
#   128.96262190000002],
#  [356, '탑동', '계곡', 0.0, '0', '강원 강릉시 왕산면 도마리', 37.6597088, 128.83178059999997],
#  [357,
#   '터미널관광안내소',
#   '관광안내소',
#   0.0,
#   '0',
#   '강원 강릉시 하슬라로 27',
#   37.7546716,
#   128.878003],
#  [358,
#   '밥봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 천남리 산 76',
#   37.599574100000005,
#   129.0517793],
#  [359,
#   '강릉시호고택',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 시동길 91-9',
#   37.73483710000001,
#   128.95777379999998],
#  [360, '절골', '계곡', 0.0, '0', '강원 강릉시 구정면 제비리', 37.7203412, 128.8525517],
#  [361,
#   '모래시계 관광안내소',
#   '관광안내소',
#   0.0,
#   '1',
#   '강원 강릉시 강동면 정동진리 7-1',
#   37.689512,
#   129.03202620000002],
#  [362,
#   '강릉이광노가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 난설헌로193번길 1-16',
#   37.7919383,
#   128.9092743],
#  [363,
#   '강릉김재성가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 지변길 175-12',
#   37.777260999999996,
#   128.8723014],
#  [364,
#   '장작골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 모전리',
#   37.71053029999999,
#   128.9755973],
#  [365,
#   '석두봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 산 1-1',
#   37.57821989999999,
#   128.7490804],
#  [366,
#   '한송사지석불좌상',
#   '불상,석불',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [367, '십리바위', '바위', 5.0, '1', '강원 강릉시 안현동', 37.801911100000005, 128.8758249],
#  [368,
#   '대기천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [369,
#   '강릉오금집',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 강릉대로210번길 23-9',
#   37.7562985,
#   128.89398500000001],
#  [370, '경포천', '하천', 0.0, '0', '강원 강릉시 대전동', 37.79388970000001, 128.8550747],
#  [371,
#   '피덕령',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [372,
#   '서대굴',
#   '동굴',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 산 428',
#   37.5789,
#   128.94787250000002],
#  [373,
#   '안현천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 산대월리',
#   37.8140851,
#   128.87542520000002],
#  [374,
#   '청학산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 산성우리 산 273',
#   37.6845435,
#   128.98680259999998],
#  [375,
#   '모정탑길',
#   '도보여행',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [376, '벌말', '계곡', 0.0, '0', '강원 강릉시 왕산면 대기리', 37.57821989999999, 128.7490804],
#  [377,
#   '왕고개',
#   '고개',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 여찬리',
#   37.7209372,
#   128.87483319999998],
#  [378,
#   '강릉역 관광통역안내센터',
#   '관광안내소',
#   0.0,
#   '0',
#   '강원 강릉시 용지로 176',
#   37.763599600000006,
#   128.8989373],
#  [379,
#   '방아다리골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 판교리',
#   37.839308700000004,
#   128.854862],
#  [380,
#   '석병산 서당바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리',
#   37.5789,
#   128.94787250000002],
#  [381,
#   '석화동굴',
#   '동굴',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 산 428',
#   37.5789,
#   128.94787250000002],
#  [382,
#   '남양천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 천남리',
#   37.601915399999996,
#   129.0410603],
#  [383, '동대굴', '동굴', 0.0, '0', '강원 강릉시 옥계면 산계리 산 257', 37.5819309, 128.9464449],
#  [384, '보진당', '유적지', 0.0, '0', '강원 강릉시 은행나무길 9', 37.7551713, 128.8987343],
#  [385,
#   '사달산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 산 3',
#   37.570945200000004,
#   128.7406375],
#  [386,
#   '고려성',
#   '산성,성곽',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 508-1',
#   37.685305299999996,
#   129.0375618],
#  [387,
#   '삼한성지',
#   '산성,성곽',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 산성우리 산 229-1',
#   37.678010799999996,
#   129.01956909999998],
#  [388,
#   '명주김득래가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 왕고개길 66-15',
#   37.7204093,
#   128.88561570000002],
#  [389, '청량골', '계곡', 0.0, '0', '강원 강릉시 청량동', 37.74485620000001, 128.9257744],
#  [390,
#   '칠성골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 어단리',
#   37.6785816,
#   128.89343689999998],
#  [391,
#   '해수박골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 삼교리',
#   37.8860651,
#   128.72118079999998],
#  [392,
#   '취영정',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 강문동 269',
#   37.7974566,
#   128.91374979999998],
#  [393,
#   '오성정',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 강변로 224-12',
#   37.747301799999995,
#   128.89339679999998],
#  [394,
#   '뱀골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 유등리',
#   37.819581799999995,
#   128.7454661],
#  [395, '큰가마골', '계곡', 0.0, '0', '강원 강릉시 성산면 어흘리', 37.7107204, 128.7795353],
#  [396,
#   '증산소류지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 남양리',
#   37.561585799999996,
#   129.00788290000003],
#  [397, '경포골', '계곡', 0.0, '0', '강원 강릉시 저동', 37.7981294, 128.8925034],
#  [398, '갓바위골', '계곡', 0.0, '0', '강원 강릉시 성산면 보광리', 37.74729, 128.78251880000002],
#  [399, '작은골길', '계곡', 0.0, '0', '강원 강릉시 옥계면 도직리', 37.605498, 129.0626627],
#  [400, '지암골', '계곡', 0.0, '0', '강원 강릉시 성산면 송암리', 37.7762297, 128.8309174],
#  [401,
#   '향현사',
#   '사당,제단',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로 2920-16',
#   37.7634402,
#   128.8937134],
#  [402, '금광천', '하천', 0.0, '0', '강원 강릉시 박월동', 37.728406400000004, 128.9108081],
#  [403,
#   '남대굴',
#   '동굴',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 1170',
#   37.5789,
#   128.94787250000002],
#  [405,
#   '대화실산',
#   '산',
#   0.0,
#   '1',
#   '강원 강릉시 왕산면 대기리 산 1-12',
#   37.57821989999999,
#   128.7490804],
#  [406,
#   '높은다리골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 보광리',
#   37.74729,
#   128.78251880000002],
#  [408,
#   '고곡동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 관음리',
#   37.74101539999999,
#   128.82543020000003],
#  [409,
#   '황산골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 왕산리',
#   37.651880600000005,
#   128.7800211],
#  [410, '임곡천', '하천', 0.0, '0', '강원 강릉시 강동면 임곡리', 37.6641691, 128.9612013],
#  [411,
#   '도마천',
#   '하천',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 목계리',
#   37.625665999999995,
#   128.8625156],
#  [412, '군선천', '하천', 0.0, '0', '강원 강릉시 강동면 언별리', 37.6645164, 128.9241222],
#  [414,
#   '별빛여행펜션',
#   '펜션',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 들꽃마을길 18',
#   37.6499273,
#   128.8558331],
#  [415, '우경골', '계곡', 0.0, '0', '강원 강릉시 입암동', 37.7553367, 128.9152179],
#  [416,
#   '절골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 천남리',
#   37.601915399999996,
#   129.0410603],
#  [417, '바두재', '고개', 0.0, '0', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [418, '보리골', '계곡', 0.0, '0', '강원 강릉시 주문진읍 교항리', 37.8789811, 128.8177091],
#  [419,
#   '나리골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리',
#   37.689200799999995,
#   129.0243271],
#  [420, '강릉시', '계곡', 0.0, '0', '강원 강릉시 주문진읍 향호리', 37.8996511, 128.7843327],
#  [421, '쟁골저수지', '저수지', 0.0, '0', '강원 강릉시 강동면 상시동리', 37.7209898, 128.9481805],
#  [422, '경포천', '하천', 0.0, '0', '강원 강릉시 성산면 송암리', 37.7762297, 128.8309174],
#  [423,
#   '망운산',
#   '산',
#   5.0,
#   '1',
#   '강원 강릉시 옥계면 남양리 산 795-1',
#   37.585021399999995,
#   129.05583059999998],
#  [424,
#   '김남명가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 하시동리 36',
#   37.747057500000004,
#   128.9574559],
#  [425, '몽탕골', '계곡', 0.0, '0', '강원 강릉시 옥계면 낙풍리', 37.6247828, 129.0127625],
#  [426,
#   '숭덕재',
#   '릉,묘,총',
#   0.0,
#   '0',
#   '강원 강릉시 동해대로 699-25',
#   37.800638799999994,
#   128.8601456],
#  [427, '싸래골', '계곡', 0.0, '0', '강원 강릉시 주문진읍 주문리', 37.8990315, 128.8227808],
#  [428, '위촌저류지', '저수지', 0.0, '1', '강원 강릉시 죽헌동', 37.7813425, 128.8562267],
#  [429,
#   '신사임당초서병풍',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [430, '할미집골', '계곡', 0.0, '0', '강원 강릉시 왕산면 고단리', 37.5327984, 128.8232836],
#  [431, '진골', '계곡', 0.0, '0', '강원 강릉시 구정면 제비리', 37.7203412, 128.8525517],
#  [432,
#   '버금골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 장덕리',
#   37.873587799999996,
#   128.7797776],
#  [433,
#   '대공산성',
#   '산성,성곽',
#   0.0,
#   '1',
#   '강원 강릉시 성산면 보광리 산 544',
#   37.7369414,
#   128.7691585],
#  [434, '서당골', '계곡', 0.0, '0', '강원 강릉시 성산면 보광리', 37.74729, 128.78251880000002],
#  [435,
#   '눈물바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 학산리',
#   37.708818799999996,
#   128.890621],
#  [436, '넙은골', '계곡', 0.0, '0', '강원 강릉시 회산동', 37.73815, 128.863319],
#  [437,
#   '창랑정',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 강문동 258-14',
#   37.803507700000004,
#   128.9086246],
#  [438,
#   '오봉저수지',
#   '저수지',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 오봉리',
#   37.706627399999995,
#   128.8142664],
#  [439, '작은도추골', '계곡', 0.0, '0', '강원 강릉시 운산동', 37.7262976, 128.93377949999999],
#  [440,
#   '덕실골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 덕실리',
#   37.805178399999996,
#   128.8410131],
#  [441,
#   '용금정',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 어단리 1141',
#   37.7027596,
#   128.9102761],
#  [442, '옥녀봉', '산봉우리', 0.0, '0', '강원 평창군 대관령면 수하리', 37.6196502, 128.7042174],
#  [443,
#   '노추산등산코스',
#   '등산로',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 산 3',
#   37.570945200000004,
#   128.7406375],
#  [444, '동대산 샘터', '샘터,약수터', 0.0, '0', '강원 강릉시 연곡면 삼산리', 37.827806, 128.6553172],
#  [445,
#   '산계리금옥계방 역사적비및종선비',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 산계리 787',
#   37.5789,
#   128.94787250000002],
#  [446, '서리바웃골', '계곡', 0.0, '0', '강원 강릉시 대전동', 37.79388970000001, 128.8550747],
#  [447,
#   '새끼뫼',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 여찬리',
#   37.7209372,
#   128.87483319999998],
#  [448, '갈보데이', '계곡', 0.0, '0', '강원 강릉시 강동면 임곡리', 37.6641691, 128.9612013],
#  [449, '돼지밭골', '계곡', 0.0, '0', '강원 강릉시 성산면 어흘리', 37.7107204, 128.7795353],
#  [450, '음달말골', '계곡', 0.0, '0', '강원 강릉시 성산면 산북리', 37.7030827, 128.8381761],
#  [451, '경포천', '하천', 0.0, '0', '강원 강릉시 운정동', 37.7880229, 128.8952955],
#  [452, '노양골', '계곡', 0.0, '0', '강원 강릉시 옥계면 금진리', 37.6432124, 129.0367071],
#  [453, '소토골', '계곡', 0.0, '0', '강원 강릉시 대전동', 37.79388970000001, 128.8550747],
#  [454,
#   '방내리삼층석탑',
#   '탑,비석',
#   3.0,
#   '0',
#   '강원 강릉시 연곡면 향교말길 22',
#   37.8576074,
#   128.8255764],
#  [455,
#   '대양산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 정동진리 산 72',
#   37.687172499999996,
#   129.0376985],
#  [456,
#   '매봉산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 송현리 산 242-1',
#   37.5769162,
#   128.8441635],
#  [457, '금란정', '문화유적', 0.0, '0', '강원 강릉시 경포로371번길 57', 37.7995585, 128.8993593],
#  [458,
#   '생쥐골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 연곡면 송림리',
#   37.8521881,
#   128.81237099999998],
#  [459,
#   '강릉선교장 안채주옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 운정길 63',
#   37.7865935,
#   128.8851277],
#  [460,
#   '장기바위',
#   '바위',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 목계리',
#   37.625665999999995,
#   128.8625156],
#  [461, '사화산', '산', 0.0, '0', '강원 강릉시 사천면 판교리 561-1', 37.8402891, 128.8495217],
#  [462, '자조와리', '계곡', 0.0, '0', '강원 강릉시 내곡동', 37.7390776, 128.8808633],
#  [463,
#   '태봉산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 모전리 산 259',
#   37.718545500000005,
#   128.96422900000002],
#  [464,
#   '전충사',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 저동길100번길 56-10',
#   37.7944081,
#   128.89477779999999],
#  [465, '속동산', '산', 0.0, '0', '강원 강릉시 강동면 심곡리 1-78', 37.6672988, 129.0416628],
#  [466, '장적골', '계곡', 0.0, '0', '강원 강릉시 강동면 언별리', 37.6645164, 128.9241222],
#  [467, '절골', '계곡', 0.0, '0', '강원 강릉시 연곡면 송림리', 37.8521881, 128.81237099999998],
#  [468, '구래골', '계곡', 5.0, '0', '강원 강릉시 사천면 노동리', 37.8158224, 128.8147526],
#  [469, '괴병산', '산', 0.0, '0', '강원 강릉시 왕산면 대기리 1719-1', 37.5881597, 128.7783093],
#  [470,
#   '둔치마을',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 도마리',
#   37.6597088,
#   128.83178059999997],
#  [471,
#   '매봉산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 어단리 산 362',
#   37.666918200000005,
#   128.8867933],
#  [472,
#   '동산리',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 천남리',
#   37.601915399999996,
#   129.0410603],
#  [473,
#   '송이골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 삼교리',
#   37.8860651,
#   128.72118079999998],
#  [474, '여우골', '계곡', 0.0, '0', '강원 강릉시 주문진읍 향호리', 37.8996511, 128.7843327],
#  [475,
#   '나팔재산',
#   '산',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 남양리 산 324-1',
#   37.5450468,
#   128.99559250000001],
#  [476, '산두골', '계곡', 0.0, '0', '강원 강릉시 성산면 산북리', 37.7030827, 128.8381761],
#  [477,
#   '허균허난설헌공원 오문장비',
#   '탑,비석',
#   0.0,
#   '0',
#   '강원 강릉시 초당동 474-9',
#   37.7912213,
#   128.9092382],
#  [478,
#   '개매리골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 강동면 산성우리',
#   37.66371229999999,
#   129.0034209],
#  [479,
#   '최근배가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로 2669-6',
#   37.7466845,
#   128.9107185],
#  [480, '안고개', '고개', 0.0, '0', '강원 강릉시 안현동', 37.801911100000005, 128.8758249],
#  [481, '한밭골', '계곡', 0.0, '0', '강원 강릉시 대전동', 37.79388970000001, 128.8550747],
#  [482, '큰골', '계곡', 0.0, '0', '강원 강릉시 연곡면 행정리', 37.8565524, 128.77651070000002],
#  [483,
#   '정의윤가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 구정면 범일로 283-7',
#   37.715477,
#   128.88706770000002],
#  [484, '이리재', '고개', 0.0, '0', '강원 강릉시 성산면 송암리 20-2', 37.7721411, 128.8416141],
#  [485, '강릉향교 사료관', '향교,서당', 0.0, '0', '강원 강릉시 명륜로 29', 37.7634, 128.895101],
#  [486,
#   '못골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 산대월리',
#   37.8140851,
#   128.87542520000002],
#  [487,
#   '옥녀봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리 산 2-1',
#   37.5881597,
#   128.7783093],
#  [488, '시목골', '계곡', 0.0, '0', '강원 강릉시 유천동', 37.767111299999996, 128.8586435],
#  [489,
#   '이이수필격몽요결',
#   '문화유적',
#   0.0,
#   '0',
#   '강원 강릉시 율곡로3139번길 24 오죽헌시립박물관',
#   37.7780704,
#   128.878503],
#  [490, '절터미골', '계곡', 0.0, '0', '강원 강릉시 구정면 제비리', 37.7203412, 128.8525517],
#  [491,
#   '강릉조광현가옥',
#   '생가,고택',
#   0.0,
#   '0',
#   '강원 강릉시 주문진읍 교항리 863-2',
#   37.8815824,
#   128.81741019999998],
#  [492,
#   '성산봉',
#   '산봉우리',
#   0.0,
#   '0',
#   '강원 강릉시 성산면 산북리 산 4',
#   37.7154955,
#   128.83658459999998],
#  [493, '절골', '계곡', 0.0, '0', '강원 강릉시 왕산면 도마리', 37.6597088, 128.83178059999997],
#  [494, '굴면동', '계곡', 0.0, '0', '강원 강릉시 성산면 어흘리', 37.7107204, 128.7795353],
#  [495, '아랫낙풍', '계곡', 0.0, '0', '강원 강릉시 옥계면 낙풍리', 37.6247828, 129.0127625],
#  [496, '애지골', '계곡', 0.0, '0', '강원 강릉시 입암동', 37.7553367, 128.9152179],
#  [497, '덕우봉', '산봉우리', 0.0, '0', '강원 강릉시 담산동 산 4', 37.7268387, 128.9047547],
#  [498,
#   '이울골',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 사천면 덕실리',
#   37.805178399999996,
#   128.8410131],
#  [499,
#   '아래숯터',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 왕산면 대기리',
#   37.57821989999999,
#   128.7490804],
#  [500, '어심밭골', '계곡', 0.0, '0', '강원 강릉시 구정면 구정리', 37.6879535, 128.8653185],
#  [501,
#   '테라로사 커피공장',
#   '커피전문점',
#   3.5,
#   '871',
#   '강원 강릉시 구정면 현천길 7',
#   37.6960049,
#   128.89188719999999],
#  [502,
#   '엄지네포장마차 본점',
#   '실내포장마차',
#   3.8,
#   '1,597',
#   '강원 강릉시 경강로2255번길 21 엄지빌딩 1층',
#   37.7663374,
#   128.9069912],
#  [503,
#   '곳',
#   '디저트카페',
#   3.6,
#   '443',
#   '강원 강릉시 사천면 진리해변길 143 1~3층',
#   37.839526299999996,
#   128.87401770000002],
#  [504,
#   '테라로사 경포호수점',
#   '커피전문점',
#   3.2,
#   '438',
#   '강원 강릉시 난설헌로 145',
#   37.7868489,
#   128.9060121],
#  [505,
#   '순두부젤라또 1호점',
#   '아이스크림',
#   3.5,
#   '854',
#   '강원 강릉시 초당순두부길 95-5',
#   37.791711299999996,
#   128.9154298],
#  [506,
#   '강릉빵다방 본점',
#   '제과,베이커리',
#   3.4,
#   '445',
#   '강원 강릉시 남강초교1길 24',
#   37.768988799999995,
#   128.9180848],
#  [507,
#   '순두부젤라또 2호점',
#   '아이스크림',
#   3.3,
#   '760',
#   '강원 강릉시 경강로 2642 1~4층',
#   37.77128270000001,
#   128.9471337],
#  [508, '벌집', '국수', 3.2, '377', '강원 강릉시 경강로2069번길 15', 37.7545049, 128.892756],
#  [509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [510,
#   '만동제과',
#   '제과,베이커리',
#   4.7,
#   '260',
#   '강원 강릉시 금성로 6',
#   37.755143200000006,
#   128.89946709999998],
#  [511,
#   '보헤미안박이추커피공장',
#   '커피전문점',
#   3.2,
#   '315',
#   '강원 강릉시 사천면 해안로 1107',
#   37.846880999999996,
#   128.86682040000002],
#  [512,
#   '원조강릉교동반점 본점',
#   '중화요리',
#   3.2,
#   '450',
#   '강원 강릉시 강릉대로 205',
#   37.758351,
#   128.89304280000002],
#  [513,
#   '돌체테리아',
#   '카페',
#   2.2,
#   '253',
#   '강원 강릉시 하슬라로206번길 4-3 1층',
#   37.7676881,
#   128.8761274],
#  [514,
#   '버드나무브루어리',
#   '호프,요리주점',
#   4.0,
#   '304',
#   '강원 강릉시 경강로 1961',
#   37.74822959999999,
#   128.88435959999998],
#  [515,
#   '풍년갈비',
#   '육류,고기',
#   3.7,
#   '1,758',
#   '강원 강릉시 강릉대로587번길 10-5',
#   37.7844299,
#   128.91952120000002],
#  [516,
#   '차현희순두부청국장',
#   '두부전문점',
#   3.4,
#   '367',
#   '강원 강릉시 초당순두부길 96',
#   37.790931799999996,
#   128.9161378],
#  [517,
#   '현대장칼국수',
#   '국수',
#   3.3,
#   '351',
#   '강원 강릉시 임영로182번길 7-1',
#   37.75746029999999,
#   128.8926371],
#  [518,
#   '초당할머니순두부',
#   '두부전문점',
#   2.9,
#   '390',
#   '강원 강릉시 초당순두부길 77',
#   37.7909005,
#   128.9149108],
#  [519,
#   '독도네꼬막 본점',
#   '조개',
#   4.6,
#   '586',
#   '강원 강릉시 옥천로 47 1층',
#   37.759226899999994,
#   128.9004925],
#  [520,
#   '해미가',
#   '회',
#   4.1,
#   '314',
#   '강원 강릉시 솔올로 103',
#   37.7710365,
#   128.87888999999998],
#  [521,
#   '테라로사 사천점',
#   '커피전문점',
#   3.5,
#   '208',
#   '강원 강릉시 사천면 순포안길 6 1, 2층',
#   37.8224255,
#   128.88480800000002],
#  [522,
#   '팔도전복해물뚝배기',
#   '해물,생선',
#   4.6,
#   '342',
#   '강원 강릉시 창해로 375',
#   37.7959574,
#   128.9162884],
#  [523,
#   '테라로사 경포대점',
#   '카페',
#   2.4,
#   '30',
#   '강원 강릉시 창해로 419',
#   37.7989517,
#   128.91428259999998],
#  [524,
#   '삼교리동치미막국수 본점',
#   '국수',
#   3.8,
#   '176',
#   '강원 강릉시 구정면 범일로 364',
#   37.716294,
#   128.8967289],
#  [525,
#   '금학칼국수',
#   '국수',
#   3.0,
#   '263',
#   '강원 강릉시 대학길 12-6',
#   37.75441970000001,
#   128.8962638],
#  [526,
#   '소나무집초당순두부',
#   '두부전문점',
#   2.6,
#   '668',
#   '강원 강릉시 초당순두부길 95-5',
#   37.791711299999996,
#   128.9154298],
#  [527,
#   '동해막국수',
#   '국수',
#   3.6,
#   '103',
#   '강원 강릉시 연곡면 성안길 47-3',
#   37.8592565,
#   128.8314326],
#  [528,
#   '강릉수제버거',
#   '햄버거',
#   4.2,
#   '538',
#   '강원 강릉시 주문진읍 주문북로 222-30 1층',
#   37.91135209999999,
#   128.8176985],
#  [529,
#   '폴&메리 강문점',
#   '햄버거',
#   2.6,
#   '432',
#   '강원 강릉시 창해로350번길 33',
#   37.7967264,
#   128.9168123],
#  [530, '퍼베이드', '카페', 3.8, '320', '강원 강릉시 화부산로 78', 37.7631986, 128.8868236],
#  [531,
#   '강릉중화짬뽕빵',
#   '제과,베이커리',
#   3.2,
#   '540',
#   '강원 강릉시 금성로13번길 17',
#   37.753244200000005,
#   128.90012040000002],
#  [532,
#   '오월',
#   '카페',
#   3.6,
#   '379',
#   '강원 강릉시 경강로2046번길 11-2',
#   37.7507555,
#   128.8931455],
#  [533,
#   '장안회집',
#   '회',
#   3.4,
#   '152',
#   '강원 강릉시 사천면 진리항구길 51',
#   37.8376125,
#   128.8753303],
#  [534,
#   '형제칼국수',
#   '국수',
#   2.8,
#   '319',
#   '강원 강릉시 강릉대로204번길 2',
#   37.7578827,
#   128.89300649999998],
#  [535,
#   '보사노바 강릉본점',
#   '카페',
#   3.8,
#   '266',
#   '강원 강릉시 창해로14번길 28',
#   37.772169700000006,
#   128.94774089999999],
#  [536,
#   '만석닭강정 안목직영점',
#   '닭강정',
#   3.8,
#   '110',
#   '강원 강릉시 창해로2번길 32 2층',
#   37.7713378,
#   128.94855320000002],
#  [537,
#   '이모네생선찜',
#   '해물,생선',
#   3.1,
#   '131',
#   '강원 강릉시 가작로 8',
#   37.76916629999999,
#   128.87642639999999],
#  [538,
#   '커피바다',
#   '카페',
#   4.3,
#   '125',
#   '강원 강릉시 주문진읍 해안로 1822 2층',
#   37.8944925,
#   128.8339037],
#  [539,
#   '삼교리동치미막국수 강릉남항진점',
#   '국수',
#   4.0,
#   '217',
#   '강원 강릉시 공항길127번길 42',
#   37.7655969,
#   128.952542],
#  [540,
#   '김우정 초당짬뽕순두부',
#   '두부전문점',
#   2.1,
#   '376',
#   '강원 강릉시 초당순두부길 114',
#   37.79251199999999,
#   128.9172098],
#  [541,
#   '대영유통',
#   '게,대게',
#   3.8,
#   '938',
#   '강원 강릉시 주문진읍 해안로 1767',
#   37.892841499999996,
#   128.82872340000003],
#  [542,
#   '건도리횟집',
#   '회',
#   3.0,
#   '122',
#   '강원 강릉시 창해로 427',
#   37.799471000000004,
#   128.9136565],
#  [543,
#   '금천칼국수',
#   '국수',
#   3.6,
#   '140',
#   '강원 강릉시 강릉대로 445-1',
#   37.773269799999994,
#   128.9121206],
#  [544,
#   '최대게',
#   '게,대게',
#   3.6,
#   '481',
#   '강원 강릉시 주문진읍 해안로 1729',
#   37.8894492,
#   128.8280805],
#  [545,
#   '카페 뤼미에르',
# ...
#  [876, '진영두부마을', '두부전문점', 5.0, '10', '강원 강릉시 옥가로 20', 37.7579816, 128.8994424],
#  [877,
#   '실비생선구이 2호점',
#   '해물,생선',
#   4.0,
#   '152',
#   '강원 강릉시 주문진읍 해안로 1723',
#   37.88884609999999,
#   128.8281374],
#  [878,
#   '젠주',
#   '카페',
#   3.6,
#   '73',
#   '강원 강릉시 창해로14번길 16 6층',
#   37.772920299999996,
#   128.94684009999997],
#  [879,
#   '통일집불고기',
#   '육류,고기',
#   3.0,
#   '10',
#   '강원 강릉시 금성로61번길 11-1',
#   37.751171,
#   128.8959784],
#  [880,
#   '위촌리전통한우',
#   '육류,고기',
#   4.0,
#   '20',
#   '강원 강릉시 성산면 소목길 203-10',
#   37.753553600000004,
#   128.84733400000002],
#  [881, '메밀촌', '국수', 3.8, '18', '강원 강릉시 창해로 33', 37.7745874, 128.9436671],
#  [882,
#   '강릉대학사식당',
#   '한식',
#   3.9,
#   '25',
#   '강원 강릉시 지변길 10',
#   37.7734211,
#   128.87372620000002],
#  [883, '카페살림', '카페', 3.9, '47', '강원 강릉시 홍제로 63', 37.7533314, 128.8848039],
#  [884,
#   '더바베큐 포남점',
#   '육류,고기',
#   4.6,
#   '26',
#   '강원 강릉시 하평1길 6',
#   37.7707287,
#   128.9114594],
#  [885,
#   '장군시오야끼 포남점',
#   '불고기,두루치기',
#   4.0,
#   '82',
#   '강원 강릉시 하평길 20',
#   37.77009210000001,
#   128.9108148],
#  [886,
#   '어국',
#   '회',
#   2.4,
#   '29',
#   '강원 강릉시 강동면 정동진리 50-153',
#   37.683463399999994,
#   129.0438501],
#  [887, '포지타노', '이탈리안', 5.0, '22', '강원 강릉시 입암로91번길 47', 37.756005, 128.9110234],
#  [888,
#   '라티엔다',
#   '뷔페',
#   2.3,
#   '77',
#   '강원 강릉시 난곡길 219',
#   37.80188649999999,
#   128.87449750000002],
#  [889,
#   '해미가수산',
#   '회',
#   4.9,
#   '31',
#   '강원 강릉시 솔올로 97 1층',
#   37.77051229999999,
#   128.8788599],
#  [890,
#   '주문진남매식당',
#   '한정식',
#   4.8,
#   '15',
#   '강원 강릉시 주문진읍 작은다리길 31',
#   37.890516,
#   128.827831],
#  [891, '피노', '이탈리안', 3.3, '16', '강원 강릉시 팔송길 42-1', 37.7756849, 128.9341219],
#  [892, '카페썬', '카페', 2.6, '28', '강원 강릉시 강동면 정동역길 6', 37.691866, 129.031552],
#  [893,
#   '오엘이프',
#   '양식',
#   5.0,
#   '21',
#   '강원 강릉시 구정면 구정중앙로 242 1층',
#   37.7183549,
#   128.8808069],
#  [894,
#   '불향쭈꾸미',
#   '해물,생선',
#   0.0,
#   '36',
#   '강원 강릉시 율곡초교길11번길 21',
#   37.7666127,
#   128.8794664],
#  [895,
#   '딸부자막국수',
#   '국수',
#   5.0,
#   '8',
#   '강원 강릉시 강동면 대동안길 17',
#   37.72538839999999,
#   128.9780504],
#  [896,
#   '카르페디엠커피',
#   '커피전문점',
#   4.4,
#   '36',
#   '강원 강릉시 연곡면 해안로 1443',
#   37.86845039999999,
#   128.84583510000002],
#  [897,
#   '어림지 강릉점',
#   '해장국',
#   3.2,
#   '14',
#   '강원 강릉시 강릉대로 340',
#   37.7657217,
#   128.9046879],
#  [898, '산촌식당', '한식', 4.4, '23', '강원 강릉시 성산면 구산길 83', 37.7144658, 128.8281265],
#  [899,
#   '불향쭈꾸미볶음 강릉1호점',
#   '해물,생선',
#   4.3,
#   '19',
#   '강원 강릉시 중앙시장3길 15-2',
#   37.7514153,
#   128.8966826],
#  [900, '여왕개미식당', '국수', 4.2, '39', '강원 강릉시 금성로23번길 4', 37.7537546, 128.8980669],
#  [901,
#   '중앙닭강정',
#   '닭강정',
#   5.0,
#   '17',
#   '강원 강릉시 금성로13번길 8-1 1층',
#   37.753851899999994,
#   128.8992426],
#  [902, '더식탁', '양식', 3.5, '141', '강원 강릉시 강릉대로210번길 28', 37.755727, 128.89343],
#  [903,
#   '태백실비식당',
#   '갈비',
#   1.0,
#   '70',
#   '강원 강릉시 경포로 33-15 1층',
#   37.7719781,
#   128.8780328],
#  [904,
#   '소반',
#   '한정식',
#   4.7,
#   '16',
#   '강원 강릉시 하슬라로232번길 7-12',
#   37.771148,
#   128.8769764],
#  [905, '난설헌메밀촌', '국수', 4.6, '15', '강원 강릉시 난설헌로 105', 37.7868489, 128.9060121],
#  [906,
#   '소고기야시장 강릉본점',
#   '육류,고기',
#   3.7,
#   '17',
#   '강원 강릉시 정원로 44',
#   37.7622992,
#   128.8768436],
#  [907, '알뜨', '카페', 4.9, '21', '강원 강릉시 용지로 171', 37.7632021, 128.8997905],
#  [908,
#   '주문진회도매센타',
#   '회',
#   3.8,
#   '3',
#   '강원 강릉시 경포로463번길 36',
#   37.80435629999999,
#   128.9033795],
#  [909, '남애횟집', '회', 4.8, '11', '강원 강릉시 강릉대로457번길 3', 37.7740835, 128.9124609],
#  [910,
#   '강릉삼삼이네횟집',
#   '회',
#   5.0,
#   '14',
#   '강원 강릉시 가작로 78 주공1차아파트 상가',
#   37.7674566,
#   128.8849478],
#  [911,
#   '쿠우쿠우 강릉점(2021년7월예정)',
#   '해산물뷔페',
#   3.1,
#   '107',
#   '강원 강릉시 금성로 41 선프라자 5층',
#   37.7526119,
#   128.8964338],
#  [912,
#   '홍돼지국밥 본점',
#   '국밥',
#   3.9,
#   '19',
#   '강원 강릉시 강릉대로 237',
#   37.7596576,
#   128.8961148],
#  [913,
#   '달선이네조개마당',
#   '조개',
#   2.9,
#   '41',
#   '강원 강릉시 창해로14번길 28-2',
#   37.772169700000006,
#   128.94774089999999],
#  [914,
#   '용골감나무집',
#   '육류,고기',
#   3.0,
#   '61',
#   '강원 강릉시 진재골길29번길 45',
#   37.7371716,
#   128.8931752],
#  [915,
#   '바우카페',
#   '카페',
#   4.7,
#   '45',
#   '강원 강릉시 연곡면 해안로 1437',
#   37.868188200000006,
#   128.84646740000002],
#  [916,
#   '장수촌손칼국수',
#   '국수',
#   4.2,
#   '19',
#   '강원 강릉시 임영로164번길 4',
#   37.755768200000006,
#   128.8921538],
#  [917,
#   '토박이해물',
#   '해물,생선',
#   4.5,
#   '16',
#   '강원 강릉시 주문진읍 해안로 1615-1',
#   37.8799506,
#   128.832977],
#  [918,
#   '사돈네닭강정',
#   '닭강정',
#   4.4,
#   '20',
#   '강원 강릉시 주문진읍 주문북로 7',
#   37.8955023,
#   128.8312602],
#  [919,
#   '강릉브루어리',
#   '호프,요리주점',
#   4.1,
#   '18',
#   '강원 강릉시 율곡초교길11번길 9',
#   37.7675597,
#   128.87969669999998],
#  [920,
#   '지베이스',
#   '테마카페',
#   5.0,
#   '42',
#   '강원 강릉시 금성로56번길 6 2층',
#   37.7524285,
#   128.8950812],
#  [921,
#   '엠꼼마카롱 강릉점',
#   '디저트카페',
#   4.5,
#   '24',
#   '강원 강릉시 경강로2115번길 15 1층',
#   37.7569003,
#   128.896734],
#  [922,
#   '은총횟집',
#   '회',
#   4.7,
#   '115',
#   '강원 강릉시 금성로 21 지하1층 41호',
#   37.75400020000001,
#   128.89858279999999],
#  [923,
#   '디오슬로',
#   '카페',
#   4.0,
#   '108',
#   '강원 강릉시 난설헌로78번길 11',
#   37.780359000000004,
#   128.9030156],
#  [924,
#   '숲속집',
#   '순대',
#   3.9,
#   '23',
#   '강원 강릉시 성산면 칠봉로 15-7',
#   37.714696999999994,
#   128.8324108],
#  [925,
#   '제일강산',
#   '삼계탕',
#   4.3,
#   '15',
#   '강원 강릉시 홍제로85번길 29',
#   37.753361299999995,
#   128.8810571],
#  [926,
#   '진화해변횟집',
#   '회',
#   4.2,
#   '13',
#   '강원 강릉시 주문진읍 해안로 1825',
#   37.8950251,
#   128.8340189],
#  [927,
#   '주문진생선구이',
#   '해물,생선',
#   4.2,
#   '52',
#   '강원 강릉시 주문진읍 해안로 1795',
#   37.8948878,
#   128.8308815],
#  [928,
#   '강릉갈비찜',
#   '갈비',
#   5.0,
#   '35',
#   '강원 강릉시 위촌길 55 1층',
#   37.75844779999999,
#   128.86194070000002],
#  [929,
#   '오드커피',
#   '카페',
#   4.4,
#   '48',
#   '강원 강릉시 주문진읍 해안로 1597',
#   37.8787791,
#   128.8340243],
#  [930,
#   '카페다온로즈with테라로사',
#   '카페',
#   5.0,
#   '0',
#   '강원 강릉시 동해대로 3288-17 로비 1층',
#   37.786088,
#   128.8756123],
#  [931,
#   '버닝72.5',
#   '카페',
#   4.8,
#   '28',
#   '강원 강릉시 율곡초교길 13-1',
#   37.7679888,
#   128.8793057],
#  [932,
#   '성원궁횟집',
#   '회',
#   4.1,
#   '167',
#   '강원 강릉시 주문진읍 해안로 1839-5',
#   37.895858000000004,
#   128.8336997],
#  [933,
#   '한우만무한리필',
#   '육류,고기',
#   4.2,
#   '42',
#   '강원 강릉시 정원로 74-23 1층',
#   37.764564299999996,
#   128.8740635],
#  [934, '봉쥬르', '카페', 0.0, '26', '강원 강릉시 가작로 292', 37.7703167, 128.907048],
#  [935,
#   '남애수산횟집',
#   '회',
#   4.2,
#   '10',
#   '강원 강릉시 하슬라로232번길 14-6',
#   37.7699686,
#   128.8770976],
#  [936,
#   '초당젤라또 도깨비점',
#   '아이스크림',
#   3.0,
#   '67',
#   '강원 강릉시 주문진읍 해안로 1605 1, 2층',
#   37.879385600000006,
#   128.833747],
#  [937,
#   '강릉대게',
#   '게,대게',
#   4.5,
#   '43',
#   '강원 강릉시 하슬라로 18 1층',
#   37.7552029,
#   128.8798534],
#  [938,
#   '오감만족 강릉본점',
#   '족발,보쌈',
#   4.6,
#   '80',
#   '강원 강릉시 경강로2267번길 18 1층',
#   37.7669494,
#   128.9083621],
#  [939,
#   '소영이네돈까스물회',
#   '돈까스,우동',
#   4.2,
#   '48',
#   '강원 강릉시 정원로 54 1층',
#   37.7624613,
#   128.8758955],
#  [940,
#   '뚱할머니순두부',
#   '두부전문점',
#   4.3,
#   '17',
#   '강원 강릉시 난설헌로 211',
#   37.7919037,
#   128.91245859999998],
#  [941,
#   '커피인',
#   '카페',
#   5.0,
#   '29',
#   '강원 강릉시 주문진읍 해안로 1581 1층',
#   37.8775901,
#   128.8352443],
#  [942,
#   '쇠네스독일앤틱 독일빈티지독일카페 강릉본점',
#   '카페',
#   2.7,
#   '15',
#   '강원 강릉시 안현로 114-2',
#   37.803123799999995,
#   128.875915],
#  [943, '선풍', '회', 4.4, '33', '강원 강릉시 율곡초교길43번길 8', 37.7670295, 128.8793866],
#  [944,
#   '빵앗간',
#   '제과,베이커리',
#   3.7,
#   '67',
#   '강원 강릉시 하평길 74 1층',
#   37.77033970000001,
#   128.9166498],
#  [945,
#   '초시막국수',
#   '국수',
#   3.9,
#   '17',
#   '강원 강릉시 연곡면 초시길 33-1',
#   37.851387,
#   128.8379268],
#  [946, '커피쓰다', '카페', 4.7, '32', '강원 강릉시 강릉대로 300 1층', 37.7632948, 128.9013386],
#  [947, '해랑', '회', 2.8, '5', '강원 강릉시 주문진읍 해안로 1609', 37.879534, 128.8335259],
#  [948, '경포칼국수', '국수', 4.2, '12', '강원 강릉시 안현로 300 1층', 37.8036692, 128.8684568],
#  [949, '나의하루', '카페', 4.9, '27', '강원 강릉시 강동면 정동3길 43', 37.686265, 129.0360095],
#  [950,
#   '진보양푼이물회섭국',
#   '회',
#   3.3,
#   '9',
#   '강원 강릉시 사천면 진리해변길 67',
#   37.8384122,
#   128.8761021],
#  [951,
#   '뒷섬장치찜',
#   '해물,생선',
#   3.4,
#   '17',
#   '강원 강릉시 정원로 73-16',
#   37.7614794,
#   128.8728333],
#  [952, '삼우옹심이', '한식', 4.6, '12', '강원 강릉시 공항길 35', 37.7627207, 128.9401025],
#  [953,
#   '옛빙그레김밥',
#   '분식',
#   2.9,
#   '36',
#   '강원 강릉시 임영로116번안길 12',
#   37.7530739,
#   128.8940903],
#  [954,
#   '주문진신짬뽕',
#   '중화요리',
#   3.7,
#   '27',
#   '강원 강릉시 주문진읍 장성로 54 1층',
#   37.88780670000001,
#   128.82603170000002],
#  [955,
#   '그옛날 초당순두부',
#   '두부전문점',
#   3.8,
#   '14',
#   '강원 강릉시 초당순두부길 57',
#   37.7885984,
#   128.9143753],
#  [956,
#   '홍두깨',
#   '육류,고기',
#   3.8,
#   '88',
#   '강원 강릉시 율곡초교길43번길 14',
#   37.7648698,
#   128.8798669],
#  [957,
#   '미스터홍게',
#   '해물,생선',
#   4.4,
#   '12',
#   '강원 강릉시 하슬라로 123',
#   37.761045700000004,
#   128.872995],
#  [958,
#   '소돌막국수',
#   '국수',
#   5.0,
#   '20',
#   '강원 강릉시 주문진읍 연주로 571',
#   37.8871355,
#   128.8255882],
#  [959,
#   '전망대횟집',
#   '회',
#   4.0,
#   '15',
#   '강원 강릉시 강동면 헌화로 982-2',
#   37.685699,
#   129.0404278],
#  [960,
#   '옛소라회센타',
#   '회',
#   3.6,
#   '21',
#   '강원 강릉시 창해로350번길 13',
#   37.795426899999995,
#   128.9179918],
#  [961,
#   '보헤미안박이추커피 본점',
#   '카페',
#   5.0,
#   '9',
#   '강원 강릉시 연곡면 홍질목길 55-11',
#   37.8645982,
#   128.8423849],
#  [962,
#   '화로상회 강릉입암점',
#   '육류,고기',
#   1.0,
#   '32',
#   '강원 강릉시 성덕포남로 53 1층',
#   37.75964039999999,
#   128.9189442],
#  [963,
#   '후타고라멘 강릉점',
#   '일본식라면',
#   4.4,
#   '40',
#   '강원 강릉시 하슬라로232번길 22-11',
#   37.7695946,
#   128.8783156],
#  [964,
#   '정혜영쿡디자인',
#   '양식',
#   3.8,
#   '11',
#   '강원 강릉시 사천면 본동길 242',
#   37.827836700000006,
#   128.8594296],
#  [965,
#   '김윤미전복삼계탕',
#   '삼계탕',
#   4.1,
#   '24',
#   '강원 강릉시 팔송길 6',
#   37.774933700000005,
#   128.9328787],
#  [966,
#   '호텔탑스텐 뷔페포세이돈',
#   '뷔페',
#   2.6,
#   '10',
#   '강원 강릉시 옥계면 헌화로 455-34 2층',
#   37.6532823,
#   129.0514825],
#  [967,
#   '모구모구식당',
#   '일식',
#   3.8,
#   '34',
#   '강원 강릉시 선수촌로 124 1층',
#   37.748864000000005,
#   128.8824222],
#  [968,
#   '진리해변길71',
#   '이탈리안',
#   4.9,
#   '10',
#   '강원 강릉시 사천면 진리해변길 71',
#   37.83838679999999,
#   128.8762518],
#  [969,
#   '차이루',
#   '중화요리',
#   4.1,
#   '3',
#   '강원 강릉시 하슬라로232번길 14-8',
#   37.769788399999996,
#   128.87709089999998],
#  [970,
#   '신리면옥 강릉점',
#   '냉면',
#   4.4,
#   '16',
#   '강원 강릉시 하슬라로177번길 7',
#   37.7661829,
#   128.87450479999998],
#  [971, '고향횟집', '회', 3.5, '14', '강원 강릉시 강동면 염전길 149', 37.7408899, 128.9839432],
#  [972,
#   '연화마을',
#   '삼계탕',
#   5.0,
#   '73',
#   '강원 강릉시 강동면 풍호길 100-1',
#   37.737660399999996,
#   128.9534989],
#  [973,
#   '성왕돈까스',
#   '돈까스,우동',
#   4.1,
#   '32',
#   '강원 강릉시 성산면 구산길 55 1층',
#   37.7157321,
#   128.8310216],
#  [974,
#   '짠지 본점',
#   '찌개,전골',
#   5.0,
#   '23',
#   '강원 강릉시 토성로 181 1층',
#   37.756964399999994,
#   128.8957645],
#  [975,
#   '알베로',
#   '커피전문점',
#   3.6,
#   '34',
#   '강원 강릉시 창해로14번길 36',
#   37.771531700000004,
#   128.9484263],
#  [976, '노아회식당', '회', 4.9, '5', '강원 강릉시 경강로 2617', 37.7728612, 128.9455601],
#  [977, '어부횟집', '회', 3.6, '27', '강원 강릉시 강동면 헌화로 993', 37.6862617, 129.0393563],
#  [978,
#   '일출횟집',
#   '회',
#   4.8,
#   '19',
#   '강원 강릉시 주문진읍 시장2길 4 주문진수산시장 내',
#   37.8910576,
#   128.82775230000001],
#  [979,
#   '명품횡성한우고집',
#   '육류,고기',
#   3.7,
#   '23',
#   '강원 강릉시 율곡초교길11번길 15',
#   37.7670461,
#   128.87957820000003],
#  [980,
#   '스웨이',
#   '카페',
#   5.0,
#   '65',
#   '강원 강릉시 경포로 489-6 2층',
#   37.804239700000004,
#   128.9048271],
#  [981,
#   '심춘옥청국장&순두부',
#   '국밥',
#   4.7,
#   '17',
#   '강원 강릉시 초당순두부길 89-11',
#   37.791778799999996,
#   128.9146223],
#  [982,
#   '메밀골동해막국수 강문점',
#   '국수',
#   4.0,
#   '13',
#   '강원 강릉시 창해로350번길 25',
#   37.7963081,
#   128.9170671],
#  [983,
#   '정동진심곡쉼터',
#   '한식',
#   4.4,
#   '17',
#   '강원 강릉시 강동면 헌화로 665-4',
#   37.6648936,
#   129.0502839],
#  [984,
#   '정감이능이백숙',
#   '닭요리',
#   3.9,
#   '10',
#   '강원 강릉시 강동면 둔지길 89-16',
#   37.71652220000001,
#   128.9575437],
#  [985, '강릉뚝배기', '국밥', 4.2, '14', '강원 강릉시 남부로 5', 37.7402088, 128.8809818],
#  [986,
#   '대관령눈꽃갈비',
#   '갈비',
#   5.0,
#   '48',
#   '강원 강릉시 성산면 솔밭길 11-10',
#   37.73546629999999,
#   128.85186570000002],
#  [987,
#   '강릉짬뽕순두부',
#   '두부전문점',
#   4.4,
#   '21',
#   '강원 강릉시 초당순두부길 116',
#   37.790108399999994,
#   128.9139757],
#  [988,
#   '연당커피',
#   '카페',
#   5.0,
#   '26',
#   '강원 강릉시 연당길 112 1층',
#   37.7871386,
#   128.91256370000002],
#  [989,
#   '미미네횟집',
#   '회',
#   4.8,
#   '4',
#   '강원 강릉시 주문진읍 해안로 1917',
#   37.90143279999999,
#   128.8309767],
#  [990,
#   '돈비촌',
#   '갈비',
#   3.3,
#   '22',
#   '강원 강릉시 하슬라로206번길 23',
#   37.767854299999996,
#   128.8782508],
#  [991,
#   '천사곱창 강릉포남점',
#   '곱창,막창',
#   0.0,
#   '48',
#   '강원 강릉시 강릉대로 422-7',
#   37.7708563,
#   128.9109252],
#  [992,
#   '빠스따보니따',
#   '이탈리안',
#   4.8,
#   '23',
#   '강원 강릉시 주문진읍 해안로 1667',
#   37.883955,
#   128.82987079999998],
#  [993,
#   '빙그레김밥',
#   '분식',
#   4.0,
#   '19',
#   '강원 강릉시 토성로 153',
#   37.755339899999996,
#   128.8930338],
#  [994,
#   '등명맛집',
#   '회',
#   4.1,
#   '32',
#   '강원 강릉시 강동면 율곡로 1378',
#   37.702972499999994,
#   129.0157207],
#  [995,
#   '권오복 분틀메밀국수',
#   '국수',
#   4.5,
#   '13',
#   '강원 강릉시 율곡로 2713',
#   37.749515,
#   128.90716740000002],
#  [996, '엘바베큐', '육류,고기', 1.6, '54', '강원 강릉시 하남길 333', 37.8080816, 128.8994195],
#  [997,
#   '경포정육점식당&조개구이',
#   '육류,고기',
#   4.0,
#   '15',
#   '강원 강릉시 경포로463번길 36',
#   37.80435629999999,
#   128.9033795],
#  [998, '송천식당', '한식', 4.2, '9', '강원 강릉시 연곡면 진고개로 777', 37.8265466, 128.637643],
#  [999,
#   '육즙가득한고기집 육고집 강릉직영점',
#   '육류,고기',
#   5.0,
#   '14',
#   '강원 강릉시 사임당로 133',
#   37.766299,
#   128.8611138],
#  [1000,
#   '도로시피크닉',
#   '카페',
#   4.7,
#   '29',
#   '강원 강릉시 하슬라로232번길 6',
#   37.766580100000006,
#   128.8760505],
#  [2000,
#   '광고춘천펜션',
#   '펜션',
#   4.5,
#   '1',
#   '강원 춘천시 신북읍 신샘밭로 774',
#   37.9313649,
#   127.77650159999999],
#  [2001,
#   '소양강스카이워크',
#   '전망대',
#   3.3,
#   '425',
#   '강원 춘천시 영서로 2663',
#   37.8931677,
#   127.7232035],
#  [2002,
#   '남이섬',
#   '섬(내륙)',
#   2.8,
#   '461',
#   '강원 춘천시 남산면 남이섬길 1',
#   37.7899352,
#   127.52580719999999],
#  [2003,
#   '제이드가든수목원',
#   '수목원,식물원',
#   3.8,
#   '123',
#   '강원 춘천시 남산면 햇골길 80',
#   37.8325325,
#   127.5422982],
#  [2004,
#   '명동닭갈비골목',
#   '먹자골목',
#   3.5,
#   '40',
#   '강원 춘천시 조양동 138-15',
#   37.8790852,
#   127.7275235],
#  [2005,
#   '의암 스카이워크',
#   '전망대',
#   3.3,
#   '54',
#   '강원 춘천시 칠전동 468-1',
#   37.8453741,
#   127.67786650000001],
#  [2006,
#   '구봉산전망대',
#   '전망대',
#   3.3,
#   '7',
#   '강원 춘천시 동면 순환대로 1154-113',
#   37.892815899999995,
#   127.77678],
#  [2007,
#   '강원도립화목원',
#   '수목원,식물원',
#   4.5,
#   '70',
#   '강원 춘천시 화목원길 24',
#   37.92339460000001,
#   127.72443799999999],
#  [2008,
#   '건봉령승호대',
#   '관광,명소',
#   5.0,
#   '4',
#   '강원 춘천시 북산면 부귀리 산 59-9',
#   37.954737,
#   127.86388670000001],
#  [2009,
#   '김유정문학촌',
#   '관광,명소',
#   3.7,
#   '100',
#   '강원 춘천시 신동면 실레길 25',
#   37.819093200000005,
#   127.71881529999999],
#  [2010,
#   '레고랜드코리아리조트(2022년3월예정)',
#   '테마파크',
#   2.3,
#   '5',
#   '강원 춘천시 중도동 603-4',
#   37.8820784,
#   127.69660159999998],
#  [2011,
#   '구봉산전망대카페거리',
#   '카페거리',
#   4.0,
#   '30',
#   '강원 춘천시 동면 장학리',
#   37.9075284,
#   127.75823229999999],
#  [2012,
#   '삼악산',
#   '산',
#   4.3,
#   '73',
#   '강원 춘천시 서면 덕두원리 산 164-23',
#   37.839908799999996,
#   127.65722240000002],
#  [2013,
#   '공지천유원지',
#   '유원지',
#   3.8,
#   '56',
#   '강원 춘천시 근화동',
#   37.880565000000004,
#   127.7124994],
#  [2014,
#   '국립용화산자연휴양림',
#   '자연휴양림',
#   4.0,
#   '24',
#   '강원 춘천시 사북면 사여골길 294',
#   38.0113477,
#   127.7603378],
#  [2015,
#   '구곡폭포',
#   '폭포',
#   4.2,
#   '86',
#   '강원 춘천시 남산면 강촌리 432-37',
#   37.793923799999995,
#   127.6091805],
#  [2016,
#   '부귀리벚꽃길',
#   '테마거리',
#   4.7,
#   '3',
#   '강원 춘천시 북산면 부귀리 115-7',
#   37.9471249,
#   127.8766635],
#  [2017,
#   '의암호반길',
#   '드라이브코스',
#   3.9,
#   '0',
#   '강원 춘천시 서면 현암리 산 33-2',
#   37.88042670000001,
#   127.6808662],
#  [2018,
#   '강아지숲',
#   '테마파크',
#   3.8,
#   '8',
#   '강원 춘천시 남산면 충효로 437',
#   37.73593579999999,
#   127.6622656],
#  [2019, '소양강처녀상', '동상', 3.0, '77', '강원 춘천시 근화동 8-1', 37.8934139, 127.7243543],
#  [2020,
#   '집다리골자연휴양림',
#   '자연휴양림',
#   4.0,
#   '4',
#   '강원 춘천시 사북면 화악지암1길 130',
#   37.9776131,
#   127.58079199999999],
#  [2021,
#   '신매대교 인증센터',
#   '자전거여행',
#   4.3,
#   '8',
#   '강원 춘천시 서면 신매리 41-2',
#   37.9202714,
#   127.71300749999999],
#  [2022, '공지천', '하천', 4.3, '2', '강원 춘천시 근화동', 37.880565000000004, 127.7124994],
#  [2023,
#   '소양강',
#   '강',
#   5.0,
#   '3',
#   '강원 춘천시 동면 장학리 896',
#   37.910504100000004,
#   127.7466249],
#  [2024,
#   '강촌레일파크 경강역',
#   '테마파크',
#   4.0,
#   '7',
#   '강원 춘천시 남산면 서백길 57',
#   37.8427618,
#   127.5506962],
#  [2025,
#   '육림랜드',
#   '테마파크',
#   4.3,
#   '46',
#   '강원 춘천시 영서로 2965',
#   37.91774110000001,
#   127.719995],
#  [2026,
#   '춘천숲자연휴양림',
#   '자연휴양림',
#   4.7,
#   '9',
#   '강원 춘천시 동산면 종자리로 224-104',
#   37.7477873,
#   127.7434473],
#  [2027,
#   '의암호',
#   '호수',
#   4.4,
#   '13',
#   '강원 춘천시 삼천동',
#   37.868108899999996,
#   127.70041090000002],
#  [2028,
#   '월드온천',
#   '온천',
#   4.7,
#   '4',
#   '강원 춘천시 신북읍 장본길 35',
#   37.94973529999999,
#   127.7539249],
#  [2029,
#   '용화산',
#   '산',
#   4.0,
#   '26',
#   '강원 춘천시 사북면 고성리',
#   38.008004299999996,
#   127.74309299999999],
#  [2030,
#   '등선폭포',
#   '폭포',
#   4.6,
#   '31',
#   '강원 춘천시 서면 덕두원리 118-2',
#   37.8275841,
#   127.6583155],
#  [2031, '소양호', '호수', 4.5, '7', '강원 춘천시 북산면 내평리', 37.9553676, 127.8949604],
#  [2032,
#   '오봉산정상',
#   '산봉우리',
#   0.0,
#   '17',
#   '강원 춘천시 북산면 청평리',
#   37.9634966,
#   127.82530030000001],
#  [2033,
#   '춘천로데오거리',
#   '테마거리',
#   0.0,
#   '0',
#   '강원 춘천시 석사동',
#   37.861137400000004,
#   127.7496163],
#  [2035,
#   '추곡약수',
#   '샘터,약수터',
#   4.0,
#   '1',
#   '강원 춘천시 북산면 추곡리',
#   38.0270881,
#   127.88114420000001],
#  [2036,
#   '강촌테마랜드',
#   '테마파크',
#   1.0,
#   '19',
#   '강원 춘천시 남산면 강촌리 224-7',
#   37.8148633,
#   127.6340174],
#  ...]

# %% [markdown]
# csv 파일 list로 변환

# %%
place_name = place['place_name'].tolist()
detail_list = couple_vlog['블로그 내용'].tolist()

# %% [markdown]
# 여행지 이름 제거

# %%
place_name.remove('공감')
place_name.remove('강릉시')

# %% [markdown]
# # Okt

# %%
from konlpy.tag import Okt
okt = Okt()

# %% [markdown]
# # 커플 여행 블로그에서 여행경로 탐색하기

# %%
p = []
re = []
couple = []
s = set(place_name)
for i in range(len(detail_list)):
  data = detail_list[i]
  p.clear()
  p = okt.phrases(detail_list[i])
  re.append(p)
  ree = [x for x in re[i] if x in s]
  couple.append(ree)
  #print(i,ree)
couple = [v for v in couple if v]

# %%
couple
# Out:
# [['벌집'],
#  ['교동'],
#  ['경포해변', '경포호'],
#  ['경포대'],
#  ['경포호', '수산시장'],
#  ['경포대'],
#  ['바로방'],
#  ['동화가든'],
#  ['보헤미안'],
#  ['경포해변', '경포대'],
#  ['경포호', '경포대'],
#  ['경포대', '경포호'],
#  ['경포해변', '경포대'],
#  ['경포대', '강문해변'],
#  ['교동'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['봉화산'],
#  ['경포해변'],
#  ['발산'],
#  ['경포대'],
#  ['경포해변', '금진해변', '해안도로'],
#  ['안목해변'],
#  ['경포대'],
#  ['강문해변', '동화가든', '경포호'],
#  ['강문해변', '경포대', '사천해변'],
#  ['교동'],
#  ['정감'],
#  ['경포해변'],
#  ['안목해변', '경포대', '경포호'],
#  ['동화가든'],
#  ['안목해변', '강문해변', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['강문해변', '경포대'],
#  ['경포대'],
#  ['비키니'],
#  ['정동심곡 바다부채길'],
#  ['안목해변'],
#  ['송정해변'],
#  ['교동'],
#  ['영진해변'],
#  ['경포대'],
#  ['강문해변', '비키니', '해송'],
#  ['경포대'],
#  ['교동'],
#  ['경포해변', '수산시장', '경포대'],
#  ['수산시장'],
#  ['경포해변', '경포대'],
#  ['회관'],
#  ['해안도로'],
#  ['금진해변'],
#  ['강문해변'],
#  ['경포대'],
#  ['헌화로'],
#  ['정감'],
#  ['안목해변'],
#  ['강문해변', '벌집'],
#  ['안목해변'],
#  ['어라운드키친'],
#  ['경포해변', '경포대', '경포호'],
#  ['수산시장', '영진해변', '보헤미안'],
#  ['강문해변'],
#  ['강문해변'],
#  ['테라로사 경포호수점', '경포호'],
#  ['강문해변'],
#  ['안목해변'],
#  ['경포호', '경포대'],
#  ['경포호', '해송'],
#  ['경포호'],
#  ['벌집'],
#  ['경포대'],
#  ['자스민'],
#  ['안목해변', '경포대', '농촌'],
#  ['테라로사 커피공장', '해동횟집', '풍년갈비', '경포대'],
#  ['경포대'],
#  ['경포대'],
#  ['경포해변', '경포호'],
#  ['경포호', '안목해변', '경포해변'],
#  ['경포해변'],
#  ['경포해변', '경포호'],
#  ['경포대'],
#  ['경포대', '남향막국수', '영진해변'],
#  ['교동'],
#  ['경포해변'],
#  ['경포대'],
#  ['안목해변', '수산시장'],
#  ['경포해변'],
#  ['강문해변'],
#  ['경포해변', '경포호'],
#  ['수산시장'],
#  ['경포대'],
#  ['경포대', '경포호'],
#  ['경포대'],
#  ['경포대'],
#  ['오죽헌'],
#  ['경포호'],
#  ['경포호'],
#  ['교동'],
#  ['오죽헌', '강문해변'],
#  ['경포해변'],
#  ['테라로사 경포호수점', '오죽헌', '경포대', '경포호'],
#  ['교동', '경포호'],
#  ['경포대', '경포호'],
#  ['강문해변'],
#  ['테라로사 사천점'],
#  ['초가'],
#  ['금학칼국수', '경포해변', '오죽헌']]

# %% [markdown]
# # pandas data 프레임

# %% [markdown]
# 블로그 여행경로와 장소 정보 합치기

# %%
r2 = []
no_p = p_li.copy()
for i in range(len(couple)):
  for j in range(len(couple[i])):
    a = couple[i][j]
    y = list(zip(*p_li))[1].index(a)
    r1 = [i+659,'family', j+1] + p_li[y]
    r2.append(r1)
    if p_li[y] in list(zip(*no_p))[1]:
      no_p.remove(p_li[y])
#print(r2)

# %%
r2
# Out:
# [[659,
#   'family',
#   1,
#   508,
#   '벌집',
#   '국수',
#   3.2,
#   '377',
#   '강원 강릉시 경강로2069번길 15',
#   37.7545049,
#   128.892756],
#  [660,
#   'family',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [661,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [661,
#   'family',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [662,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [663,
#   'family',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [663,
#   'family',
#   2,
#   569,
#   '수산시장',
#   '회',
#   4.4,
#   '122',
#   '강원 강릉시 창해로 361-7',
#   37.794538200000005,
#   128.9175687],
#  [664,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [665,
#   'family',
#   1,
#   562,
#   '바로방',
#   '제과,베이커리',
#   3.2,
#   '153',
#   '강원 강릉시 경강로 2092',
#   37.7543398,
#   128.89587360000002],
#  [666,
#   'family',
#   1,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [667,
#   'family',
#   1,
#   629,
#   '보헤미안',
#   '카페',
#   4.6,
#   '44',
#   '강원 강릉시 수리골길 121-4',
#   37.780452600000004,
#   128.8946232],
#  [668,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [668,
#   'family',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [669,
#   'family',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [669,
#   'family',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [670,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [670,
#   'family',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [671,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [671,
#   'family',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [672,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [672,
#   'family',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [673,
#   'family',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [674,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [675,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [676,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [677,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [678,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [679,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [680,
#   'family',
#   1,
#   2091,
#   '봉화산',
#   '산',
#   5.0,
#   '6',
#   '강원 춘천시 남면 가정리',
#   37.756294700000005,
#   127.5830014],
#  [681,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [682,
#   'family',
#   1,
#   2342,
#   '발산',
#   '산',
#   0.0,
#   '0',
#   '강원 춘천시 신북읍 발산리 883',
#   37.955636600000005,
#   127.75034],
#  [683,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [684,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [684,
#   'family',
#   2,
#   29,
#   '금진해변',
#   '해수욕장,해변',
#   4.1,
#   '10',
#   '강원 강릉시 옥계면 금진리',
#   37.6432124,
#   129.0367071],
#  [684,
#   'family',
#   3,
#   24,
#   '해안도로',
#   '드라이브코스',
#   3.7,
#   '3',
#   '강원 강릉시 강동면 헌화로 641',
#   37.6647915,
#   129.05304579999998],
#  [685,
#   'family',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [686,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [687,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [687,
#   'family',
#   2,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [687,
#   'family',
#   3,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [688,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [688,
#   'family',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [688,
#   'family',
#   3,
#   15,
#   '사천해변',
#   '해수욕장,해변',
#   3.8,
#   '27',
#   '강원 강릉시 사천면 방동리 282-1',
#   37.8202946,
#   128.86527809999998],
#  [689,
#   'family',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [690,
#   'family',
#   1,
#   601,
#   '정감',
#   '퓨전요리',
#   3.8,
#   '151',
#   '강원 강릉시 가작로 34',
#   37.771342600000004,
#   128.9003281],
#  [691,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [692,
#   'family',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [692,
#   'family',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [692,
#   'family',
#   3,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [693,
#   'family',
#   1,
#   509,
#   '동화가든',
#   '두부전문점',
#   3.3,
#   '1,726',
#   '강원 강릉시 초당순두부길77번길 15',
#   37.7911013,
#   128.9147331],
#  [694,
#   'family',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [694,
#   'family',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [694,
#   'family',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [695,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [696,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [697,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [697,
#   'family',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [698,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [699,
#   'family',
#   1,
#   814,
#   '비키니',
#   '카페',
#   3.9,
#   '122',
#   '강원 강릉시 해안로 355',
#   37.7946563,
#   128.9142002],
#  [700,
#   'family',
#   1,
#   3,
#   '정동심곡 바다부채길',
#   '관광,명소',
#   4.3,
#   '182',
#   '강원 강릉시 강동면 심곡리 114-3',
#   37.6662501,
#   129.05454709999998],
#  [701,
#   'family',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [702,
#   'family',
#   1,
#   12,
#   '송정해변',
#   '해수욕장,해변',
#   4.5,
#   '36',
#   '강원 강릉시 송정동 산 1-4',
#   37.7825361,
#   128.93417079999998],
#  [703,
#   'family',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [704,
#   'family',
#   1,
#   13,
#   '영진해변',
#   '해수욕장,해변',
#   4.1,
#   '43',
#   '강원 강릉시 연곡면 영진리 72-2',
#   37.8680886,
#   128.8469178],
#  [705,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [706,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [706,
#   'family',
#   2,
#   814,
#   '비키니',
#   '카페',
#   3.9,
#   '122',
#   '강원 강릉시 해안로 355',
#   37.7946563,
#   128.9142002],
#  [706,
#   'family',
#   3,
#   642,
#   '해송',
#   '회',
#   3.3,
#   '18',
#   '강원 강릉시 창해로14번길 16',
#   37.772920299999996,
#   128.94684009999997],
#  [707,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [708,
#   'family',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [709,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [709,
#   'family',
#   2,
#   569,
#   '수산시장',
#   '회',
#   4.4,
#   '122',
#   '강원 강릉시 창해로 361-7',
#   37.794538200000005,
#   128.9175687],
#  [709,
#   'family',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [710,
#   'family',
#   1,
#   569,
#   '수산시장',
#   '회',
#   4.4,
#   '122',
#   '강원 강릉시 창해로 361-7',
#   37.794538200000005,
#   128.9175687],
#  [711,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [711,
#   'family',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [712,
#   'family',
#   1,
#   2992,
#   '회관',
#   '카페',
#   4.3,
#   '29',
#   '강원 춘천시 춘천로167번길 39 1층',
#   37.879684000000005,
#   127.73209340000001],
#  [713,
#   'family',
#   1,
#   24,
#   '해안도로',
#   '드라이브코스',
#   3.7,
#   '3',
#   '강원 강릉시 강동면 헌화로 641',
#   37.6647915,
#   129.05304579999998],
#  [714,
#   'family',
#   1,
#   29,
#   '금진해변',
#   '해수욕장,해변',
#   4.1,
#   '10',
#   '강원 강릉시 옥계면 금진리',
#   37.6432124,
#   129.0367071],
#  [715,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [716,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [717,
#   'family',
#   1,
#   173,
#   '헌화로',
#   '드라이브코스',
#   3.5,
#   '12',
#   '강원 강릉시 강동면 심곡리',
#   37.6672988,
#   129.0416628],
#  [718,
#   'family',
#   1,
#   601,
#   '정감',
#   '퓨전요리',
#   3.8,
#   '151',
#   '강원 강릉시 가작로 34',
#   37.771342600000004,
#   128.9003281],
#  [719,
#   'family',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [720,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [720,
#   'family',
#   2,
#   508,
#   '벌집',
#   '국수',
#   3.2,
#   '377',
#   '강원 강릉시 경강로2069번길 15',
#   37.7545049,
#   128.892756],
#  [721,
#   'family',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [722,
#   'family',
#   1,
#   2735,
#   '어라운드키친',
#   '양식',
#   3.1,
#   '77',
#   '강원 춘천시 동면 만천로 114-3',
#   37.881884899999996,
#   127.7621551],
#  [723,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [723,
#   'family',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [723,
#   'family',
#   3,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [724,
#   'family',
#   1,
#   569,
#   '수산시장',
#   '회',
#   4.4,
#   '122',
#   '강원 강릉시 창해로 361-7',
#   37.794538200000005,
#   128.9175687],
#  [724,
#   'family',
#   2,
#   13,
#   '영진해변',
#   '해수욕장,해변',
#   4.1,
#   '43',
#   '강원 강릉시 연곡면 영진리 72-2',
#   37.8680886,
#   128.8469178],
#  [724,
#   'family',
#   3,
#   629,
#   '보헤미안',
#   '카페',
#   4.6,
#   '44',
#   '강원 강릉시 수리골길 121-4',
#   37.780452600000004,
#   128.8946232],
#  [725,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [726,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [727,
#   'family',
#   1,
#   504,
#   '테라로사 경포호수점',
#   '커피전문점',
#   3.2,
#   '438',
#   '강원 강릉시 난설헌로 145',
#   37.7868489,
#   128.9060121],
#  [727,
#   'family',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [728,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [729,
#   'family',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [730,
#   'family',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [730,
#   'family',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [731,
#   'family',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [731,
#   'family',
#   2,
#   642,
#   '해송',
#   '회',
#   3.3,
#   '18',
#   '강원 강릉시 창해로14번길 16',
#   37.772920299999996,
#   128.94684009999997],
#  [732,
#   'family',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [733,
#   'family',
#   1,
#   508,
#   '벌집',
#   '국수',
#   3.2,
#   '377',
#   '강원 강릉시 경강로2069번길 15',
#   37.7545049,
#   128.892756],
#  [734,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [735,
#   'family',
#   1,
#   731,
#   '자스민',
#   '양식',
#   4.1,
#   '27',
#   '강원 강릉시 포남동 945 라동 1층',
#   37.785320399999996,
#   128.9038834],
#  [736,
#   'family',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [736,
#   'family',
#   2,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [736,
#   'family',
#   3,
#   860,
#   '농촌',
#   '한정식',
#   3.3,
#   '8',
#   '강원 강릉시 임영로164번길 3',
#   37.756065,
#   128.8919871],
#  [737,
#   'family',
#   1,
#   501,
#   '테라로사 커피공장',
#   '커피전문점',
#   3.5,
#   '871',
#   '강원 강릉시 구정면 현천길 7',
#   37.6960049,
#   128.89188719999999],
#  [737,
#   'family',
#   2,
#   613,
#   '해동횟집',
#   '회',
#   3.0,
#   '39',
#   '강원 강릉시 사천면 진리해변길 133',
#   37.84261420000001,
#   128.8735943],
#  [737,
#   'family',
#   3,
#   515,
#   '풍년갈비',
#   '육류,고기',
#   3.7,
#   '1,758',
#   '강원 강릉시 강릉대로587번길 10-5',
#   37.7844299,
#   128.91952120000002],
#  [737,
#   'family',
#   4,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [738,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [739,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [740,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [740,
#   'family',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [741,
#   'family',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [741,
#   'family',
#   2,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [741,
#   'family',
#   3,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [742,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [743,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [743,
#   'family',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [744,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [745,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [745,
#   'family',
#   2,
#   852,
#   '남향막국수',
#   '국수',
#   3.9,
#   '16',
#   '강원 강릉시 저동골길 30',
#   37.798062200000004,
#   128.8948264],
#  [745,
#   'family',
#   3,
#   13,
#   '영진해변',
#   '해수욕장,해변',
#   4.1,
#   '43',
#   '강원 강릉시 연곡면 영진리 72-2',
#   37.8680886,
#   128.8469178],
#  [746,
#   'family',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [747,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [748,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [749,
#   'family',
#   1,
#   6,
#   '안목해변',
#   '해수욕장,해변',
#   4.3,
#   '489',
#   '강원 강릉시 창해로14번길 51-26',
#   37.7719317,
#   128.9489348],
#  [749,
#   'family',
#   2,
#   569,
#   '수산시장',
#   '회',
#   4.4,
#   '122',
#   '강원 강릉시 창해로 361-7',
#   37.794538200000005,
#   128.9175687],
#  [750,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [751,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [752,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [752,
#   'family',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [753,
#   'family',
#   1,
#   569,
#   '수산시장',
#   '회',
#   4.4,
#   '122',
#   '강원 강릉시 창해로 361-7',
#   37.794538200000005,
#   128.9175687],
#  [754,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [755,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [755,
#   'family',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [756,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [757,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [758,
#   'family',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [759,
#   'family',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [760,
#   'family',
#   1,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [761,
#   'family',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [762,
#   'family',
#   1,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [762,
#   'family',
#   2,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [763,
#   'family',
#   1,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [764,
#   'family',
#   1,
#   504,
#   '테라로사 경포호수점',
#   '커피전문점',
#   3.2,
#   '438',
#   '강원 강릉시 난설헌로 145',
#   37.7868489,
#   128.9060121],
#  [764,
#   'family',
#   2,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575],
#  [764,
#   'family',
#   3,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [764,
#   'family',
#   4,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [765,
#   'family',
#   1,
#   318,
#   '교동',
#   '계곡',
#   0.0,
#   '0',
#   '강원 강릉시 옥계면 현내리',
#   37.6089752,
#   129.0291988],
#  [765,
#   'family',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [766,
#   'family',
#   1,
#   8,
#   '경포대',
#   '문화유적',
#   4.1,
#   '95',
#   '강원 강릉시 경포로 365',
#   37.795075399999995,
#   128.896598],
#  [766,
#   'family',
#   2,
#   20,
#   '경포호',
#   '호수',
#   4.3,
#   '88',
#   '강원 강릉시 초당동',
#   37.7919049,
#   128.9158303],
#  [767,
#   'family',
#   1,
#   4,
#   '강문해변',
#   '해수욕장,해변',
#   4.1,
#   '197',
#   '강원 강릉시 강문동 182-1',
#   37.795486100000005,
#   128.91791990000002],
#  [768,
#   'family',
#   1,
#   521,
#   '테라로사 사천점',
#   '커피전문점',
#   3.5,
#   '208',
#   '강원 강릉시 사천면 순포안길 6 1, 2층',
#   37.8224255,
#   128.88480800000002],
#  [769,
#   'family',
#   1,
#   2675,
#   '초가',
#   '찌개,전골',
#   4.5,
#   '60',
#   '강원 춘천시 신북읍 율문길 107-1',
#   37.9249484,
#   127.7496351],
#  [770,
#   'family',
#   1,
#   525,
#   '금학칼국수',
#   '국수',
#   3.0,
#   '263',
#   '강원 강릉시 대학길 12-6',
#   37.75441970000001,
#   128.8962638],
#  [770,
#   'family',
#   2,
#   2,
#   '경포해변',
#   '해수욕장,해변',
#   4.1,
#   '194',
#   '강원 강릉시 창해로 514',
#   37.8057795,
#   128.9074169],
#  [770,
#   'family',
#   3,
#   7,
#   '오죽헌',
#   '유적지',
#   4.1,
#   '451',
#   '강원 강릉시 율곡로3139번길 24',
#   37.779183700000004,
#   128.8794575]]

# %%
total = pd.DataFrame(r2)
total.columns = ['user_id','trip','course','place_id','place_name','place_category','rating','review','place_address','place_lat','place_lng']
total['y'] = 1

# %%
total
# Out:
#      user_id    trip  course  ...  place_lat   place_lng  y
# 0        659  family       1  ...  37.754505  128.892756  1
# 1        660  family       1  ...  37.608975  129.029199  1
# 2        661  family       1  ...  37.805779  128.907417  1
# 3        661  family       2  ...  37.791905  128.915830  1
# 4        662  family       1  ...  37.795075  128.896598  1
# ..       ...     ...     ...  ...        ...         ... ..
# 160      768  family       1  ...  37.822426  128.884808  1
# 161      769  family       1  ...  37.924948  127.749635  1
# 162      770  family       1  ...  37.754420  128.896264  1
# 163      770  family       2  ...  37.805779  128.907417  1
# 164      770  family       3  ...  37.779184  128.879458  1
#
# [165 rows x 12 columns]

# %% [markdown]
# # 여행자가 가지 않은 장소와 여행자 합치기

# %%
from random import *
r3 = []
for i in range(len(couple)):
  for j in range(len(no_p)):
    k = randint(1,10)
    r4 = [i+659,'family',k] + no_p[j]
    r3.append(r4)

# %%
total1 = pd.DataFrame(r3)
total1.columns = ['user_id','trip','course','place_id','place_name','place_category','rating','review','place_address','place_lat','place_lng']
total1['y'] = 0

# %%
total1
# Out:
#         user_id    trip  course  ...  place_lat   place_lng  y
# 0           659  family       8  ...  37.707959  129.012171  0
# 1           659  family       7  ...  37.805779  128.907417  0
# 2           659  family       4  ...  37.666250  129.054547  0
# 3           659  family       9  ...  37.795486  128.917920  0
# 4           659  family       9  ...  37.689094  129.034821  0
# ...         ...     ...     ...  ...        ...         ... ..
# 219291      770  family       6  ...  37.865485  127.750965  0
# 219292      770  family       6  ...  37.850043  127.748694  0
# 219293      770  family      10  ...  37.979383  127.816946  0
# 219294      770  family       9  ...  37.867057  127.752314  0
# 219295      770  family       9  ...  37.884303  127.743665  0
#
# [219296 rows x 12 columns]

# %%
result1 = pd.concat([total,total1], ignore_index=True)
result1
# Out:
#         user_id    trip  course  ...  place_lat   place_lng  y
# 0           659  family       1  ...  37.754505  128.892756  1
# 1           660  family       1  ...  37.608975  129.029199  1
# 2           661  family       1  ...  37.805779  128.907417  1
# 3           661  family       2  ...  37.791905  128.915830  1
# 4           662  family       1  ...  37.795075  128.896598  1
# ...         ...     ...     ...  ...        ...         ... ..
# 219456      770  family       6  ...  37.865485  127.750965  0
# 219457      770  family       6  ...  37.850043  127.748694  0
# 219458      770  family      10  ...  37.979383  127.816946  0
# 219459      770  family       9  ...  37.867057  127.752314  0
# 219460      770  family       9  ...  37.884303  127.743665  0
#
# [219461 rows x 12 columns]

# %%
result1.to_csv('/content/drive/MyDrive/졸업프로젝트/강원도 명소 데이터/final data/family_full.csv', index = False, encoding='utf-8')

# %% [markdown]
# # y가 0인 데이터 100만개 이하로 줄이기

# %%
total2 = total1.sample(frac=0.003, random_state= 1)
total2
# Out:
#         user_id    trip  course  ...  place_lat   place_lng  y
# 60248       689  family       2  ...  37.929536  127.778762  0
# 100732      710  family       9  ...  37.752612  128.896434  0
# 164612      743  family       7  ...  37.745332  128.865827  0
# 95750       707  family      10  ...  37.860835  127.742176  0
# 74922       697  family       9  ...  37.766660  128.906482  0
# ...         ...     ...     ...  ...        ...         ... ..
# 78827       699  family       1  ...  37.889449  128.828080  0
# 36341       677  family       1  ...  38.002273  127.598936  0
# 214794      768  family       5  ...  37.880217  127.749967  0
# 205788      764  family       7  ...  37.578900  128.947873  0
# 181356      751  family       6  ...  37.938325  127.954976  0
#
# [658 rows x 12 columns]

# %%
result1 = pd.concat([total,total2], ignore_index=True)
result1
# Out:
#      user_id    trip  course  ...  place_lat   place_lng  y
# 0        659  family       1  ...  37.754505  128.892756  1
# 1        660  family       1  ...  37.608975  129.029199  1
# 2        661  family       1  ...  37.805779  128.907417  1
# 3        661  family       2  ...  37.791905  128.915830  1
# 4        662  family       1  ...  37.795075  128.896598  1
# ..       ...     ...     ...  ...        ...         ... ..
# 818      699  family       1  ...  37.889449  128.828080  0
# 819      677  family       1  ...  38.002273  127.598936  0
# 820      768  family       5  ...  37.880217  127.749967  0
# 821      764  family       7  ...  37.578900  128.947873  0
# 822      751  family       6  ...  37.938325  127.954976  0
#
# [823 rows x 12 columns]

# %% [markdown]
# # family 카테고리 csv

# %%
result1.to_csv('/content/drive/MyDrive/졸업프로젝트/강원도 명소 데이터/final data/family.csv', index = False, encoding='utf-8')
